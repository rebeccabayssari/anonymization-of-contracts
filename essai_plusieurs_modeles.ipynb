# %%
import re

def preprocess_contract(text):
    # Supprimer les sections de la table des matières (y compris les points et numéros)
    text = re.sub(r"(Article\s+\d+.*?\.{3,}\s+\d+\n?)", "", text, flags=re.DOTALL)

    # Supprimer les lignes contenant seulement des points 
    text = re.sub(r"\.{3,}", "", text)  # Supprime les lignes contenant des points répétés
    text = re.sub(r"Articl e \d+.*", "", text)  # Supprime les erreurs de format type "Articl e"

    # Supprimer les symboles comme "•", "✓"
    text = re.sub(r"[•✓✔]", "", text)

    # Supprimer explicitement les caractères inconnus affichés comme "?" dans un carré
    text = re.sub(r"[\ufffd\u3000]", "", text)  # Supprime les caractères problématiques

    # Supprimer les caractères non imprimables 
    text = re.sub(r"[^\w\s,.!?;:()\[\]{}'\"-éèêàùçÉÈÊÀÙÇ]", "", text, flags=re.UNICODE)

    # Normaliser les espaces et les lignes vides
    text = re.sub(r"[ ]{2,}", " ", text)  
    text = re.sub(r"\n{3,}", "\n\n", text)  

    return text


#input_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts/Contracts/2MAINS/CCAP_2MAINS_BPM031594_vF.txt"
#output_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts/Contracts/2MAINS/cleaned_contract_fixed_nchalla.txt"
#input_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts/Contracts/2MAINS/CCTP_2MAINS_BPM031594_vF.txt"
#output_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract2.txt"
#input_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts\Contracts\DATAVAL\REGLEMENT DE LA CONSULTATION.txt"
#output_path =  r"C:\Users\hp\Downloads\clever contact\cleanedcontract3.txt"
input_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts\Contracts\DATAVAL\CCAP MARCHE DATAVAL.txt"
output_path =  r"C:\Users\hp\Downloads\clever contact\cleanedcontract4.txt"




with open(input_path, "r", encoding="utf-8") as file:
    original_text = file.read()


cleaned_text = preprocess_contract(original_text)

with open(output_path, "w", encoding="utf-8") as file:
    file.write(cleaned_text)

print(f"Le contrat nettoyé a été sauvegardé dans : {output_path}")
# Out:
# Le contrat nettoyé a été sauvegardé dans : C:\Users\hp\Downloads\clever contact\cleanedcontract4.txt

# %%
#input_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts/Contracts/2MAINS/cleaned_contract_fixed_nchalla.txt"
#input_path =  r"C:\Users\hp\Downloads\clever contact\cleanedcontract2.txt"
#input_path =  r"C:\Users\hp\Downloads\clever contact\cleanedcontract3.txt"
input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract4.txt"




from transformers import CamembertTokenizerFast, CamembertForTokenClassification, pipeline
import spacy


model_checkpoint = "Jean-Baptiste/camembert-ner"
tokenizer = CamembertTokenizerFast.from_pretrained(model_checkpoint)
model = CamembertForTokenClassification.from_pretrained(model_checkpoint)
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, framework="pt")
nlp = spacy.load("fr_core_news_sm")  # model pour la segmentation des phrase

def split_text_into_sentence_chunks(text, sentences_per_chunk=2):
    
    doc = nlp(text)  
    sentences = [sent.text for sent in doc.sents]  # Extraction des phrases 

    # sentences_per_chunk
    chunks = []
    for i in range(0, len(sentences), sentences_per_chunk):
        chunk = " ".join(sentences[i:i + sentences_per_chunk])
        chunks.append(chunk)
    return chunks
def group_entities(entities, allowed_types={"B-ORG", "I-ORG", "B-LOC", "I-LOC"}):
    
    grouped_entities = []
    current_entity = None

    for entity in entities:
        entity_type = entity["entity"]
        word = entity["word"].replace("▁", "")  
        start = entity.get("start", 0)
        end = entity.get("end", 0)

        
        if not any(allowed in entity_type for allowed in allowed_types):
            continue

         # gerer la cotinuation du meme type d'entites
        if current_entity and (entity_type.startswith("I-") or entity_type == current_entity["entity"]):
            current_entity["text"] += " " + word
            current_entity["end"] = end
        else:
            if current_entity:
                grouped_entities.append(current_entity)
            current_entity = {"entity": entity_type, "text": word, "start": start, "end": end}

    if current_entity:
        grouped_entities.append(current_entity)

    return grouped_entities


with open(input_path, "r", encoding="utf-8") as file:
    cleaned_text = file.read()

sentence_chunks = split_text_into_sentence_chunks(cleaned_text, sentences_per_chunk=2)


sample_chunks = sentence_chunks[16:30]

#  Application de NER sur les chunks
for i, chunk in enumerate(sample_chunks):
    print(f"\nChunk {i + 1}:\n{chunk}\n")
    entities = ner_pipeline(chunk)
    grouped_entities = group_entities(entities)
    for entity in grouped_entities:
        print(f"Entity: {entity['text']} | Type: {entity['entity']} | Start: {entity['start']} | End: {entity['end']}")
# Out:
# Device set to use cpu
# Chunk 1:
# , Réversibilité et Transférabilité 16
#
# CCAP BPM060225_DATAVAL BPM060225
# 3/48 2.14Prix de laccord-cadre et des marches subséquents
# 16
# 2.14.1
#
# Entity: et | Type: I-LOC | Start: 15 | End: 18
#
# Chunk 2:
# Forme et contenu des prix de la partie à bons de commande de laccord-cadre 16
# 2.14.2 Révision des prix de la partie à bons de commande de laccord-cadre 16
# 2.14.3
#
#
# Chunk 3:
# Etablissement des prix plafonds de laccord-cadre pour les marchés subséquents 18
# 2.14.4 Révision des prix plafonds de laccord-cadre 18
# 3.1
#
#
# Chunk 4:
# Emission et exécution des bons de commande 18
# 3.2 Délai dexécution des prestations 20
# 4.1
#
# Entity: E | Type: I-LOC | Start: 0 | End: 1
#
# Chunk 5:
# Les pièces constitutives des marchés subséquents 20
# 4.2 Forme des marchés subséquents 20
# 4.3 Modalités de passation des marchés subséquents 20
# 4.3.1
#
# Entity: Les | Type: I-LOC | Start: 0 | End: 3
#
# Chunk 6:
# Modalités de passation 20
# 4.3.2 Obligation de réponse 21
# 4.4 Durée des marchés subséquents 21
# 4.5 Délai dexécution des marchés subséquents 21
# 5.1
#
#
# Chunk 7:
# Conditions dexécution 22
# 5.1.1 Gestion du personnel
#
#
# Chunk 8:
# 22
# 5.1.2 Mise en place de léquipe technique 22
# 5.1.3 Remplacement du personnel 22
#
#
#
# Chunk 9:
# 5.1.4 Délais dexécution des prestations 23
# 5.2
#
#
# Chunk 10:
# Pilotage 23
#  5.3 Exigences relatives aux prestations 23
# 5.4
#
#
# Chunk 11:
# Clause dinsertion par lactivité économique 23
# 5.4.1
#
#
# Chunk 12:
# Les publics visés 23
# 5.4.2 Objectif dinsertion 24
# 5.4.3 Les modalités de mise en œuvre des actions dinsertion. 24
# 5.4.4 Le dispositif daccompagnement pour la mise en œuvre des clauses sociales 25
# 5.4.5 Les modalités de contrôle de laction dinsertion 25
# 5.4.6 Clause
#
# Entity: Les Objectif | Type: I-LOC | Start: 0 | End: 35
#
# Chunk 13:
# RGPD relative au contrôle et au suivi de laction dinsertion 26
# 5.5 Considérations environnementales 27
# 5.6
#
#
# Chunk 14:
# Clauses de réexamen 27
# 5.6.1 Définitions 27
# 5.6.2

# %% [markdown]
# to save in a json file delete the previous if all okay

# %%
import spacy
import json
from transformers import CamembertTokenizerFast, CamembertForTokenClassification, pipeline
model_checkpoint = "Jean-Baptiste/camembert-ner"
tokenizer = CamembertTokenizerFast.from_pretrained(model_checkpoint)
model = CamembertForTokenClassification.from_pretrained(model_checkpoint)
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, framework="pt")
nlp = spacy.load("fr_core_news_lg")  # model pour la segmentation des phrase
#input_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts/Contracts/2MAINS/cleaned_contract_fixed_nchalla.txt"
#input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract2.txt"
#input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract3.txt"
input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract4.txt"

def split_text_into_sentence_chunks(text, sentences_per_chunk=2):
    doc = nlp(text)  
    sentences = [sent.text for sent in doc.sents]  # Extract sentences

    # Group sentences into chunks
    chunks = []
    for i in range(0, len(sentences), sentences_per_chunk):
        chunk = " ".join(sentences[i:i + sentences_per_chunk])
        chunks.append(chunk)
    
    return chunks
def group_entities(entities, allowed_types={"B-ORG", "I-ORG", "B-LOC", "I-LOC"}):
    
    grouped_entities = []
    current_entity = None

    for entity in entities:
        entity_type = entity["entity"]
        word = entity["word"].replace("▁", "")  
        start = entity.get("start", 0)
        end = entity.get("end", 0)

        
        if not any(allowed in entity_type for allowed in allowed_types):
            continue

         # gerer la cotinuation du meme type d'entites
        if current_entity and (entity_type.startswith("I-") or entity_type == current_entity["entity"]):
            current_entity["text"] += " " + word
            current_entity["end"] = end
        else:
            if current_entity:
                grouped_entities.append(current_entity)
            current_entity = {"entity": entity_type, "text": word, "start": start, "end": end}

    if current_entity:
        grouped_entities.append(current_entity)

    return grouped_entities
with open(input_path, "r", encoding="utf-8") as file:
    cleaned_text = file.read()

sentence_chunks = split_text_into_sentence_chunks(cleaned_text, sentences_per_chunk=2)
sample_chunks = sentence_chunks[16:50]

extracted_entities = [] 
#  Application de NER sur les chunks
for i, chunk in enumerate(sample_chunks):
    print(f"\nChunk {i + 1}:\n{chunk}\n")
    entities = ner_pipeline(chunk)
    grouped_entities = group_entities(entities)
    for entity in grouped_entities:
          extracted_entities.append({
            "text": entity['text'],
            "type": entity['entity'],
            "start": entity['start'],
            "end": entity['end'],
            "chunk_id": i + 1  # Store which chunk it came from
        })
# Save to a JSON file
with open("extracted_entities_jeanbaptiste4.json", "w", encoding="utf-8") as f:
    json.dump(extracted_entities, f, indent=4, ensure_ascii=False)

print(" Entities saved successfully!")
# Out:
# Device set to use cpu
# Chunk 1:
# Obligation de respect déontologique 15
# 2.13.8 État de lart 15
# 2.13.9 Initialisation
#
#
# Chunk 2:
# , Réversibilité et Transférabilité 16
#
# CCAP BPM060225_DATAVAL BPM060225
# 3/48
#
#
# Chunk 3:
# 2.14Prix de laccord -
#
#
# Chunk 4:
# cadre et des marches subséquents
# 16
# 2.14.1 Forme et contenu des prix de la partie à bons de commande de laccord
#
#
# Chunk 5:
# -cadre 16
# 2.14.2 Révision des prix de la partie à bons de commande de laccord
#
#
# Chunk 6:
# - cadre 16
# 2.14.3
#
#
# Chunk 7:
# Etablissement des prix plafonds de laccord -
#
#
# Chunk 8:
# cadre pour les marchés subséquents 18
# 2.14.4 Révision des prix plafonds de laccord
#
#
# Chunk 9:
# -cadre 18
# 3.1 Emission et exécution des bons de commande 18
# 3.2
#
#
# Chunk 10:
# Délai dexécution des prestations 20
# 4.1 Les pièces constitutives des marchés subséquents 20
# 4.2
#
#
# Chunk 11:
# Forme des marchés subséquents 20
# 4.3 Modalités de passation des marchés subséquents 20
# 4.3.1
#
#
# Chunk 12:
# Modalités de passation 20
# 4.3.2 Obligation de réponse
#
#
# Chunk 13:
# 21
# 4.4 Durée des marchés subséquents 21
# 4.5 Délai dexécution des marchés subséquents 21
# 5.1
#
#
# Chunk 14:
# Conditions dexécution 22
# 5.1.1 Gestion du personnel 22
# 5.1.2 Mise en place de léquipe technique 22
# 5.1.3
#
#
# Chunk 15:
# Remplacement du personnel 22
# 5.1.4 Délais dexécution des prestations 23
#
#
#
# Chunk 16:
# 5.2 Pilotage 23
# 5.3 Exigences relatives aux prestations 23
# 5.4
#
#
# Chunk 17:
# Clause dinsertion par lactivité économique 23
# 5.4.1 Les publics visés 23
# 5.4.2
#
#
# Chunk 18:
# Objectif dinsertion 24
# 5.4.3 Les modalités de mise en œuvre des actions dinsertion.
#
#
# Chunk 19:
# 24
# 5.4.4 Le dispositif daccompagnement pour la mise en œuvre des clauses sociales 25
# 5.4.5 Les modalités de contrôle de laction dinsertion 25
# 5.4.6 Clause RGPD
#
#
# Chunk 20:
# relative au contrôle et au suivi de laction dinsertion 26
# 5.5
#
#
# Chunk 21:
# Considérations environnementales 27
# 5.6 Clauses de réexamen 27
# 5.6.1
#
#
# Chunk 22:
# Définitions 27
# 5.6.2 Modalités
#
#
# Chunk 23:
# de mise en œuvre de la modification / de lajout 28
# 5.7 Constatation de lexécution des prestations et admission 28
#
# CCAP BPM060225_DATAVAL BPM060225
# 4/48 5.7.1 Contrôle 28
#
#
#
# Chunk 24:
# 5.7.2 Opérations de vérification 28
# 5.7.3 Décision après vérifications 30
# 5.7.4 Audits 31
#
#
#
# Chunk 25:
# 5.7.5 Arrêt de lexécution des prestations 31
# 5.8 Destruction des données 31
# 5.9 Garantie 32
# 5.10Pénalités de laccord-cadre et des marches subséquents
# 32
# 5.10.1 Pénalités liées à la sécurité 32
# 5.10.2 Pénalités et primes liées à lexécution des prestations 32
# 5.10.3 Pénalités liées aux clauses sociales 33
# 5.10.5 Plafonnement des pénalités 33
#
#
#
# Chunk 26:
# Le montant total des pénalités encourues est plafonné à 50 % du montant du bon de commande 33
# 5.10.6 Seuil
#
#
# Chunk 27:
# dexonération des pénalités 33
# 5.10.7 Modalités de mise en œuvre des pénalités et primes 34
# 5.11Régime financier
# 34
# 5.11.1
#
#
# Chunk 28:
# Avance 34
# 5.11.2 Modalités financières
#
#
# Chunk 29:
# 34
# 5.11.2.1 Répartition des paiements 34
# 5.11.2.2 Retenue de garantie et de cautionnement 35
# 5.11.2.3
#
#
# Chunk 30:
# Cession et nantissement de créance 35
# 5.11.2.4 Intérêts moratoires
#
#
# Chunk 31:
# 35
# 5.11.2.5 Modalités de facturation
#
#
# Chunk 32:
# 35
# 5.11.2.6 Mentions obligatoires 36
# 5.11.2.7
#
#
# Chunk 33:
# Modalités de transmission des factures 37
# 5.11.2.8 Taux de TVA 38
# 5.11.2.9 Monnaie 38
# 5.12 Langue
# 38
# 5.13 Sous-traitance
# 38
# 5.14Protection des données personnelles
# 38
# 5.15régime des droits de propriété intellectuelle
# 42
# 5.15.1
#
#
# Chunk 34:
# Régime des droits sur les résultats 42
# 5.15.2 Régime des droits sur les connaissances antérieures
#
#  Entities saved successfully!

# %%
# !python -m spacy download fr_core_news_md
# Out:
# Collecting fr-core-news-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_md-3.8.0/fr_core_news_md-3.8.0-py3-none-any.whl (45.8 MB)
#      ---------------------------------------- 0.0/45.8 MB ? eta -:--:--
#      ---------- ---------------------------- 11.8/45.8 MB 61.7 MB/s eta 0:00:01
#      ------------------- ------------------- 23.1/45.8 MB 56.2 MB/s eta 0:00:01
#      --------------------------------- ----- 39.6/45.8 MB 62.9 MB/s eta 0:00:01
#      --------------------------------------  45.6/45.8 MB 64.5 MB/s eta 0:00:01
#      --------------------------------------- 45.8/45.8 MB 53.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_md')
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# trial of improvement of jean-Baptiste/camembert-ner

# %%
import spacy
from transformers import CamembertTokenizerFast, CamembertForTokenClassification, pipeline
model_checkpoint = "Jean-Baptiste/camembert-ner"
tokenizer = CamembertTokenizerFast.from_pretrained(model_checkpoint)
model = CamembertForTokenClassification.from_pretrained(model_checkpoint)
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, framework="pt")
nlp = spacy.load("fr_core_news_md")  
#input_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts/Contracts/2MAINS/cleaned_contract_fixed_nchalla.txt"
#input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract2.txt"
#input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract3.txt"
input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract4.txt"

def split_text_into_sentence_chunks(text, sentences_per_chunk=2):
    doc = nlp(text)  
    sentences = [sent.text for sent in doc.sents]  # Extract sentences

    # Group sentences into chunks
    chunks = []
    for i in range(0, len(sentences), sentences_per_chunk):
        chunk = " ".join(sentences[i:i + sentences_per_chunk])
        chunks.append(chunk)
    
    return chunks
def group_entities(entities, allowed_types={"B-ORG", "I-ORG", "B-LOC", "I-LOC"}):
    grouped_entities = []
    current_entity = None

    for entity in entities:
        entity_type = entity["entity"]
        word = entity["word"].replace("▁", "").strip()  # Remove artifacts and spaces
        start = entity.get("start", 0)
        end = entity.get("end", 0)

        # Ignore unwanted entity types
        if not any(allowed in entity_type for allowed in allowed_types):
            continue

        # If there's an ongoing entity, check for merging conditions
        if current_entity:
            if (entity_type.startswith("I-") or entity_type[2:] == current_entity["entity"][2:]) and (
                entity["start"] == current_entity["end"] + 1 or word.islower()
            ):
                # Merge if it's a continuation
                current_entity["text"] += " " + word
                current_entity["end"] = end
            else:
                # Otherwise, save and start a new entity
                grouped_entities.append(current_entity)
                current_entity = {"entity": entity_type, "text": word, "start": start, "end": end}
        else:
            # Initialize first entity
            current_entity = {"entity": entity_type, "text": word, "start": start, "end": end}

    # Append last entity
    if current_entity:
        grouped_entities.append(current_entity)

    return grouped_entities
with open(input_path, "r", encoding="utf-8") as file:
    cleaned_text = file.read()

sentence_chunks = split_text_into_sentence_chunks(cleaned_text, sentences_per_chunk=2)
sample_chunks = sentence_chunks[16:50]


for i, chunk in enumerate(sample_chunks):
    print(f"\nChunk {i + 1}:\n{chunk}\n")
    entities = ner_pipeline(chunk)
    grouped_entities = group_entities(entities)
    for entity in grouped_entities:
        print(f"Entity: {entity['text']} | Type: {entity['entity']} | Start: {entity['start']} | End: {entity['end']}")
# Out:
# Device set to use cpu
# Chunk 1:
# Obligation de respect déontologique 15
# 2.13.8 État de lart 15
# 2.13.9 Initialisation, Réversibilité et Transférabilité 16
#
# CCAP BPM060225_DATAVAL BPM060225
# 3/48
#
#
# Chunk 2:
# 2.14Prix de laccord-cadre et des marches subséquents
# 16
# 2.14.1 Forme
#
#
# Chunk 3:
# et contenu des prix de la partie à bons de commande de laccord -cadre 16
# 2.14.2
#
#
# Chunk 4:
# Révision des prix de la partie à bons de commande de laccord -
#
#
# Chunk 5:
# cadre 16
# 2.14.3 Etablissement des prix plafonds de laccord-cadre pour les marchés subséquents 18
# 2.14.4
#
#
# Chunk 6:
# Révision des prix plafonds de laccord-cadre 18
# 3.1 Emission et exécution des bons de commande 18
# 3.2 Délai dexécution des prestations 20
# 4.1
#
# Entity: Ré | Type: I-LOC | Start: 0 | End: 2
#
# Chunk 7:
# Les pièces constitutives des marchés subséquents 20
# 4.2 Forme des marchés subséquents 20
# 4.3
#
# Entity: Les | Type: I-LOC | Start: 0 | End: 3
#
# Chunk 8:
# Modalités de passation des marchés subséquents 20
# 4.3.1 Modalités de passation 20
# 4.3.2
#
# Entity: s | Type: I-LOC | Start: 8 | End: 9
#
# Chunk 9:
# Obligation de réponse 21
# 4.4 Durée des marchés subséquents 21
# 4.5 Délai dexécution des marchés subséquents 21
# 5.1
#
#
# Chunk 10:
# Conditions dexécution 22
# 5.1.1 Gestion du personnel 22
# 5.1.2
#
#
# Chunk 11:
# Mise en place de léquipe technique 22
# 5.1.3 Remplacement du personnel 22
# 5.1.4
#
#
# Chunk 12:
# Délais dexécution des prestations 23
# 5.2 Pilotage 23
# 5.3
#
#
# Chunk 13:
# Exigences relatives aux prestations 23
# 5.4 Clause dinsertion par lactivité économique 23
#  5.4.1 Les publics visés 23
# 5.4.2 Objectif dinsertion 24
# 5.4.3 Les modalités de mise en œuvre des actions dinsertion.
#
# Entity: Ex | Type: I-LOC | Start: 0 | End: 2
#
# Chunk 14:
# 24
# 5.4.4 Le dispositif daccompagnement pour la mise en œuvre des clauses sociales 25
# 5.4.5 Les modalités de contrôle de laction dinsertion 25
# 5.4.6 Clause RGPD relative au contrôle et au suivi de laction dinsertion 26
# 5.5
#
#
# Chunk 15:
# Considérations environnementales 27
# 5.6 Clauses de réexamen 27
# 5.6.1
#
#
# Chunk 16:
# Définitions 27
# 5.6.2 Modalités de mise en œuvre de la modification / de lajout 28
# 5.7 Constatation de lexécution des prestations et admission 28
#
# CCAP BPM060225_DATAVAL BPM060225
# 4/48
#
#
# Chunk 17:
# 5.7.1 Contrôle 28
#  5.7.2 Opérations de vérification 28
# 5.7.3 Décision après vérifications 30
# 5.7.4 Audits 31
# 5.7.5
#
#
# Chunk 18:
# Arrêt de lexécution des prestations 31
# 5.8 Destruction des données 31
# 5.9 Garantie 32
# 5.10Pénalités de laccord-cadre et des marches subséquents
# 32
# 5.10.1 Pénalités liées à la sécurité 32
# 5.10.2
#
#
# Chunk 19:
# Pénalités et primes liées à lexécution des prestations 32
# 5.10.3 Pénalités liées aux clauses sociales 33
# 5.10.5 Plafonnement des pénalités 33
#
#
# Entity: Pén alité s | Type: I-LOC | Start: 0 | End: 9
#
# Chunk 20:
# Le montant total des pénalités encourues est plafonné à 50 % du montant du bon de commande 33
# 5.10.6 Seuil
#
#
# Chunk 21:
# dexonération des pénalités 33
# 5.10.7 Modalités de mise en œuvre des pénalités et primes 34
# 5.11Régime
#
#
# Chunk 22:
# financier
# 34
# 5.11.1 Avance 34
# 5.11.2
#
#
# Chunk 23:
# Modalités financières 34
# 5.11.2.1 Répartition des paiements 34
# 5.11.2.2
#
#
# Chunk 24:
# Retenue de garantie et de cautionnement 35
# 5.11.2.3 Cession et nantissement de créance 35
# 5.11.2.4 Intérêts moratoires 35
# 5.11.2.5
#
#
# Chunk 25:
# Modalités de facturation 35
# 5.11.2.6 Mentions obligatoires 36
# 5.11.2.7
#
#
# Chunk 26:
# Modalités de transmission des factures 37
# 5.11.2.8 Taux de TVA 38
# 5.11.2.9 Monnaie 38
# 5.12 Langue
# 38
# 5.13 Sous-traitance
# 38
# 5.14Protection
#
#
# Chunk 27:
# des données personnelles
# 38
# 5.15régime des droits de propriété intellectuelle
# 42
# 5.15.1 Régime des droits sur les résultats 42
# 5.15.2 Régime des droits sur les connaissances antérieures 43
# 5.15.3
#
#
# Chunk 28:
# Prix de la cession des droits 43
#
# CCAP BPM060225_DATAVAL BPM060225
# 5/48 5.16 Assurances
# 43
# 5.17Autres obligations administratives
# 43
# 5.18 Résiliation
# 44
# 5.19Exécution aux frais et risques du titulaire
# 45
# 5.20Dispositions applicables en cas de menace sanitaire grave appelant des mesures durgence
# 45
# 5.21Litiges et contentieux
# 48
# 5.22 Différends
# 48
#
# CCAP BPM060225_DATAVAL BPM060225
# 6/48
#
# Entity: B | Type: I-LOC | Start: 353 | End: 355
#
# Chunk 29:
# Définitions/Glossaire
#  Au sens du présent cahier des clauses administratives particulières (CCAP) et des différents documents
# particuliers du marché, les termes mentionnés ci-après sont définis comme suit :
#
#
#
# Chunk 30:
# Pouvoir adjudicateur Acheteur public
#
# Entity: Pouvoir ad | Type: I-ORG | Start: 0 | End: 10
# Entity:  | Type: I-ORG | Start: 20 | End: 21
# Entity: Acheteur public | Type: I-ORG | Start: 21 | End: 36
#
# Chunk 31:
# soumis à lordonnance n°2015 -899 du 23 juillet 2015
# relative aux marchés publics
#
#
# Chunk 32:
# . Cest le cocontractant du titulaire.
#
#
#
# Chunk 33:
# Il sagit de la Direction du numérique, et des directions bénéficiaires en
# charge de la conclusion du marché pour chaque marché subséquent.
#  Département ministériel
#
# Entity: Direction du numérique | Type: I-ORG | Start: 14 | End: 37
#
# Chunk 34:
# Partie, secteur de l'administration, constituant un ensemble spécialisé et
# autonome, attribué à un ministre.

# %%
import spacy
from transformers import CamembertTokenizerFast, CamembertForTokenClassification, pipeline
model_checkpoint = "Jean-Baptiste/camembert-ner"
tokenizer = CamembertTokenizerFast.from_pretrained(model_checkpoint)
model = CamembertForTokenClassification.from_pretrained(model_checkpoint)
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, framework="pt")
nlp = spacy.load("fr_core_news_md")  
#input_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts/Contracts/2MAINS/cleaned_contract_fixed_nchalla.txt"
#input_path =  r"C:\Users\hp\Downloads\clever contact\cleanedcontract2.txt"
#input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract3.txt"
input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract4.txt"
def split_text_into_sentence_chunks(text, sentences_per_chunk=2):
    doc = nlp(text)  
    sentences = [sent.text for sent in doc.sents]  # Extract sentences

    # Group sentences into chunks
    chunks = []
    for i in range(0, len(sentences), sentences_per_chunk):
        chunk = " ".join(sentences[i:i + sentences_per_chunk])
        chunks.append(chunk)
    
    return chunks
def group_entities(entities, allowed_types={"B-ORG", "I-ORG", "B-LOC", "I-LOC"}):
    grouped_entities = []
    current_entity = None

    for entity in entities:
        entity_type = entity["entity"]
        word = entity["word"].replace("▁", "").strip()  # Remove artifacts and spaces
        start = entity.get("start", 0)
        end = entity.get("end", 0)

        # Ignore unwanted entity types
        if not any(allowed in entity_type for allowed in allowed_types):
            continue

        # If there's an ongoing entity, check for merging conditions
        if current_entity:
            if (entity_type.startswith("I-") or entity_type[2:] == current_entity["entity"][2:]) and (
                entity["start"] == current_entity["end"] + 1 or word.islower()
            ):
                # Merge if it's a continuation
                current_entity["text"] += " " + word
                current_entity["end"] = end
            else:
                # Otherwise, save and start a new entity
                grouped_entities.append(current_entity)
                current_entity = {"entity": entity_type, "text": word, "start": start, "end": end}
        else:
            # Initialize first entity
            current_entity = {"entity": entity_type, "text": word, "start": start, "end": end}

    # Append last entity
    if current_entity:
        grouped_entities.append(current_entity)

    return grouped_entities
with open(input_path, "r", encoding="utf-8") as file:
    cleaned_text = file.read()

sentence_chunks = split_text_into_sentence_chunks(cleaned_text, sentences_per_chunk=2)
sample_chunks = sentence_chunks[16:50]


for i, chunk in enumerate(sample_chunks):
    print(f"\nChunk {i + 1}:\n{chunk}\n")
    entities = ner_pipeline(chunk)
    grouped_entities = group_entities(entities)
    for entity in grouped_entities:
         extracted_entities.append({
            "text": entity['text'],
            "type": entity['entity'],
            "start": entity['start'],
            "end": entity['end'],
            "chunk_id": i + 1  # Store which chunk it came from
        })
         print(f"Entity: {entity['text']} | Type: {entity['entity']} | Start: {entity['start']} | End: {entity['end']}")

# Save to a JSON file
with open("extracted_entities_jeanBaptisteimprovement4.json", "w", encoding="utf-8") as f:
    json.dump(extracted_entities, f, indent=4, ensure_ascii=False)

print(" Entities saved successfully!")
# Out:
# Device set to use cpu
# Chunk 1:
# Obligation de respect déontologique 15
# 2.13.8 État de lart 15
# 2.13.9 Initialisation, Réversibilité et Transférabilité 16
#
# CCAP BPM060225_DATAVAL BPM060225
# 3/48
#
#
# Chunk 2:
# 2.14Prix de laccord-cadre et des marches subséquents
# 16
# 2.14.1 Forme
#
#
# Chunk 3:
# et contenu des prix de la partie à bons de commande de laccord -cadre 16
# 2.14.2
#
#
# Chunk 4:
# Révision des prix de la partie à bons de commande de laccord -
#
#
# Chunk 5:
# cadre 16
# 2.14.3 Etablissement des prix plafonds de laccord-cadre pour les marchés subséquents 18
# 2.14.4
#
#
# Chunk 6:
# Révision des prix plafonds de laccord-cadre 18
# 3.1 Emission et exécution des bons de commande 18
# 3.2 Délai dexécution des prestations 20
# 4.1
#
# Entity: Ré | Type: I-LOC | Start: 0 | End: 2
#
# Chunk 7:
# Les pièces constitutives des marchés subséquents 20
# 4.2 Forme des marchés subséquents 20
# 4.3
#
# Entity: Les | Type: I-LOC | Start: 0 | End: 3
#
# Chunk 8:
# Modalités de passation des marchés subséquents 20
# 4.3.1 Modalités de passation 20
# 4.3.2
#
# Entity: s | Type: I-LOC | Start: 8 | End: 9
#
# Chunk 9:
# Obligation de réponse 21
# 4.4 Durée des marchés subséquents 21
# 4.5 Délai dexécution des marchés subséquents 21
# 5.1
#
#
# Chunk 10:
# Conditions dexécution 22
# 5.1.1 Gestion du personnel 22
# 5.1.2
#
#
# Chunk 11:
# Mise en place de léquipe technique 22
# 5.1.3 Remplacement du personnel 22
# 5.1.4
#
#
# Chunk 12:
# Délais dexécution des prestations 23
# 5.2 Pilotage 23
# 5.3
#
#
# Chunk 13:
# Exigences relatives aux prestations 23
# 5.4 Clause dinsertion par lactivité économique 23
#  5.4.1 Les publics visés 23
# 5.4.2 Objectif dinsertion 24
# 5.4.3 Les modalités de mise en œuvre des actions dinsertion.
#
# Entity: Ex | Type: I-LOC | Start: 0 | End: 2
#
# Chunk 14:
# 24
# 5.4.4 Le dispositif daccompagnement pour la mise en œuvre des clauses sociales 25
# 5.4.5 Les modalités de contrôle de laction dinsertion 25
# 5.4.6 Clause RGPD relative au contrôle et au suivi de laction dinsertion 26
# 5.5
#
#
# Chunk 15:
# Considérations environnementales 27
# 5.6 Clauses de réexamen 27
# 5.6.1
#
#
# Chunk 16:
# Définitions 27
# 5.6.2 Modalités de mise en œuvre de la modification / de lajout 28
# 5.7 Constatation de lexécution des prestations et admission 28
#
# CCAP BPM060225_DATAVAL BPM060225
# 4/48
#
#
# Chunk 17:
# 5.7.1 Contrôle 28
#  5.7.2 Opérations de vérification 28
# 5.7.3 Décision après vérifications 30
# 5.7.4 Audits 31
# 5.7.5
#
#
# Chunk 18:
# Arrêt de lexécution des prestations 31
# 5.8 Destruction des données 31
# 5.9 Garantie 32
# 5.10Pénalités de laccord-cadre et des marches subséquents
# 32
# 5.10.1 Pénalités liées à la sécurité 32
# 5.10.2
#
#
# Chunk 19:
# Pénalités et primes liées à lexécution des prestations 32
# 5.10.3 Pénalités liées aux clauses sociales 33
# 5.10.5 Plafonnement des pénalités 33
#
#
# Entity: Pén alité s | Type: I-LOC | Start: 0 | End: 9
#
# Chunk 20:
# Le montant total des pénalités encourues est plafonné à 50 % du montant du bon de commande 33
# 5.10.6 Seuil
#
#
# Chunk 21:
# dexonération des pénalités 33
# 5.10.7 Modalités de mise en œuvre des pénalités et primes 34
# 5.11Régime
#
#
# Chunk 22:
# financier
# 34
# 5.11.1 Avance 34
# 5.11.2
#
#
# Chunk 23:
# Modalités financières 34
# 5.11.2.1 Répartition des paiements 34
# 5.11.2.2
#
#
# Chunk 24:
# Retenue de garantie et de cautionnement 35
# 5.11.2.3 Cession et nantissement de créance 35
# 5.11.2.4 Intérêts moratoires 35
# 5.11.2.5
#
#
# Chunk 25:
# Modalités de facturation 35
# 5.11.2.6 Mentions obligatoires 36
# 5.11.2.7
#
#
# Chunk 26:
# Modalités de transmission des factures 37
# 5.11.2.8 Taux de TVA 38
# 5.11.2.9 Monnaie 38
# 5.12 Langue
# 38
# 5.13 Sous-traitance
# 38
# 5.14Protection
#
#
# Chunk 27:
# des données personnelles
# 38
# 5.15régime des droits de propriété intellectuelle
# 42
# 5.15.1 Régime des droits sur les résultats 42
# 5.15.2 Régime des droits sur les connaissances antérieures 43
# 5.15.3
#
#
# Chunk 28:
# Prix de la cession des droits 43
#
# CCAP BPM060225_DATAVAL BPM060225
# 5/48 5.16 Assurances
# 43
# 5.17Autres obligations administratives
# 43
# 5.18 Résiliation
# 44
# 5.19Exécution aux frais et risques du titulaire
# 45
# 5.20Dispositions applicables en cas de menace sanitaire grave appelant des mesures durgence
# 45
# 5.21Litiges et contentieux
# 48
# 5.22 Différends
# 48
#
# CCAP BPM060225_DATAVAL BPM060225
# 6/48
#
# Entity: B | Type: I-LOC | Start: 353 | End: 355
#
# Chunk 29:
# Définitions/Glossaire
#  Au sens du présent cahier des clauses administratives particulières (CCAP) et des différents documents
# particuliers du marché, les termes mentionnés ci-après sont définis comme suit :
#
#
#
# Chunk 30:
# Pouvoir adjudicateur Acheteur public
#
# Entity: Pouvoir ad | Type: I-ORG | Start: 0 | End: 10
# Entity:  | Type: I-ORG | Start: 20 | End: 21
# Entity: Acheteur public | Type: I-ORG | Start: 21 | End: 36
#
# Chunk 31:
# soumis à lordonnance n°2015 -899 du 23 juillet 2015
# relative aux marchés publics
#
#
# Chunk 32:
# . Cest le cocontractant du titulaire.
#
#
#
# Chunk 33:
# Il sagit de la Direction du numérique, et des directions bénéficiaires en
# charge de la conclusion du marché pour chaque marché subséquent.
#  Département ministériel
#
# Entity: Direction du numérique | Type: I-ORG | Start: 14 | End: 37
#
# Chunk 34:
# Partie, secteur de l'administration, constituant un ensemble spécialisé et
# autonome, attribué à un ministre.
#
#  Entities saved successfully!

# %%
! pip install flair
# Out:
# Requirement already satisfied: flair in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (0.15.0)
# Requirement already satisfied: boto3>=1.20.27 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (1.36.8)
# Requirement already satisfied: conllu<5.0.0,>=4.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (4.5.3)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (1.2.18)
# Requirement already satisfied: ftfy>=6.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (6.3.1)
# Requirement already satisfied: gdown>=4.4.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (5.2.0)
# Requirement already satisfied: huggingface-hub>=0.10.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (0.26.5)
# Requirement already satisfied: langdetect>=1.0.9 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (1.0.9)
# Requirement already satisfied: lxml>=4.8.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (5.3.0)
# Requirement already satisfied: matplotlib>=2.2.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (3.9.2)
# Requirement already satisfied: more-itertools>=8.13.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (10.6.0)
# Requirement already satisfied: mpld3>=0.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (0.5.10)
# Requirement already satisfied: pptree>=3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (2.9.0.post0)
# Requirement already satisfied: pytorch-revgrad>=0.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (0.2.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (2024.11.6)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (1.6.1)
# Requirement already satisfied: segtok>=1.5.11 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (1.5.11)
# Requirement already satisfied: sqlitedict>=2.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (2.1.0)
# Requirement already satisfied: tabulate>=0.8.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (0.9.0)
# Requirement already satisfied: torch!=1.8,>=1.5.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (2.5.1)
# Requirement already satisfied: tqdm>=4.63.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (4.67.1)
# Requirement already satisfied: transformer-smaller-training-vocab>=0.2.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (0.4.0)
# Requirement already satisfied: transformers<5.0.0,>=4.25.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (4.47.0)
# Requirement already satisfied: wikipedia-api>=0.5.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (0.8.1)
# Requirement already satisfied: bioc<3.0.0,>=2.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flair) (2.1)
# Requirement already satisfied: jsonlines>=1.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from bioc<3.0.0,>=2.0.0->flair) (4.0.0)
# Requirement already satisfied: intervaltree in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from bioc<3.0.0,>=2.0.0->flair) (3.1.0)
# Requirement already satisfied: docopt in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from bioc<3.0.0,>=2.0.0->flair) (0.6.2)
# Requirement already satisfied: botocore<1.37.0,>=1.36.8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from boto3>=1.20.27->flair) (1.36.8)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from boto3>=1.20.27->flair) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from boto3>=1.20.27->flair) (0.11.2)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from deprecated>=1.2.13->flair) (1.17.0)
# Requirement already satisfied: wcwidth in c:\users\hp\appdata\roaming\python\python312\site-packages (from ftfy>=6.1.0->flair) (0.2.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from gdown>=4.4.0->flair) (4.12.3)
# Requirement already satisfied: filelock in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from gdown>=4.4.0->flair) (3.16.1)
# Requirement already satisfied: requests[socks] in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from gdown>=4.4.0->flair) (2.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.10.0->flair) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.10.0->flair) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.10.0->flair) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.10.0->flair) (4.12.2)
# Requirement already satisfied: six in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from langdetect>=1.0.9->flair) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->flair) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->flair) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->flair) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->flair) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->flair) (1.26.4)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->flair) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->flair) (3.1.4)
# Requirement already satisfied: jinja2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from mpld3>=0.3->flair) (3.1.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.0.2->flair) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.0.2->flair) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.0.2->flair) (3.5.0)
# Requirement already satisfied: networkx in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from torch!=1.8,>=1.5.0->flair) (3.4.2)
# Requirement already satisfied: setuptools in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from torch!=1.8,>=1.5.0->flair) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from torch!=1.8,>=1.5.0->flair) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch!=1.8,>=1.5.0->flair) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.63.0->flair) (0.4.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.25.0->transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (0.4.5)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (0.2.0)
# Requirement already satisfied: protobuf in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from transformers[sentencepiece]<5.0.0,>=4.25.0->flair) (5.29.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from botocore<1.37.0,>=1.36.8->boto3>=1.20.27->flair) (2.2.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jsonlines>=1.2.0->bioc<3.0.0,>=2.0.0->flair) (24.2.0)
# Requirement already satisfied: accelerate>=0.26.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from transformers[sentencepiece,torch]<5.0,>=4.1->transformer-smaller-training-vocab>=0.2.3->flair) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->gdown>=4.4.0->flair) (2.6)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from intervaltree->bioc<3.0.0,>=2.0.0->flair) (2.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jinja2->mpld3>=0.3->flair) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests[socks]->gdown>=4.4.0->flair) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests[socks]->gdown>=4.4.0->flair) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests[socks]->gdown>=4.4.0->flair) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests[socks]->gdown>=4.4.0->flair) (1.7.1)
# Requirement already satisfied: psutil in c:\users\hp\appdata\roaming\python\python312\site-packages (from accelerate>=0.26.0->transformers[sentencepiece,torch]<5.0,>=4.1->transformer-smaller-training-vocab>=0.2.3->flair) (6.0.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# trial with flair

# %%
import spacy
import json
import pandas as pd
from flair.data import Sentence
from flair.models import SequenceTagger

# Load spaCy for sentence splitting
nlp = spacy.load("fr_core_news_sm")

def split_text_into_sentence_chunks(text, sentences_per_chunk=2):
    """Splits text into chunks of sentences."""
    doc = nlp(text)
    sentences = [sent.text for sent in doc.sents]
    chunks = [" ".join(sentences[i:i + sentences_per_chunk]) for i in range(0, len(sentences), sentences_per_chunk)]
    return chunks

# Load Flair NER tagger
tagger = SequenceTagger.load('flair/ner-french')

# Load text file
#input_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts/Contracts/2MAINS/cleaned_contract_fixed_nchalla.txt"
#input_path= r"C:\Users\hp\Downloads\clever contact\cleanedcontract2.txt"
#input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract3.txt"
input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract4.txt"
with open(input_path, "r", encoding="utf-8") as file:
    cleaned_text = file.read()

# Split text into chunks
sentence_chunks = split_text_into_sentence_chunks(cleaned_text, sentences_per_chunk=2)

# Extract entities
extracted_entities = []
for i, chunk in enumerate(sentence_chunks):
    sentence = Sentence(chunk)
    tagger.predict(sentence)
    
    for entity in sentence.get_spans('ner'):
        extracted_entities.append({
            "text": entity.text,
            "type": entity.tag,
            "start": entity.start_position,
            "end": entity.end_position,
            "chunk_id": i + 1  # Track which chunk the entity belongs to
        })

# Save to JSON file
json_output_file = "extracted_entities_flair4.json"
with open(json_output_file, "w", encoding="utf-8") as f:
    json.dump(extracted_entities, f, indent=4, ensure_ascii=False)

print(f" Entities saved successfully to {json_output_file}!")
# Out:
# 2025-04-05 02:54:08,555 SequenceTagger predicts: Dictionary with 19 tags: O, S-LOC, B-LOC, E-LOC, I-LOC, S-PER, B-PER, E-PER, I-PER, S-MISC, B-MISC, E-MISC, I-MISC, S-ORG, B-ORG, E-ORG, I-ORG, <START>, <STOP>
#  Entities saved successfully to extracted_entities_flair4.json!

# %% [markdown]
# First trial using Alizee/xlm-roberta-large-finetuned-wikiner-fr

# %%
import spacy
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Load SpaCy for sentence segmentation
nlp = spacy.load("fr_core_news_sm")

def split_text_into_sentence_chunks(text, sentences_per_chunk=2):
    doc = nlp(text)  
    sentences = [sent.text for sent in doc.sents]
    chunks = []
    for i in range(0, len(sentences), sentences_per_chunk):
        chunk = " ".join(sentences[i:i + sentences_per_chunk])
        chunks.append(chunk)
    return chunks


model_name = "Alizee/xlm-roberta-large-finetuned-wikiner-fr"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)


ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer)


#input_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts/Contracts/2MAINS/cleaned_contract_fixed_nchalla.txt"
#input_path =  r"C:\Users\hp\Downloads\clever contact\cleanedcontract2.txt"
#input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract3.txt"
input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract4.txt"

# Read and process the file
with open(input_path, "r", encoding="utf-8") as file:
    cleaned_text = file.read()

# Split text into chunks
sentence_chunks = split_text_into_sentence_chunks(cleaned_text, sentences_per_chunk=2)

# Apply NER on the chunks using the loaded xlm-roberta model
for i, chunk in enumerate(sentence_chunks):
    print(f"\nChunk {i + 1}:\n{chunk}\n")
    results = ner_pipeline(chunk)
    for result in results:
        entity = result['word']
        entity_type = result['entity']
        score = result['score']
        print(f"Entity: {entity} | Type: {entity_type} | Score: {score}")
# Out:
# Device set to use cpu
# Chunk 1:
# SECRETARIAT GENERAL
# DIRECTION DES FINANCES
#
#
# Chunk 2:
# ,
# DES ACHATS ET DES SERVICES
#
#
# Entity: ATS | Type: I-MISC | Score: 0.5736098289489746
# Entity: S | Type: I-MISC | Score: 0.6170268058776855
#
# Chunk 3:
# Numéro de consultation : BPM060225
# ACCORD
#
# Entity: ▁B | Type: I-MISC | Score: 0.5275194644927979
# Entity: PM | Type: I-MISC | Score: 0.5919273495674133
# Entity: 060 | Type: I-MISC | Score: 0.45134592056274414
#
# Chunk 4:
# - CADRE RELATIF
#
#
# Chunk 5:
# A DES PRESTATIONS DE VALORISATION DES
# DONNEES
#  CAHIER DES CLAUSES ADMINISTRATIVES
#
#
# Chunk 6:
# PARTICULIÈRES
#  Numéro de consultation :
#
# Entity: ▁PARTI | Type: I-LOC | Score: 0.44765371084213257
# Entity: C | Type: I-LOC | Score: 0.41455554962158203
# Entity: ULI | Type: I-LOC | Score: 0.48105278611183167
# Entity: È | Type: I-LOC | Score: 0.6068423390388489
# Entity: RES | Type: I-LOC | Score: 0.6377915143966675
#
# Chunk 7:
# BPM060225
# Procédure de passation : Appel doffres ouvert, en application des articles L2124-1, L2124-2, R2124-2
# et R2161-2 à R2161-5 du Code de la commande publique
# ACHETEUR
# MINISTERES SOCIAUX
# SECRETARIAT GENERAL
# DIRECTION DU NUMERIQUE
#
# CCAP BPM060225_DATAVAL BPM060225
# 2/48 Table des matières
# 2.6
#
# Entity: ▁B | Type: I-LOC | Score: 0.4576408565044403
# Entity: PM | Type: I-LOC | Score: 0.45403215289115906
# Entity: ▁L | Type: I-LOC | Score: 0.9060428142547607
# Entity: 21 | Type: I-LOC | Score: 0.7834323644638062
# Entity: ▁L | Type: I-LOC | Score: 0.9187129139900208
# Entity: 21 | Type: I-LOC | Score: 0.8290537595748901
# Entity: -2 | Type: I-LOC | Score: 0.5158957242965698
# Entity: ▁R | Type: I-LOC | Score: 0.9414685368537903
# Entity: 21 | Type: I-LOC | Score: 0.8764839768409729
# Entity: 24 | Type: I-LOC | Score: 0.5390378832817078
# Entity: ▁R | Type: I-LOC | Score: 0.9203054308891296
# Entity: 2 | Type: I-LOC | Score: 0.6223240494728088
# Entity: ▁R | Type: I-LOC | Score: 0.8985138535499573
# Entity: 21 | Type: I-LOC | Score: 0.744372546672821
# Entity: ▁Code | Type: I-LOC | Score: 0.5837125778198242
# Entity: ▁de | Type: I-LOC | Score: 0.46101537346839905
# Entity: ▁la | Type: I-MISC | Score: 0.4877224564552307
# Entity: ▁commande | Type: I-MISC | Score: 0.524675726890564
# Entity: ▁publique | Type: I-MISC | Score: 0.4626905918121338
# Entity: ▁MINI | Type: I-ORG | Score: 0.9872989058494568
# Entity: STER | Type: I-ORG | Score: 0.988973081111908
# Entity: ES | Type: I-ORG | Score: 0.9904153347015381
# Entity: ▁SOCI | Type: I-ORG | Score: 0.9908958077430725
# Entity: A | Type: I-ORG | Score: 0.99092698097229
# Entity: UX | Type: I-ORG | Score: 0.9875170588493347
# Entity: ▁B | Type: I-LOC | Score: 0.3890290856361389
# Entity: PM | Type: I-LOC | Score: 0.45165276527404785
# Entity: ▁B | Type: I-LOC | Score: 0.42143723368644714
# Entity: PM | Type: I-LOC | Score: 0.4814925789833069
#
# Chunk 8:
# Forme et étendue de laccord-cadre 10
# 2.6.1 Forme de chaque lot 10
# 2.6.2
#
#
# Chunk 9:
# Etendue de laccord-cadre 11
#  2.7 Documents contractuels de laccord-cadre 11
# 2.8
#
# Entity: ▁l | Type: I-MISC | Score: 0.6391432881355286
# Entity: accord | Type: I-MISC | Score: 0.6572211384773254
# Entity: - | Type: I-MISC | Score: 0.6816747784614563
# Entity: cad | Type: I-MISC | Score: 0.6041984558105469
# Entity: re | Type: I-MISC | Score: 0.6061410307884216
# Entity: ▁l | Type: I-MISC | Score: 0.6990446448326111
# Entity: accord | Type: I-MISC | Score: 0.6906417012214661
# Entity: - | Type: I-MISC | Score: 0.7338083982467651
# Entity: cad | Type: I-MISC | Score: 0.6486005783081055
# Entity: re | Type: I-MISC | Score: 0.6508892774581909
#
# Chunk 10:
# Représentation des parties de laccord-cadre 12
# 2.8.1 Représentation du pouvoir adjudicateur 12
#
#
# Entity: ▁Re | Type: I-LOC | Score: 0.3939840495586395
#
# Chunk 11:
# 2.8.2 Représentation du titulaire 12
#
#
#
# Chunk 12:
# 2.9 Durée de laccord-cadre 12
# 2.9.1 Cadre général 12
# 2.9.2 Reconduction de laccord-cadre 12
# Chaque lot peut être reconduit 2 fois par période de 12 mois chacune au plus tôt à compter de la date à
# laquelle le montant maximum est atteint, ou au plus tard au terme d'un délai dun an à compter de sa
# date de notification ou de sa reconduction, le cas échéant.
#
#
# Chunk 13:
# La durée totale, reconductions comprises,
# nexcédera pas quatre ans. 12
# 2.10Lieu dexécution
# 13
# 2.11Forme des notifications et des informations
# 13
# 2.12Responsabilité du titulaire
# 13
# 2.13Obligations du titulaire
# 13
# 2.13.1 Obligation de conseil 13
# 2.13.2
#
#
# Chunk 14:
# Obligation dinformation 13
# 2.13.3 Obligation de confidentialité 14
# 2.13.4
#
# Entity: ▁Ob | Type: I-MISC | Score: 0.4311417043209076
# Entity: lig | Type: I-MISC | Score: 0.5515194535255432
# Entity: ation | Type: I-MISC | Score: 0.5716769099235535
#
# Chunk 15:
# Mesures de sécurité 14
# 2.13.5 Mise à disposition des documents relatifs aux politiques et procédures de sécurité 14
# 2.13.6
#
# Entity: ures | Type: I-MISC | Score: 0.4811801612377167
#
# Chunk 16:
# Maintien en condition de sécurité 14
# 2.13.7 Obligation de respect déontologique 15
# 2.13.8 État de lart 15
# 2.13.9 Initialisation
#
# Entity: État | Type: I-LOC | Score: 0.41209906339645386
# Entity: ▁la | Type: I-LOC | Score: 0.40451663732528687
# Entity: rt | Type: I-LOC | Score: 0.40276098251342773
# Entity: ▁In | Type: I-MISC | Score: 0.8438449501991272
# Entity: iti | Type: I-MISC | Score: 0.8430666327476501
# Entity: al | Type: I-MISC | Score: 0.7671455144882202
# Entity: isation | Type: I-MISC | Score: 0.7560386061668396
#
# Chunk 17:
# , Réversibilité et Transférabilité 16
#
# CCAP BPM060225_DATAVAL BPM060225
# 3/48 2.14Prix de laccord-cadre et des marches subséquents
# 16
# 2.14.1
#
# Entity: ▁Ré | Type: I-MISC | Score: 0.5125597715377808
# Entity: versi | Type: I-MISC | Score: 0.7125231027603149
# Entity: bilité | Type: I-MISC | Score: 0.808621883392334
# Entity: ▁Trans | Type: I-MISC | Score: 0.8219291567802429
# Entity: fér | Type: I-MISC | Score: 0.8150335550308228
# Entity: a | Type: I-MISC | Score: 0.837556779384613
# Entity: bilité | Type: I-MISC | Score: 0.8237466216087341
# Entity: ▁C | Type: I-MISC | Score: 0.47062212228775024
# Entity: ▁B | Type: I-MISC | Score: 0.5883209705352783
# Entity: PM | Type: I-MISC | Score: 0.5478374361991882
# Entity: 060 | Type: I-MISC | Score: 0.4110482931137085
# Entity: ATA | Type: I-MISC | Score: 0.4734179973602295
# Entity: ▁B | Type: I-MISC | Score: 0.5311600565910339
# Entity: PM | Type: I-MISC | Score: 0.5532229542732239
# Entity: 060 | Type: I-MISC | Score: 0.39713940024375916
#
# Chunk 18:
# Forme et contenu des prix de la partie à bons de commande de laccord-cadre 16
# 2.14.2 Révision des prix de la partie à bons de commande de laccord-cadre 16
# 2.14.3
#
# Entity: ▁l | Type: I-MISC | Score: 0.6256687045097351
# Entity: accord | Type: I-MISC | Score: 0.5542421340942383
# Entity: - | Type: I-MISC | Score: 0.6412321329116821
# Entity: cad | Type: I-MISC | Score: 0.5653862357139587
# Entity: re | Type: I-MISC | Score: 0.5868690013885498
#
# Chunk 19:
# Etablissement des prix plafonds de laccord-cadre pour les marchés subséquents 18
# 2.14.4 Révision des prix plafonds de laccord-cadre 18
# 3.1
#
#
# Chunk 20:
# Emission et exécution des bons de commande 18
# 3.2 Délai dexécution des prestations 20
# 4.1
#
# Entity: ▁Dél | Type: I-MISC | Score: 0.5436975955963135
# Entity: ai | Type: I-MISC | Score: 0.5767033696174622
#
# Chunk 21:
# Les pièces constitutives des marchés subséquents 20
# 4.2 Forme des marchés subséquents 20
# 4.3 Modalités de passation des marchés subséquents 20
# 4.3.1
#
#
# Chunk 22:
# Modalités de passation 20
# 4.3.2 Obligation de réponse 21
# 4.4 Durée des marchés subséquents 21
# 4.5 Délai dexécution des marchés subséquents 21
# 5.1
#
#
# Chunk 23:
# Conditions dexécution 22
# 5.1.1 Gestion du personnel
#
# Entity: ▁Gestion | Type: I-LOC | Score: 0.6307126879692078
#
# Chunk 24:
# 22
# 5.1.2 Mise en place de léquipe technique 22
# 5.1.3 Remplacement du personnel 22
#
#
#
# Chunk 25:
# 5.1.4 Délais dexécution des prestations 23
# 5.2
#
# Entity: ▁Dél | Type: I-MISC | Score: 0.5085887908935547
# Entity: ais | Type: I-MISC | Score: 0.5824076533317566
#
# Chunk 26:
# Pilotage 23
#  5.3 Exigences relatives aux prestations 23
# 5.4
#
# Entity: ▁Pilot | Type: I-MISC | Score: 0.5198463797569275
#
# Chunk 27:
# Clause dinsertion par lactivité économique 23
# 5.4.1
#
#
# Chunk 28:
# Les publics visés 23
# 5.4.2 Objectif dinsertion 24
# 5.4.3 Les modalités de mise en œuvre des actions dinsertion. 24
# 5.4.4 Le dispositif daccompagnement pour la mise en œuvre des clauses sociales 25
# 5.4.5 Les modalités de contrôle de laction dinsertion 25
# 5.4.6 Clause
#
# Entity: ▁Object | Type: I-MISC | Score: 0.49906232953071594
#
# Chunk 29:
# RGPD relative au contrôle et au suivi de laction dinsertion 26
# 5.5 Considérations environnementales 27
# 5.6
#
# Entity: ▁ | Type: I-MISC | Score: 0.981979250907898
# Entity: RG | Type: I-MISC | Score: 0.9877049922943115
# Entity: PD | Type: I-MISC | Score: 0.9915737509727478
#
# Chunk 30:
# Clauses de réexamen 27
# 5.6.1 Définitions 27
# 5.6.2
#
# Entity: ▁Dé | Type: I-MISC | Score: 0.8509101271629333
# Entity: fini | Type: I-MISC | Score: 0.8226213455200195
# Entity: tions | Type: I-MISC | Score: 0.8643303513526917
#
# Chunk 31:
# Modalités de mise en œuvre de la modification / de lajout 28
# 5.7
#
# Entity: ▁la | Type: I-PER | Score: 0.991898775100708
# Entity: jo | Type: I-PER | Score: 0.9943536520004272
# Entity: ut | Type: I-PER | Score: 0.9921945333480835
#
# Chunk 32:
# Constatation de lexécution des prestations et admission 28
#
# CCAP BPM060225_DATAVAL BPM060225
# 4/48 5.7.1
#
# Entity: ▁C | Type: I-MISC | Score: 0.6458184123039246
# Entity: CAP | Type: I-MISC | Score: 0.6532402634620667
# Entity: ▁B | Type: I-MISC | Score: 0.7610962390899658
# Entity: PM | Type: I-MISC | Score: 0.8212514519691467
# Entity: 060 | Type: I-MISC | Score: 0.6684661507606506
# Entity: D | Type: I-MISC | Score: 0.5772392749786377
# Entity: ATA | Type: I-MISC | Score: 0.5598159432411194
# Entity: VAL | Type: I-MISC | Score: 0.5452624559402466
# Entity: ▁B | Type: I-MISC | Score: 0.658207893371582
# Entity: PM | Type: I-MISC | Score: 0.7599054574966431
# Entity: 060 | Type: I-MISC | Score: 0.5785364508628845
#
# Chunk 33:
# Contrôle 28
# 5.7.2 Opérations de vérification 28
# 5.7.3 Décision après vérifications 30
#
#
# Entity: ▁Contr | Type: I-MISC | Score: 0.8376407027244568
# Entity: ô | Type: I-MISC | Score: 0.8249750137329102
# Entity: le | Type: I-MISC | Score: 0.9040519595146179
# Entity: s | Type: I-MISC | Score: 0.491853803396225
# Entity: ▁Déc | Type: I-MISC | Score: 0.7841147184371948
# Entity: i | Type: I-MISC | Score: 0.7527029514312744
# Entity: sion | Type: I-MISC | Score: 0.7886267900466919
#
# Chunk 34:
# 5.7.4 Audits 31
# 5.7.5 Arrêt de lexécution des prestations 31
# 5.8 Destruction des données 31
# 5.9 Garantie 32
# 5.10Pénalités de laccord-cadre et des marches subséquents
#  32
# 5.10.1 Pénalités liées à la sécurité 32
# 5.10.2
#
# Entity: ▁Audi | Type: I-MISC | Score: 0.47060075402259827
# Entity: ts | Type: I-MISC | Score: 0.5086556673049927
# Entity: e | Type: I-MISC | Score: 0.4265381395816803
#
# Chunk 35:
# Pénalités et primes liées à lexécution des prestations 32
#  5.10.3
#
# Entity: ▁Pé | Type: I-LOC | Score: 0.400206059217453
# Entity: ités | Type: I-LOC | Score: 0.34190720319747925
#
# Chunk 36:
# Pénalités liées aux clauses sociales 33
# 5.10.5
#
#
# Chunk 37:
# Plafonnement des pénalités 33
#  Le montant total des pénalités encourues est plafonné à 50 % du montant du bon de commande 33
# 5.10.6
#
#
# Chunk 38:
# Seuil dexonération des pénalités 33
# 5.10.7 Modalités de mise en œuvre des pénalités et primes 34
# 5.11Régime financier
#
#
# Entity: ▁Seu | Type: I-LOC | Score: 0.431777685880661
# Entity: il | Type: I-LOC | Score: 0.3887525796890259
#
# Chunk 39:
# 34
# 5.11.1 Avance 34
# 5.11.2 Modalités financières 34
# 5.11.2.1 Répartition des paiements 34
# 5.11.2.2
#
# Entity: ▁A | Type: I-LOC | Score: 0.6821616888046265
# Entity: vance | Type: I-LOC | Score: 0.5709619522094727
#
# Chunk 40:
# Retenue de garantie et de cautionnement 35
# 5.11.2.3 Cession et nantissement de créance 35
# 5.11.2.4 Intérêts moratoires
#
# Entity: ▁In | Type: I-MISC | Score: 0.696378767490387
# Entity: tér | Type: I-MISC | Score: 0.5620244145393372
# Entity: ê | Type: I-MISC | Score: 0.6352473497390747
# Entity: ts | Type: I-MISC | Score: 0.7487661838531494
#
# Chunk 41:
# 35
# 5.11.2.5 Modalités de facturation 35
#  5.11.2.6 Mentions obligatoires 36
# 5.11.2.7 Modalités de transmission des factures 37
# 5.11.2.8 Taux de TVA 38
# 5.11.2.9 Monnaie 38
# 5.12 Langue
# 38
# 5.13 Sous-traitance
# 38
# 5.14Protection des données personnelles
# 38
# 5.15régime des droits de propriété intellectuelle
# 42
# 5.15.1 Régime des droits sur les résultats 42
# 5.15.2 Régime des droits sur les connaissances antérieures
#
# Entity: ités | Type: I-LOC | Score: 0.3812295198440552
# Entity: ▁Mon | Type: I-LOC | Score: 0.3789375126361847
# Entity: na | Type: I-MISC | Score: 0.40028929710388184
# Entity: ie | Type: I-MISC | Score: 0.44596847891807556
# Entity: ▁Lan | Type: I-MISC | Score: 0.9113550782203674
# Entity: gue | Type: I-MISC | Score: 0.9238191843032837
# Entity: ion | Type: I-MISC | Score: 0.48331961035728455
# Entity: ▁des | Type: I-MISC | Score: 0.5166022181510925
# Entity: ▁données | Type: I-MISC | Score: 0.48397237062454224
# Entity: ▁personnelles | Type: I-MISC | Score: 0.523237943649292
# Entity: ▁Régi | Type: I-MISC | Score: 0.3863247036933899
# Entity: me | Type: I-MISC | Score: 0.3875691294670105
#
# Chunk 42:
# 43
# 5.15.3 Prix de la cession des droits 43
#
# CCAP BPM060225_DATAVAL BPM060225
# 5/48 5.16 Assurances
# 43
# 5.17Autres obligations administratives
# 43
# 5.18 Résiliation
# 44
# 5.19Exécution aux frais et risques du titulaire
# 45
# 5.20Dispositions applicables en cas de menace sanitaire grave appelant des mesures durgence
# 45
# 5.21Litiges et contentieux
# 48
# 5.22 Différends
# 48
#
# CCAP BPM060225_DATAVAL BPM060225
#  6/48 Définitions/Glossaire
#
#
# Entity: ▁C | Type: I-MISC | Score: 0.6293877959251404
# Entity: CAP | Type: I-MISC | Score: 0.7227556705474854
# Entity: ▁B | Type: I-MISC | Score: 0.86197429895401
# Entity: PM | Type: I-MISC | Score: 0.8897994160652161
# Entity: ▁B | Type: I-MISC | Score: 0.6880848407745361
# Entity: PM | Type: I-MISC | Score: 0.7701082229614258
# Entity: ▁C | Type: I-MISC | Score: 0.607545793056488
# Entity: CAP | Type: I-MISC | Score: 0.6822974681854248
# Entity: ▁B | Type: I-MISC | Score: 0.8368252515792847
# Entity: PM | Type: I-MISC | Score: 0.8777955770492554
# Entity: ATA | Type: I-MISC | Score: 0.4485015571117401
# Entity: ▁B | Type: I-MISC | Score: 0.771226704120636
# Entity: PM | Type: I-MISC | Score: 0.8344950675964355
# Entity: s | Type: I-MISC | Score: 0.6325415372848511
# Entity: aire | Type: I-MISC | Score: 0.5137043595314026
#
# Chunk 43:
# Au sens du présent cahier des clauses administratives particulières (CCAP) et des différents documents
# particuliers du marché, les termes mentionnés ci-après sont définis comme suit :
# Pouvoir adjudicateur Acheteur public soumis à lordonnance n°2015-899 du 23 juillet 2015
# relative aux marchés publics.
#
# Entity: ▁A | Type: I-LOC | Score: 0.32981976866722107
# Entity: che | Type: I-MISC | Score: 0.3784104287624359
# Entity: teur | Type: I-MISC | Score: 0.3304351568222046
# Entity: ▁lor | Type: I-LOC | Score: 0.46872907876968384
# Entity: don | Type: I-LOC | Score: 0.4820764362812042
# Entity: n | Type: I-LOC | Score: 0.5104861259460449
# Entity: ance | Type: I-MISC | Score: 0.36219367384910583
#
# Chunk 44:
# Cest le cocontractant du titulaire.
#  Il sagit de la Direction du numérique, et des directions bénéficiaires en
# charge de la conclusion du marché pour chaque marché subséquent.
#
#
# Entity: ▁Direction | Type: I-LOC | Score: 0.5344710350036621
# Entity: ▁du | Type: I-ORG | Score: 0.4560099244117737
# Entity: ▁numérique | Type: I-ORG | Score: 0.4868704378604889
#
# Chunk 45:
# Département ministériel Partie, secteur de l'administration, constituant un ensemble spécialisé et
# autonome, attribué à un ministre.
# Service bénéficiaire Toutes les Directions des Ministères sociaux.
#
# Entity: ▁Parti | Type: I-LOC | Score: 0.4097329378128052
# Entity: e | Type: I-LOC | Score: 0.5009980201721191
# Entity: ▁Direction | Type: I-LOC | Score: 0.7918990254402161
# Entity: s | Type: I-LOC | Score: 0.729607343673706
# Entity: ▁Ministère | Type: I-LOC | Score: 0.5188340544700623
# Entity: s | Type: I-LOC | Score: 0.5461618900299072
# Entity: ▁sociaux | Type: I-ORG | Score: 0.44955965876579285
#
# Chunk 46:
# Les services bénéficiaires
# émettent directement leurs bons de commande et concluent leurs marchés
# subséquents.
#  DFAS
#
# Entity: ▁DF | Type: I-ORG | Score: 0.7411482334136963
# Entity: AS | Type: I-ORG | Score: 0.7536430358886719
#
# Chunk 47:
# Direction des finances, des achats et des services
#  DNUM
#
# Entity: ▁D | Type: I-ORG | Score: 0.49914056062698364
# Entity: NUM | Type: I-LOC | Score: 0.5102265477180481
#
# Chunk 48:
# Direction du numérique
#  DGCS
#
# Entity: ▁ | Type: I-ORG | Score: 0.9745137095451355
# Entity: DG | Type: I-ORG | Score: 0.9583324790000916
# Entity: CS | Type: I-ORG | Score: 0.9141649603843689
#
# Chunk 49:
# Direction Générale de la cohésion sociale
#  DGEFP
#
# Entity: ▁Direction | Type: I-ORG | Score: 0.8276484608650208
# Entity: ▁Général | Type: I-ORG | Score: 0.799441397190094
# Entity: e | Type: I-ORG | Score: 0.7959144711494446
# Entity: ▁de | Type: I-ORG | Score: 0.7670624256134033
# Entity: ▁la | Type: I-ORG | Score: 0.7688021063804626
# Entity: ▁co | Type: I-ORG | Score: 0.8402940630912781
# Entity: hé | Type: I-ORG | Score: 0.7518188953399658
# Entity: sion | Type: I-ORG | Score: 0.825691819190979
# Entity: ▁sociale | Type: I-ORG | Score: 0.8370167016983032
# Entity: ▁D | Type: I-ORG | Score: 0.9443821907043457
# Entity: GE | Type: I-ORG | Score: 0.9390357136726379
# Entity: FP | Type: I-ORG | Score: 0.9534578323364258
#
# Chunk 50:
# Délégation générale à l'emploi et à la formation professionnelle
#  MiTN Mission transformation numérique
# ARS
#
# Entity: ▁Mi | Type: I-ORG | Score: 0.8723628520965576
# Entity: TN | Type: I-ORG | Score: 0.882811963558197
# Entity: ▁Mission | Type: I-ORG | Score: 0.8635832071304321
# Entity: ▁transformation | Type: I-ORG | Score: 0.6387342214584351
# Entity: ▁numérique | Type: I-ORG | Score: 0.6889811158180237
# Entity: ▁ | Type: I-ORG | Score: 0.9671091437339783
# Entity: ARS | Type: I-ORG | Score: 0.9257177710533142
#
# Chunk 51:
# Agences régionales de santé
#  DGS
#
# Entity: ▁D | Type: I-LOC | Score: 0.44235697388648987
# Entity: GS | Type: I-LOC | Score: 0.5010039806365967
#
# Chunk 52:
# Direction Générale de la Santé
#  DGOS Direction Générale de l'Offre de Soins
#
#
# Entity: ▁Direction | Type: I-ORG | Score: 0.5938611030578613
# Entity: ▁Général | Type: I-LOC | Score: 0.49975740909576416
# Entity: e | Type: I-ORG | Score: 0.6985722780227661
# Entity: ▁de | Type: I-ORG | Score: 0.6175011396408081
# Entity: ▁la | Type: I-ORG | Score: 0.49790796637535095
# Entity: ▁Sant | Type: I-ORG | Score: 0.6276448965072632
# Entity: é | Type: I-ORG | Score: 0.6247217655181885
# Entity: ▁D | Type: I-ORG | Score: 0.7484496831893921
# Entity: GOS | Type: I-ORG | Score: 0.5994126200675964
# Entity: ▁Direction | Type: I-ORG | Score: 0.6440591216087341
# Entity: ▁Général | Type: I-ORG | Score: 0.5405622124671936
# Entity: e | Type: I-ORG | Score: 0.6451767086982727
# Entity: ▁de | Type: I-ORG | Score: 0.6013337969779968
# Entity: ▁l | Type: I-ORG | Score: 0.6043912172317505
# Entity: ' | Type: I-ORG | Score: 0.6350778937339783
# Entity: Off | Type: I-ORG | Score: 0.7020219564437866
# Entity: re | Type: I-ORG | Score: 0.6961237192153931
# Entity: ▁de | Type: I-ORG | Score: 0.626462459564209
# Entity: ▁So | Type: I-ORG | Score: 0.670710563659668
# Entity: ins | Type: I-ORG | Score: 0.6701253652572632
#
# Chunk 53:
# Titulaire Opérateur économique signataire du marché
# Délais Sexpriment en jours calendaires, sauf mention contraire.
# CCAP Cahier des Clauses Administratives Particulières
#
#
# Entity: ▁Dél | Type: I-MISC | Score: 0.823653519153595
# Entity: ais | Type: I-MISC | Score: 0.7116367816925049
# Entity: ▁Sex | Type: I-MISC | Score: 0.4992843270301819
# Entity: pri | Type: I-MISC | Score: 0.7143818140029907
# Entity: ment | Type: I-MISC | Score: 0.6447650194168091
# Entity: ▁C | Type: I-MISC | Score: 0.9534162282943726
# Entity: CAP | Type: I-MISC | Score: 0.9486307501792908
# Entity: ▁Ca | Type: I-MISC | Score: 0.9733075499534607
# Entity: hier | Type: I-MISC | Score: 0.9760011434555054
# Entity: ▁des | Type: I-MISC | Score: 0.9657518267631531
# Entity: ▁Claus | Type: I-MISC | Score: 0.9731172323226929
# Entity: es | Type: I-MISC | Score: 0.9820668697357178
# Entity: ▁Administrativ | Type: I-MISC | Score: 0.975562572479248
# Entity: es | Type: I-MISC | Score: 0.979744553565979
# Entity: ▁Parti | Type: I-MISC | Score: 0.9765397310256958
# Entity: cul | Type: I-MISC | Score: 0.9721181988716125
# Entity: ières | Type: I-MISC | Score: 0.9779518842697144
#
# Chunk 54:
# RH Ressources Humaines
# Mission
#
# Entity: ▁RH | Type: I-ORG | Score: 0.9946933388710022
# Entity: ▁Res | Type: I-ORG | Score: 0.9682628512382507
# Entity: source | Type: I-ORG | Score: 0.9536885023117065
# Entity: s | Type: I-ORG | Score: 0.9552674889564514
# Entity: ▁Huma | Type: I-ORG | Score: 0.9504333138465881
# Entity: ines | Type: I-ORG | Score: 0.9370391964912415
# Entity: ▁Mission | Type: I-MISC | Score: 0.7299086451530457
#
# Chunk 55:
# Prestation réalisée sur la base dun ou plusieurs bons de commande ou dun
# marché subséquent en vue datteindre lobjectif cible défini par le pouvoir
# adjudicateur.
#
# CCAP BPM060225_DATAVAL BPM060225
# 7/48
# Article 1
#
# Entity: ▁B | Type: I-LOC | Score: 0.8250494599342346
# Entity: PM | Type: I-LOC | Score: 0.8495927453041077
# Entity: 060 | Type: I-LOC | Score: 0.6265929341316223
# Entity: ▁B | Type: I-LOC | Score: 0.8747799396514893
# Entity: PM | Type: I-LOC | Score: 0.8930971622467041
# Entity: 060 | Type: I-LOC | Score: 0.7811589241027832
# Entity: 225 | Type: I-LOC | Score: 0.489321231842041
#
# Chunk 56:
# PREAMBULE- CONTEXTE
#  Les ministères sociaux sont engagés dans une démarche de promotion de la diversité et de légalité
# Professionnelle entre les femmes et les hommes.
#
#
# Entity: ▁l | Type: I-MISC | Score: 0.8572561740875244
# Entity: égalité | Type: I-MISC | Score: 0.8580188155174255
# Entity: ▁Profession | Type: I-MISC | Score: 0.8265615105628967
# Entity: nelle | Type: I-MISC | Score: 0.8313751220703125
# Entity: ▁entre | Type: I-MISC | Score: 0.7952627539634705
#
# Chunk 57:
# A ce titre, ils sont attentifs dans le choix de leurs contractants comme dans la réalisation des prestations, au
# respect des dispositions législatives et réglementaires en la matière.
#  Au-delà du respect de ces dispositions, les ministères sociaux sont également sensibles aux actions conduites
# par leurs prestataires dans ce domaine au sein de leur entreprise.
# Dans ce cadre, un questionnaire relatif aux actions conduites en matière de diversité et dégalité
# professionnelle entre les femmes et les hommes sera envoyé à la (aux) société(s) retenue(s) dans les jours
# suivant la notification du marché.
#
#
# Entity: ▁ministère | Type: I-ORG | Score: 0.5990885496139526
# Entity: s | Type: I-ORG | Score: 0.5131950974464417
#
# Chunk 58:
# Ce questionnaire devra être complété et renvoyé dans le mois suivant sa réception à ladresse suivante :
# Ministères sociaux
# Direction des finances, des achats et des services
# Sous-direction des achats et du développement durable
# 78-84, rue Olivier-de-Serres CS 59234
# 75739 PARIS cedex
# ou par courriel à :
# DFAS-DADD-RESEAU-ACHAT@sg.social.gouv.fr
# Article 2 DISPOSITIONS RELATIVES A LACCORD-CADRE
# 2.1 OBJET DE LACCORD-CADRE
#
#
# Entity: ▁Ministère | Type: I-ORG | Score: 0.9314294457435608
# Entity: s | Type: I-ORG | Score: 0.8918625712394714
# Entity: ▁sociaux | Type: I-ORG | Score: 0.8133100271224976
# Entity: ▁Direction | Type: I-LOC | Score: 0.7433251142501831
# Entity: ▁Sou | Type: I-LOC | Score: 0.7575319409370422
# Entity: s | Type: I-LOC | Score: 0.5402920842170715
# Entity: - | Type: I-LOC | Score: 0.5616573691368103
# Entity: ▁rue | Type: I-LOC | Score: 0.9750750660896301
# Entity: ▁Olivier | Type: I-LOC | Score: 0.9910582304000854
# Entity: - | Type: I-LOC | Score: 0.9938043355941772
# Entity: de | Type: I-LOC | Score: 0.9936701059341431
# Entity: - | Type: I-LOC | Score: 0.9946554899215698
# Entity: Ser | Type: I-LOC | Score: 0.991454005241394
# Entity: res | Type: I-LOC | Score: 0.9900063872337341
# Entity: ▁CS | Type: I-LOC | Score: 0.9348068237304688
# Entity: ▁ | Type: I-LOC | Score: 0.5574079751968384
# Entity: ▁75 | Type: I-LOC | Score: 0.9089749455451965
# Entity: 739 | Type: I-LOC | Score: 0.939370334148407
# Entity: ▁P | Type: I-LOC | Score: 0.9929787516593933
# Entity: ARIS | Type: I-LOC | Score: 0.9967838525772095
# Entity: ▁ce | Type: I-LOC | Score: 0.9754466414451599
# Entity: dex | Type: I-LOC | Score: 0.9766826629638672
# Entity: ▁LA | Type: I-MISC | Score: 0.49321460723876953
# Entity: CC | Type: I-MISC | Score: 0.6381057500839233
# Entity: ORD | Type: I-MISC | Score: 0.7347708344459534
# Entity: - | Type: I-MISC | Score: 0.6588258743286133
# Entity: CC | Type: I-MISC | Score: 0.5584231615066528
# Entity: ORD | Type: I-MISC | Score: 0.6732692718505859
# Entity: - | Type: I-MISC | Score: 0.5246025919914246
#
# Chunk 59:
# Le présent marché a pour objet les prestations nécessaires à la valorisation et au traitement des données des
# directions et délégations de ladministration centrale des ministères sociaux. Elle permet lachat de prestations
# de gouvernance et de cadrage de projets décisionnels, de modélisation et de création de bases de données,
# de chargement et mise en qualité des données, de traitements (croisement de sources de données, calculs
# dagrégats, traitements algorithmiques) et de mise à disposition des données (Business intelligence,
# datavisualisation).
#
#
# Entity: Business | Type: I-MISC | Score: 0.8616605997085571
# Entity: intelligence | Type: I-MISC | Score: 0.5980017781257629
#
# Chunk 60:
# Le périmètre technologique des projets concernés par ce marché correspond à lensemble des technologies
# et plateformes de traitement des données présentes aux ministères sociaux. Et quid pour lavenir ?
#
#
# Entity: ▁la | Type: I-LOC | Score: 0.6288274526596069
# Entity: venir | Type: I-LOC | Score: 0.7030011415481567
#
# Chunk 61:
# Ce marché ninclut pas lacquisition de progiciels.
#  Le présent marché est un marché de service.
# Codes CPV de la consultation : 72500000-0
#
#
# Chunk 62:
# - Services informatiques.
# 2.2 IDENTIFICATION DES ELEMENTS SOUMIS AU DROIT DE LA PROPRIETE INTELLECTUELLE
#
#
# Entity: ▁Services | Type: I-MISC | Score: 0.5099952220916748
# Entity: ▁informatique | Type: I-MISC | Score: 0.5483368635177612
# Entity: s | Type: I-MISC | Score: 0.5007994174957275
#
# Chunk 63:
# Les éléments soumis au droit de la propriété intellectuelle sont lensemble des livrables cités dans le CCTP
# aux articles 5, 6 (lot 1), 7 (lot 2), 8 (lot 3) et 9 (lot 4).
#
#  CCAP BPM060225_DATAVAL BPM060225
# 8/48 2.3 PERIMETRE DE LACCORD-CADRE
#
#
# Entity: ▁CC | Type: I-MISC | Score: 0.8697258830070496
# Entity: TP | Type: I-MISC | Score: 0.8730075359344482
# Entity: ▁B | Type: I-MISC | Score: 0.4192804992198944
# Entity: PM | Type: I-MISC | Score: 0.41530680656433105
# Entity: PM | Type: I-MISC | Score: 0.3974952697753906
#
# Chunk 64:
# Les bénéficiaires du présent marché sont toutes les directions et services dadministration centrale des
# ministères sociaux.
#  La maîtrise dœuvre (MOE) en charge de la définition, de la commande et du pilotage des prestations de
# maintenance et de développement est la Direction du Numérique (DNUM).
#
#
# Entity: ▁Direction | Type: I-ORG | Score: 0.5441429615020752
# Entity: ▁du | Type: I-ORG | Score: 0.6449877023696899
# Entity: ▁Nu | Type: I-ORG | Score: 0.6338453888893127
# Entity: mér | Type: I-ORG | Score: 0.6905509233474731
# Entity: ique | Type: I-ORG | Score: 0.7058008909225464
# Entity: D | Type: I-ORG | Score: 0.5710479617118835
# Entity: NUM | Type: I-LOC | Score: 0.5106925368309021
#
# Chunk 65:
# Certaines directions disposant de leurs propres ressources pour la conduite et le pilotage des projets
# informatiques peuvent toutefois être aussi MOE. Dans ce cas, ces directions utilisant directement un des lots,
# sont responsables de lensemble des prestations quelles commandent.
#
#
# Chunk 66:
# Elles gèrent en autonomie le côté
# opérationnel depuis la validation des devis, jusquà lémission des PV de SF en passant par toutes les phases
# intermédiaires.
# La gouvernance générale du marché est réalisée par la Direction du numérique des ministères sociaux
# (DNUM). Les directions, utilisant un des lots, participent aux instances de pilotage du marché et se conforment
# à lensemble des procédures du marché, notamment la règle dattribution des projets.
#
# Entity: ▁Direction | Type: I-ORG | Score: 0.8858944177627563
# Entity: ▁du | Type: I-ORG | Score: 0.9037076830863953
# Entity: ▁numérique | Type: I-ORG | Score: 0.9080852270126343
# Entity: ▁des | Type: I-ORG | Score: 0.9439034461975098
# Entity: ▁ministère | Type: I-ORG | Score: 0.9604969024658203
# Entity: s | Type: I-ORG | Score: 0.9667916893959045
# Entity: ▁sociaux | Type: I-ORG | Score: 0.9397734999656677
# Entity: D | Type: I-ORG | Score: 0.7783717513084412
# Entity: NUM | Type: I-ORG | Score: 0.7804166674613953
#
# Chunk 67:
# Pour les lots multi-
# attributaires, la règle du « tour de rôle » est centralisée pour toutes les directions.
#  Le présent marché, conclu par le pouvoir adjudicateur représenté par la Direction du numérique (DNUM) des
# Ministères Sociaux est ouvert à lensemble des services relevant du périmètre budgétaire des Ministères
# Sociaux, qui peuvent émettre des bons de commande pour leur besoin propre.
#
#
# Entity: ▁Direction | Type: I-ORG | Score: 0.5157827734947205
# Entity: ▁du | Type: I-ORG | Score: 0.5046669244766235
# Entity: ▁numérique | Type: I-ORG | Score: 0.39815059304237366
# Entity: D | Type: I-ORG | Score: 0.4490288496017456
# Entity: ▁Ministère | Type: I-ORG | Score: 0.9432520866394043
# Entity: s | Type: I-ORG | Score: 0.9612230658531189
# Entity: ▁Soci | Type: I-ORG | Score: 0.9545563459396362
# Entity: aux | Type: I-ORG | Score: 0.9558677077293396
# Entity: ▁Ministère | Type: I-ORG | Score: 0.9312508702278137
# Entity: s | Type: I-ORG | Score: 0.9580123424530029
# Entity: ▁Soci | Type: I-ORG | Score: 0.9549241065979004
# Entity: aux | Type: I-ORG | Score: 0.9511419534683228
#
# Chunk 68:
# Le périmètre du présent marché comprend lensemble des systèmes dinformation data des Directions
# dadministration centrale des ministères sociaux. Ce périmètre a vocation à senrichir au fur et à mesure de
# lexécution du présent marché.
#
#
# Entity: ▁Direction | Type: I-LOC | Score: 0.5094492435455322
# Entity: s | Type: I-LOC | Score: 0.5053390860557556
# Entity: administration | Type: I-ORG | Score: 0.411793053150177
# Entity: ▁centrale | Type: I-LOC | Score: 0.3698333501815796
#
# Chunk 69:
# Il comprend notamment :
#  Le système dinformation décisionnel de la DGEFP
#   La base connaissance entreprise (BCE) de la MiTN (DNUM)
#
#
# Entity: ▁D | Type: I-ORG | Score: 0.6579271554946899
# Entity: GE | Type: I-ORG | Score: 0.6222188472747803
# Entity: FP | Type: I-ORG | Score: 0.6976628303527832
# Entity: ▁Mi | Type: I-ORG | Score: 0.6568933129310608
# Entity: TN | Type: I-ORG | Score: 0.6707831025123596
# Entity: D | Type: I-LOC | Score: 0.4217571020126343
# Entity: NUM | Type: I-LOC | Score: 0.4858054518699646
#
# Chunk 70:
# Le SI MANDOLINE Décisionnel de la DGCS
#   Le SI DIAMANT du SCN SI des ARS (DNUM)
#
#
# Entity: ▁SI | Type: I-MISC | Score: 0.8610634803771973
# Entity: ▁M | Type: I-MISC | Score: 0.8745887279510498
# Entity: ANDO | Type: I-MISC | Score: 0.9326330423355103
# Entity: LINE | Type: I-MISC | Score: 0.9426130056381226
# Entity: ▁Déc | Type: I-MISC | Score: 0.9934644103050232
# Entity: i | Type: I-MISC | Score: 0.9906994700431824
# Entity: sion | Type: I-MISC | Score: 0.9902510643005371
# Entity: nel | Type: I-MISC | Score: 0.988860011100769
# Entity: ▁ | Type: I-ORG | Score: 0.8983376026153564
# Entity: DG | Type: I-ORG | Score: 0.8873066902160645
# Entity: CS | Type: I-ORG | Score: 0.814744234085083
# Entity: ▁SI | Type: I-MISC | Score: 0.8259024024009705
# Entity: ▁DIA | Type: I-MISC | Score: 0.5201614499092102
# Entity: MAN | Type: I-MISC | Score: 0.5251858234405518
# Entity: T | Type: I-MISC | Score: 0.6149961352348328
# Entity: ▁S | Type: I-ORG | Score: 0.8245478272438049
# Entity: CN | Type: I-ORG | Score: 0.6932990550994873
# Entity: ▁SI | Type: I-MISC | Score: 0.48641419410705566
# Entity: ▁ | Type: I-ORG | Score: 0.8608818054199219
# Entity: ARS | Type: I-ORG | Score: 0.8360980153083801
#
# Chunk 71:
# Le SI PILO360 de la DGOS
#   Le SI Aqua
#
# Entity: ▁SI | Type: I-MISC | Score: 0.6770607233047485
# Entity: ▁P | Type: I-MISC | Score: 0.6403315663337708
# Entity: ILO | Type: I-MISC | Score: 0.7047967314720154
# Entity: 360 | Type: I-MISC | Score: 0.5604978203773499
# Entity: ▁D | Type: I-ORG | Score: 0.5728741884231567
# Entity: GOS | Type: I-MISC | Score: 0.42517098784446716
# Entity: ▁Le | Type: I-MISC | Score: 0.6461275219917297
# Entity: ▁SI | Type: I-MISC | Score: 0.9571679830551147
# Entity: ▁Aqua | Type: I-MISC | Score: 0.9680533409118652
#
# Chunk 72:
# - Sise de la DGS
#
#
# Entity: ▁D | Type: I-LOC | Score: 0.8880005478858948
# Entity: GS | Type: I-LOC | Score: 0.9128948450088501
#
# Chunk 73:
# Lensemble des réalisations BI des Directions des ministères sociaux
#   Lensemble des tableaux de bord des Directions des ministères sociaux
# A noter que la cartographie (au sens Système dInformation Géographique) est exclue du périmètre du présent
# marché, sauf quand elle est accessoire et peut être prise en charge dans les outils de production de rapports
# ou de Dataviz
# La maîtrise dœuvre (MOE) en charge de la définition, de la commande et du pilotage des prestations de
# maintenance et de développement est la Direction du NUMérique (DNUM), utilisatrice majoritaire du marché.
#
#
# Entity: ▁Direction | Type: I-ORG | Score: 0.8688613772392273
# Entity: s | Type: I-ORG | Score: 0.8941671848297119
# Entity: ▁des | Type: I-ORG | Score: 0.9129535555839539
# Entity: ▁ministère | Type: I-ORG | Score: 0.9155133366584778
# Entity: s | Type: I-ORG | Score: 0.9113355875015259
# Entity: ▁sociaux | Type: I-ORG | Score: 0.9130113124847412
# Entity: ▁Direction | Type: I-ORG | Score: 0.8507214784622192
# Entity: s | Type: I-ORG | Score: 0.8720523118972778
# Entity: ▁des | Type: I-ORG | Score: 0.8916513919830322
# Entity: ▁ministère | Type: I-ORG | Score: 0.9051772356033325
# Entity: s | Type: I-ORG | Score: 0.8821464776992798
# Entity: ▁sociaux | Type: I-ORG | Score: 0.91568922996521
# Entity: ▁Sy | Type: I-MISC | Score: 0.9552505016326904
# Entity: st | Type: I-MISC | Score: 0.9362696409225464
# Entity: ème | Type: I-MISC | Score: 0.9531480073928833
# Entity: ▁d | Type: I-MISC | Score: 0.9607552886009216
# Entity: Information | Type: I-MISC | Score: 0.9779940247535706
# Entity: ▁Gé | Type: I-MISC | Score: 0.9544275403022766
# Entity: o | Type: I-MISC | Score: 0.9654607772827148
# Entity: graphique | Type: I-MISC | Score: 0.9589053988456726
# Entity: ▁Data | Type: I-MISC | Score: 0.9704915881156921
# Entity: viz | Type: I-MISC | Score: 0.9852978587150574
# Entity: ▁Direction | Type: I-ORG | Score: 0.8461198210716248
# Entity: ▁du | Type: I-ORG | Score: 0.8739758133888245
# Entity: ▁ | Type: I-ORG | Score: 0.860611081123352
# Entity: NUM | Type: I-ORG | Score: 0.8923243880271912
# Entity: é | Type: I-ORG | Score: 0.8937602043151855
# Entity: rique | Type: I-ORG | Score: 0.889561653137207
# Entity: D | Type: I-ORG | Score: 0.786819577217102
# Entity: NUM | Type: I-ORG | Score: 0.6759663224220276
#
# Chunk 74:
# Certaines directions disposant de leurs propres ressources pour la conduite et le pilotage des projets
# informatiques peuvent toutefois être aussi MOE. Dans ce cas, ces directions utilisant directement un des lots,
# sont responsables de lensemble des prestations quelles commandent.
#
#
# Chunk 75:
# Elles gèrent en autonomie le côté
# opérationnel depuis la validation des devis, jusquà lémission des PV de SF en passant par toutes les phases
# intermédiaires.
# La gouvernance générale du marché est réalisée au niveau de la DNUM. Les directions, utilisant un des lots,
# participent aux instances de pilotage du marché et se conforment à lensemble des procédures du marché,
# notamment la règle dattribution des projets.
#
# Entity: ▁D | Type: I-ORG | Score: 0.5503321886062622
# Entity: NUM | Type: I-ORG | Score: 0.36607611179351807
#
# Chunk 76:
# Pour les lots multi-attributaires, la règle du « tour de rôle» est
# centralisée pour toutes les directions.
#
#  CCAP BPM060225_DATAVAL BPM060225
# 9/48
# 2.4
#
# Entity: ▁C | Type: I-MISC | Score: 0.40122178196907043
# Entity: ▁B | Type: I-LOC | Score: 0.752781331539154
# Entity: PM | Type: I-LOC | Score: 0.8176555037498474
# Entity: 060 | Type: I-LOC | Score: 0.8070448040962219
# Entity: 225 | Type: I-LOC | Score: 0.5288919806480408
# Entity: ▁B | Type: I-LOC | Score: 0.8137632608413696
# Entity: PM | Type: I-LOC | Score: 0.8018419742584229
# Entity: 060 | Type: I-LOC | Score: 0.8002498745918274
# Entity: 225 | Type: I-LOC | Score: 0.5029789805412292
#
# Chunk 77:
# ALLOTISSEMENT
# Laccord-cadre est multi attributaire et alloti en 4 lots de la manière suivante :
# Nom des lots Perimetre Nombre
# dattributaires
# maximum
# Lot 1
# Gouvernance de la donnée
#
# Entity: ▁L | Type: I-MISC | Score: 0.8484518527984619
# Entity: accord | Type: I-MISC | Score: 0.8020890355110168
# Entity: - | Type: I-MISC | Score: 0.7252562046051025
# Entity: cad | Type: I-MISC | Score: 0.734233021736145
# Entity: re | Type: I-MISC | Score: 0.7612649202346802
# Entity: ▁Peri | Type: I-LOC | Score: 0.5363750457763672
# Entity: ▁Gou | Type: I-MISC | Score: 0.7938865423202515
# Entity: vern | Type: I-MISC | Score: 0.7721171379089355
# Entity: ance | Type: I-MISC | Score: 0.7934725284576416
#
# Chunk 78:
# Définition dune
#
# Entity: ▁du | Type: I-MISC | Score: 0.5246536731719971
# Entity: ne | Type: I-MISC | Score: 0.5286288261413574
#
# Chunk 79:
# stratégie de
# valorisation de la donnée
#   Définition du volet fonctionnel
#
#
#
# Chunk 80:
# Définition du volet technique
# 2
# Lot 2
# Informatique décisionnelle BI et
# Dataviz Cadrage et specification du besoin
#  Collecte et mise en qualité des
# données
#  Modélisation et réalisation de
# lentrepôt de données
#   Chargement des données et
# automatisation
#
#
# Entity: ▁Lot | Type: I-LOC | Score: 0.507262647151947
# Entity: ▁Informati | Type: I-MISC | Score: 0.7085584402084351
# Entity: que | Type: I-MISC | Score: 0.6993138194084167
# Entity: ▁BI | Type: I-MISC | Score: 0.7362757325172424
# Entity: ▁Data | Type: I-MISC | Score: 0.9899681806564331
# Entity: viz | Type: I-MISC | Score: 0.9899575114250183
#
# Chunk 81:
# Restitution des données
# 3
# Lot 3
# Data science et Intelligence
# artificielle Cadrage et spécification du besoin
#   Collecte et mise en qualité des
# données
#
#
# Entity: ▁Data | Type: I-MISC | Score: 0.85507732629776
# Entity: ▁science | Type: I-MISC | Score: 0.5852586627006531
# Entity: ▁Intelligence | Type: I-MISC | Score: 0.9491850733757019
# Entity: ▁artifici | Type: I-MISC | Score: 0.7707546949386597
#
# Chunk 82:
# Traitement algorithmique
#   Restitution des données
# 2
# Lot 4
#
#
# Entity: ▁Re | Type: I-MISC | Score: 0.9903156161308289
# Entity: stitu | Type: I-MISC | Score: 0.9724990129470825
# Entity: tion | Type: I-MISC | Score: 0.9902998208999634
# Entity: ▁des | Type: I-MISC | Score: 0.9013595581054688
# Entity: ▁données | Type: I-MISC | Score: 0.919694721698761
# Entity: ▁2 | Type: I-MISC | Score: 0.5562553405761719
# Entity: ▁Lot | Type: I-MISC | Score: 0.6345999240875244
#
# Chunk 83:
# Prestations daccompagnement à
# la valorisation des données Assistance à maîtrise dœuvre de
# projets data
#  Expertise technique
# 1
# Les soumissionnaires sont libres de présenter une offre pour chacun des lots. Cependant il existe une règle
# dexclusivité dattribution entre le lot 4 et les autres lots :
#
#
# Entity: ▁Assist | Type: I-MISC | Score: 0.472746342420578
# Entity: ance | Type: I-MISC | Score: 0.6076298952102661
# Entity: ▁data | Type: I-MISC | Score: 0.5821889042854309
# Entity: ▁Expert | Type: I-MISC | Score: 0.8895663619041443
# Entity: ise | Type: I-MISC | Score: 0.8363007307052612
# Entity: ▁technique | Type: I-MISC | Score: 0.7349148988723755
# Entity: ▁1 | Type: I-MISC | Score: 0.5056524276733398
#
# Chunk 84:
# - Les lots 1, 2 et 3 peuvent être attribués aux mêmes soumissionnaires ;
#  - Le lot 4 est exclusif des autres lots, il ne peut être attribué quà un seul titulaire autre que ceux retenus
# sur les lots 1,2 et 3.
#
#
#
# Chunk 85:
# Le soumissionnaire précise donc, dans le document non-contractuel « ordre de préférence dattribution des
# lots » (annexe 1 au RC), son ordre de préférence dattribution entre le lot 4 et les lots 1, 2 et 3. Ce document
# est remis au moment du dépôt de loffre.
#
# CCAP BPM060225_DATAVAL BPM060225
# 10/48 2.5 PROCEDURE DE PASSATION
#
#
# Entity: ▁RC | Type: I-MISC | Score: 0.5575321912765503
# Entity: ▁C | Type: I-MISC | Score: 0.3740254044532776
# Entity: ▁B | Type: I-LOC | Score: 0.5018555521965027
# Entity: PM | Type: I-LOC | Score: 0.4970623552799225
# Entity: 060 | Type: I-LOC | Score: 0.40375369787216187
# Entity: ▁B | Type: I-MISC | Score: 0.4757569134235382
# Entity: PM | Type: I-MISC | Score: 0.5322327613830566
# Entity: 060 | Type: I-LOC | Score: 0.3796321153640747
#
# Chunk 86:
# Le présent accord-cadre est un marché de services, passé selon une procédure dappel doffres ouvert en
# application des articles L2124-1, L2124-2, R2124-2 et R2161-2 à R2161-5 du Code de la commande publique.
# 2.6 FORME ET ETENDUE DE LACCORD-CADRE
#  Il sagit dun accord-cadre mixte, qui sexécute par lémission de bons de commande et à marchés
# subséquents, sans montant minimum mais avec un maximum de 126 000 000 HT sur la durée totale du
# marché (reconductions comprises), en application des articles R2162-2, R2162-13 et R2162-14 du code de la
# commande publique.
#
#
# Entity: ▁L | Type: I-LOC | Score: 0.8336243629455566
# Entity: 21 | Type: I-LOC | Score: 0.6473643183708191
# Entity: ▁L | Type: I-LOC | Score: 0.8575418591499329
# Entity: 21 | Type: I-LOC | Score: 0.699914813041687
# Entity: -2 | Type: I-LOC | Score: 0.44570252299308777
# Entity: ▁R | Type: I-LOC | Score: 0.8917247653007507
# Entity: 21 | Type: I-LOC | Score: 0.6727915406227112
# Entity: ▁R | Type: I-LOC | Score: 0.8790714740753174
# Entity: ▁R | Type: I-LOC | Score: 0.8507713675498962
# Entity: 21 | Type: I-LOC | Score: 0.521412193775177
# Entity: ▁Code | Type: I-LOC | Score: 0.7650496363639832
# Entity: ▁de | Type: I-LOC | Score: 0.7268251776695251
# Entity: ▁la | Type: I-LOC | Score: 0.7029803395271301
# Entity: ▁commande | Type: I-LOC | Score: 0.645411491394043
# Entity: ▁publique | Type: I-LOC | Score: 0.642259418964386
# Entity: ▁R | Type: I-LOC | Score: 0.8936743140220642
# Entity: ▁R | Type: I-LOC | Score: 0.8990613222122192
# Entity: ▁R | Type: I-LOC | Score: 0.8717057108879089
# Entity: 21 | Type: I-LOC | Score: 0.6353119015693665
# Entity: ▁code | Type: I-LOC | Score: 0.5875062942504883
# Entity: ▁de | Type: I-LOC | Score: 0.5876526236534119
# Entity: ▁la | Type: I-LOC | Score: 0.5779682993888855
# Entity: ▁commande | Type: I-LOC | Score: 0.514945387840271
# Entity: ▁publique | Type: I-LOC | Score: 0.5267344117164612
#
# Chunk 87:
# Le montant maximum indiqué ne correspond pas à un engagement de commandes.
# Pour chaque lot, celui-ci cessera automatiquement de produire ses effets et deviendra caduc si ce montant
# maximum est atteint. La fin du lot produite par l'atteinte du montant maximum sapplique quelle que soit la
# durée du lot prévue initialement.
# laccord-cadre est conclu à compter de sa date de notification pour une période initiale de 2 ans ferme, sauf si
# le montant maximum est atteint avant cette échéance, il sera ensuite reconductible 2 fois pour une durée pour
# une durée de 1 an s au plus tôt, à compter de la date à laquelle le montant maximum est atteint ou au plus
# tard au terme dun délai de :
#
#
#
# Chunk 88:
# - 2 ans mois à compter de sa date de notification pour la période ferme,
# - 1 an à compter de sa date de reconduction pour les périodes suivantes.
#  Sans que sa durée totale (toutes reconductions comprises) ne puisse excéder 4 ans
#
#
#
# Chunk 89:
# 2.6.1 Forme de chaque lot
# Chaque lot de laccord-cadre est multi-attributaires sauf le lot4 qui est mono-attributaire
#
#
#
# Chunk 90:
# Le présent document est commun à l'ensemble des lots. Pour chacun des lots, laccord-cadre est exécuté en
# partie par lémission de bons de commande et une partie donne lieu à la conclusion de marchés subséquents.
#
#
#
# Chunk 91:
# - Chaque lot est conclu sans minimum mais avec un maximum qui se décompose comme suit :
# Année 1 & Année 2 Année 3
#
# Entity: ▁An | Type: I-MISC | Score: 0.9385223984718323
# Entity: née | Type: I-MISC | Score: 0.9284167885780334
# Entity: ▁1 | Type: I-MISC | Score: 0.7390585541725159
# Entity: ▁An | Type: I-MISC | Score: 0.9648433923721313
# Entity: née | Type: I-MISC | Score: 0.9423114061355591
# Entity: ▁2 | Type: I-MISC | Score: 0.7939063906669617
# Entity: ▁An | Type: I-MISC | Score: 0.88226318359375
# Entity: née | Type: I-MISC | Score: 0.8282721638679504
# Entity: ▁3 | Type: I-MISC | Score: 0.7147208452224731
#
# Chunk 92:
# Année 4 Total
# Lot 1 12 M 6 M 6 M 24 M
# Lot 2 36 M 18 M 18 M 72 M
#
#
# Entity: ▁Total | Type: I-LOC | Score: 0.74311363697052
# Entity: ▁Lot | Type: I-LOC | Score: 0.9827987551689148
# Entity: ▁M | Type: I-LOC | Score: 0.5543857216835022
# Entity: ▁Lot | Type: I-LOC | Score: 0.9834182858467102
#
# Chunk 93:
# Lot 3 9 M 4,5 M 4,5 M 18 M
#
#
# Entity: ▁Lot | Type: I-LOC | Score: 0.988079845905304
#
# Chunk 94:
# Lot 4 6M 3 M 3 M 12 M
#
#
# Entity: ▁Lot | Type: I-LOC | Score: 0.8269537687301636
# Entity: M | Type: I-LOC | Score: 0.5304219722747803
#
# Chunk 95:
# - Lestimation pour toute la durée du marché est de 42 M HT qui se répartissent comme suit :
#  Lot 1 : 8 M HT
#
#
# Entity: ▁Les | Type: I-LOC | Score: 0.5900598168373108
# Entity: tim | Type: I-LOC | Score: 0.47261103987693787
# Entity: ation | Type: I-LOC | Score: 0.4545295834541321
#
# Chunk 96:
# Lot 2 : 24 M HT
#
#
# Entity: ▁Lot | Type: I-LOC | Score: 0.8633999824523926
#
# Chunk 97:
# Lot 3 : 6 M HT
#
#
# Entity: ▁Lot | Type: I-LOC | Score: 0.9667006731033325
#
# Chunk 98:
# Lot 4 : 4 M HT
#
# CCAP BPM060225_DATAVAL BPM060225
# 11/48 2.6.2
#
# Entity: ▁M | Type: I-LOC | Score: 0.5378559827804565
# Entity: ▁ | Type: I-LOC | Score: 0.7221503257751465
# Entity: HT | Type: I-LOC | Score: 0.7651002407073975
# Entity: ▁C | Type: I-LOC | Score: 0.8246945142745972
# Entity: CAP | Type: I-LOC | Score: 0.7563432455062866
# Entity: ▁B | Type: I-LOC | Score: 0.8755415081977844
# Entity: PM | Type: I-LOC | Score: 0.8987505435943604
# Entity: 060 | Type: I-LOC | Score: 0.8575899600982666
# Entity: 225 | Type: I-LOC | Score: 0.6404088735580444
# Entity: _ | Type: I-LOC | Score: 0.6611572504043579
# Entity: D | Type: I-LOC | Score: 0.7082735896110535
# Entity: ATA | Type: I-LOC | Score: 0.731547474861145
# Entity: VAL | Type: I-LOC | Score: 0.7458896636962891
# Entity: ▁B | Type: I-LOC | Score: 0.893279492855072
# Entity: PM | Type: I-LOC | Score: 0.9034432768821716
# Entity: 060 | Type: I-LOC | Score: 0.8350430727005005
# Entity: 225 | Type: I-LOC | Score: 0.5949209332466125
#
# Chunk 99:
# Etendue de laccord- cadre
# Partie à bons de commande
# Pour chacun des lots, la partie à bons de commande de laccord cadre concerne les prestations attendues,
# chacune de ces unités dœuvre fait lobjet
#
#
# Chunk 100:
# dune évaluation de charge ventilée par profil permettant de la
# chiffrer dans lannexe financière.
# Pour des prestations spécifiques du fait de leur nature
#
#
# Chunk 101:
# , leur complexité, ou leur importance, chaque service
# bénéficiaire pourra conclure des marchés subséquents.
#  Partie à marchés subséquents
# Dans le cas où la complexité des prestations envisagées ne seraient pas réalisables dans le cadre dun bon
# de commande, il est prévu de procéder via un marché subséquent.
#
#
#
# Chunk 102:
# Les cas envisageables pour la mise en œuvre de cette procédure pour lensemble des lots sont les suivants :
#  Nécessité dapporter des compléments ou des adaptations nécessaires au recours à une méthode de
# conduite de projet (les méthodes cycles en V, incrémentales ou mode agiles)
#  Nécessité dadaptation de la gouvernance du lot telle que, la phase dinitialisation sur un projet
# spécifique.
#  Pour des prestations spécifiques du fait de leur nature, leur complexité, ou leur importance, chaque
# service bénéficiaire pourra conclure des marchés subséquents permettant de préciser les
# caractéristiques et les modalités d'exécution des prestations demandées.
# Les marchés subséquents seront conclus sous la forme daccord-cadre à bons de commande, sur la base des
# Unités dœuvre à prix plafond décrites dans le BPU de chaque lot.
# Dans tous les autres cas on procèdera par simple bon de commande.
# 2.7 DOCUMENTS CONTRACTUELS DE LACCORD-
#
# Entity: ▁cycle | Type: I-MISC | Score: 0.7079939246177673
# Entity: s | Type: I-MISC | Score: 0.6978532075881958
# Entity: ▁en | Type: I-MISC | Score: 0.7113603949546814
# Entity: ▁V | Type: I-MISC | Score: 0.9408029913902283
# Entity: ▁Un | Type: I-MISC | Score: 0.8401442766189575
# Entity: ités | Type: I-MISC | Score: 0.739064633846283
# Entity: ▁d | Type: I-MISC | Score: 0.7586643695831299
# Entity: œuvre | Type: I-MISC | Score: 0.7805372476577759
# ...
# bénéfice de ce dernier.
#  Suspension à linitiative de lacheteur
#  Si lacheteur décide de suspendre lexécution de tout ou partie des prestations, il en informe le titulaire par
# écrit, dans les meilleurs délais et par tout moyen matériel ou dématérialisé permettant de déterminer de façon
# certaine la date et lheure de sa réception.
# Dans sa décision
#
# Entity: ▁Si | Type: I-MISC | Score: 0.6065204739570618
# Entity: che | Type: I-PER | Score: 0.5007907152175903
# Entity: teur | Type: I-PER | Score: 0.464735209941864
#
# Chunk 477:
# , lacheteur précise limpact éventuel de la suspension sur la durée du marché. Toute
# modification de la durée du marché ne peut résulter que dun avenant.
#
#
# Entity: ▁la | Type: I-PER | Score: 0.9979963898658752
# Entity: che | Type: I-PER | Score: 0.998306393623352
# Entity: teur | Type: I-PER | Score: 0.998069703578949
#
# Chunk 478:
# En cas de suspension de tout ou partie des prestations, les parties procèdent à létablissement dun constat
# contradictoire des prestations réalisées jusquà la suspension, sauf lorsque celui-ci savère manifestement
# inutile.
#
#
#
# Chunk 479:
# Lacheteur ne peut voir sa responsabilité contractuelle engagée dès lors quest établi un lien de causalité entre
# lévènement perturbateur et la décision de suspension.
#  Le titulaire, quant à lui, ne peut être sanctionné, se voir appliquer de pénalités contractuelles, ni voir sa
# responsabilité contractuelle engagée du fait de cette suspension.
#
#
#
# Chunk 480:
# Celle-ci donne lieu à indemnisation du titulaire sil démontre lexistence dun lien direct entre le préjudice subi
# et la suspension des prestations.
#  Pour ce faire, il adresse à lacheteur un mémoire en réclamation, conformément aux dispositions de larticle
# du CCAG de référence relatif aux différends entre les parties.
#
# Entity: ▁CC | Type: I-ORG | Score: 0.8805792927742004
# Entity: AG | Type: I-ORG | Score: 0.8918224573135376
#
# Chunk 481:
# Ce mémoire justifie :
# - les coûts darrêt des prestations objet du marché ;
#  - les coûts de remise en état à lissue de la suspension en vue de la reprise dexécution ;
#
#
#
# Chunk 482:
# - la part des charges dexploitation directement liées à lexécution du marché et qui ont continué dêtre
# supportées par le titulaire pendant la période de suspension.
#  Prolongation du délai dexécution des prestations
#
#
#
# Chunk 483:
# Lacheteur prolonge le délai dexécution dès lors que le titulaire est dans limpossibilité de le respecter, ou que
# cette exécution en temps et en heure nécessiterait des moyens dont la mobilisation ferait peser sur lui une
# charge manifestement excessive.
#
# Entity: ▁La | Type: I-PER | Score: 0.994056224822998
# Entity: che | Type: I-PER | Score: 0.9964761137962341
# Entity: teur | Type: I-PER | Score: 0.9927858710289001
#
# Chunk 484:
# Pour bénéficier de cette prolongation, le titulaire justifie des causes faisant
# obstacle à lexécution de tout ou partie des prestations dans le délai contractuel et du lien de causalité entre
# cette impossibilité et lévènement perturbateur.
# La demande de prolongation intervient avant lexpiration du délai contractuel et de la période associée à
# lévènement perturbateur. Elle seffectue dans les conditions fixées par le CCAG de référence.
#
#
# Entity: ▁CC | Type: I-ORG | Score: 0.6799126863479614
# Entity: AG | Type: I-ORG | Score: 0.6514668464660645
#
# Chunk 485:
# La prolongation du délai dexécution peut être à linitiative de lacheteur qui en informe le titulaire par écrit,
# dans les meilleurs délais et par tout moyen matériel ou dématérialisé permettant de déterminer de façon
# certaine la date et lheure de sa réception.
#
# CCAP BPM060225_DATAVAL BPM060225
# 47/48 En cas de prolongation, le nouveau délai a les mêmes effets que le délai contractuel et est dune durée
# suffisante pour la réalisation des prestations. La décision de prolongation précise son impact éventuel sur la
# durée du marché.
#
# Entity: ▁C | Type: I-MISC | Score: 0.42526930570602417
# Entity: ▁B | Type: I-LOC | Score: 0.48515358567237854
# Entity: PM | Type: I-LOC | Score: 0.46536991000175476
# Entity: 060 | Type: I-LOC | Score: 0.4113145172595978
# Entity: D | Type: I-MISC | Score: 0.3641108274459839
# Entity: ATA | Type: I-MISC | Score: 0.3879973292350769
# Entity: ▁B | Type: I-LOC | Score: 0.460202693939209
# Entity: PM | Type: I-MISC | Score: 0.4542999267578125
# Entity: 060 | Type: I-LOC | Score: 0.3567337393760681
#
# Chunk 486:
# Toute modification de la durée du marché ne peut résulter que dun avenant.
#  Résiliation en cas dimpossibilité dexécuter la prestation et indemnisation associée
# Lorsque le titulaire est dans limpossibilité dexécuter le marché du fait de lévènement perturbateur
#
#
# Chunk 487:
# , lacheteur
# prononce la résiliation du marché sur le fondement de larticle L. 2195-2 du code de la commande publique.
#  Le décompte de résiliation est établi conformément aux dispositions du CCAG de référence, en faisant
# application des modalités de résiliation sattachant au cas de résiliation pour évènement présentant les
# caractéristiques de la force majeure.
#
#
# Entity: ▁L | Type: I-LOC | Score: 0.7267187833786011
# Entity: . | Type: I-LOC | Score: 0.6280279159545898
# Entity: ▁code | Type: I-LOC | Score: 0.4892093539237976
# Entity: ▁de | Type: I-LOC | Score: 0.4884743392467499
# Entity: ▁la | Type: I-LOC | Score: 0.448961466550827
# Entity: ▁commande | Type: I-LOC | Score: 0.4092515707015991
# Entity: ▁publique | Type: I-LOC | Score: 0.45524951815605164
# Entity: ▁CC | Type: I-MISC | Score: 0.41550928354263306
#
# Chunk 488:
# Indemnisation suite à lannulation dun bon de commande
#  Lannulation dun bon de commande par lacheteur à la suite dun évènement perturbateur ouvre droit à une
# indemnisation du titulaire des dépenses spécifiquement engagées pour lexécution des prestations annulées.
#
#
# Entity: ▁Lan | Type: I-MISC | Score: 0.5598257184028625
#
# Chunk 489:
# Le titulaire adresse à lacheteur un mémoire en réclamation, conformément aux dispositions de larticle du
# CCAG de référence relative aux différends entre les parties. Ce mémoire justifie :
# - de lexistence du préjudice subi (réalité des charges pesant sur le titulaire et évaluation du montant demandé)
# ;
#
#
# Entity: che | Type: I-PER | Score: 0.49864161014556885
# Entity: teur | Type: I-PER | Score: 0.4306087791919708
# Entity: ▁CC | Type: I-ORG | Score: 0.8552939891815186
# Entity: AG | Type: I-ORG | Score: 0.8822656273841858
#
# Chunk 490:
# - de lexistence dun lien de causalité entre lévènement perturbateur et ledit préjudice.
#  Indemnisation en cas de poursuite dexécution bouleversant léquilibre du contrat
#
#
#
# Chunk 491:
# Lorsque léquilibre du contrat est bouleversé du fait de la poursuite de lexécution des prestations, le titulaire
# peut être indemnisé des charges supplémentaires extracontractuelles quil supporte, dans les conditions
# précisées par la circulaire du Premier ministre et du ministre de léconomie et des finances du 20 novembre
# 1974 relative à lindemnisation des titulaires de marchés publics en cas daccroissement imprévisible de leurs
# charges économiques
# Pour ce faire, le titulaire doit démontrer le bouleversement de léquilibre du contrat, la perte effective subie
# ainsi que le lien avec lévènement perturbateur. A défaut, la demande dindemnisation est rejetée.
#
#
# Entity: ▁Premier | Type: I-LOC | Score: 0.6746942400932312
# Entity: ▁ministre | Type: I-LOC | Score: 0.6096411347389221
# Entity: ▁ministre | Type: I-LOC | Score: 0.5845116376876831
# Entity: ▁de | Type: I-LOC | Score: 0.5825783014297485
# Entity: ▁l | Type: I-LOC | Score: 0.4970369040966034
# Entity: économie | Type: I-ORG | Score: 0.47552892565727234
# Entity: ▁et | Type: I-LOC | Score: 0.5988107919692993
# Entity: ▁des | Type: I-LOC | Score: 0.4823905825614929
# Entity: ▁finance | Type: I-LOC | Score: 0.5552000999450684
# Entity: s | Type: I-LOC | Score: 0.5967851877212524
#
# Chunk 492:
# Un pourcentage de 10% du montant de la perte effective reste à la charge du titulaire.
#  Demandes indemnitaires
#
#
# Entity: ▁Demand | Type: I-MISC | Score: 0.5157890319824219
# Entity: es | Type: I-MISC | Score: 0.7538869976997375
# Entity: ▁indem | Type: I-MISC | Score: 0.5445420145988464
# Entity: nit | Type: I-MISC | Score: 0.6320575475692749
# Entity: aires | Type: I-MISC | Score: 0.6324138045310974
#
# Chunk 493:
# Les demandes indemnitaires font lobjet dun mémoire en réclamation transmis à lacheteur par tout moyen
# matériel ou dématérialisé permettant de déterminer de façon certaine la date et lheure de sa réception. Le
# mémoire en réclamation est transmis dans les conditions fixées par larticle 55.2 du CCAG TIC et justifie de
# manière circonstanciée le préjudice subi, les coûts associés, et leur lien avec lévènement ayant caractère de
# force majeure.
#
#
# Entity: ▁la | Type: I-ORG | Score: 0.4287075102329254
# Entity: che | Type: I-ORG | Score: 0.8030590415000916
# Entity: teur | Type: I-ORG | Score: 0.7969571352005005
# Entity: ▁CC | Type: I-MISC | Score: 0.5344699025154114
# Entity: AG | Type: I-MISC | Score: 0.5102797746658325
# Entity: ▁TIC | Type: I-MISC | Score: 0.587064802646637
#
# Chunk 494:
# Ne peuvent être indemnisés des coûts résultant de la négligence ou de la défaillance du titulaire.
#  Modalités de communications en cas de crise sanitaire
# En période de crise sanitaire
#
#
# Chunk 495:
# , les réunions en présentiel peuvent être remplacées par des réunions à distance
# par tous moyens de téléconférence (audioconférence, visioconférence notamment).
#  Lorsque les parties privilégient les échanges dématérialisés, les modalités fixées au présent document
# sappliquent (cf article «
#
#
# Chunk 496:
# Forme des notifications et des informations »).
#
#  CCAP BPM060225_DATAVAL BPM060225
# 48/48
#
# Entity: ▁C | Type: I-MISC | Score: 0.5550045967102051
# Entity: CAP | Type: I-MISC | Score: 0.4850928485393524
# Entity: ▁B | Type: I-MISC | Score: 0.7249958515167236
# Entity: PM | Type: I-MISC | Score: 0.7889413833618164
# Entity: 060 | Type: I-MISC | Score: 0.6050325632095337
# Entity: 225 | Type: I-MISC | Score: 0.46909528970718384
# Entity: ▁B | Type: I-MISC | Score: 0.698715090751648
# Entity: PM | Type: I-MISC | Score: 0.7838560342788696
# Entity: 060 | Type: I-MISC | Score: 0.6155820488929749
#
# Chunk 497:
# 5.21 LITIGES ET CONTENTIEUX
#  Le présent accord-cadre est régi par le droit français.
# Tout litige dans le cadre du présent marché est soumis au Tribunal administratif de Paris (4 rue de Jouy
# 75004 Paris (Tel :01 44 59 44 00) pour les aspects concernant les modalités d'exécution du marché.
#
#
# Entity: ▁Tribunal | Type: I-LOC | Score: 0.9905328750610352
# Entity: ▁administra | Type: I-LOC | Score: 0.9781805276870728
# Entity: tif | Type: I-LOC | Score: 0.9811553955078125
# Entity: ▁de | Type: I-LOC | Score: 0.9440563321113586
# Entity: ▁Paris | Type: I-LOC | Score: 0.9929894208908081
# Entity: ▁rue | Type: I-LOC | Score: 0.9848836660385132
# Entity: ▁de | Type: I-LOC | Score: 0.9919074773788452
# Entity: ▁Jou | Type: I-LOC | Score: 0.9961771965026855
# Entity: y | Type: I-LOC | Score: 0.9966901540756226
# Entity: ▁750 | Type: I-LOC | Score: 0.6359573602676392
# Entity: 04 | Type: I-LOC | Score: 0.6484653353691101
# Entity: ▁Paris | Type: I-LOC | Score: 0.9991124272346497
#
# Chunk 498:
# Les tribunaux de grande instance compétents pour connaitre des actions en matière de propriété intellectuelle
# sont désignés par le Code de l'organisation judiciaire.
# 5.22 DIFFERENDS
# La procédure de règlement à lamiable des différends ou litiges, susceptibles de survenir en cours dexécution
# du marché est celle prévue aux articles R2197-1 à R2197-25 et D2197-13 à D2197-22 du Code de la
# commande publique.
#  Le comité consultatif compétent est le comité consultatif national de règlement amiable des litiges, 6 rue Louise
# Weiss, 75013 Paris (Tel : 01 44 87 17 17).
#
#
# Entity: ▁Code | Type: I-LOC | Score: 0.7569081783294678
# Entity: ▁de | Type: I-LOC | Score: 0.8076709508895874
# Entity: ▁l | Type: I-LOC | Score: 0.8164684176445007
# Entity: ' | Type: I-LOC | Score: 0.772560715675354
# Entity: organisation | Type: I-LOC | Score: 0.7268591523170471
# Entity: ▁judiciaire | Type: I-LOC | Score: 0.8028175234794617
# Entity: ▁R | Type: I-LOC | Score: 0.7061014175415039
# Entity: ▁R | Type: I-LOC | Score: 0.7283775806427002
# Entity: 21 | Type: I-LOC | Score: 0.4674220085144043
# Entity: ▁D | Type: I-LOC | Score: 0.6113538146018982
# Entity: ▁D | Type: I-LOC | Score: 0.5930399298667908
# Entity: 21 | Type: I-LOC | Score: 0.46563276648521423
# Entity: ▁Code | Type: I-LOC | Score: 0.7425488233566284
# Entity: ▁de | Type: I-LOC | Score: 0.6805033683776855
# Entity: ▁la | Type: I-LOC | Score: 0.6447274088859558
# Entity: ▁commande | Type: I-LOC | Score: 0.5968016386032104
# Entity: ▁publique | Type: I-LOC | Score: 0.5989682674407959
# Entity: ▁rue | Type: I-LOC | Score: 0.8647827506065369
# Entity: ▁Louise | Type: I-LOC | Score: 0.5133116841316223
# Entity: ▁Weiss | Type: I-LOC | Score: 0.5966894030570984
# Entity: ▁750 | Type: I-LOC | Score: 0.5203651785850525
# Entity: 13 | Type: I-LOC | Score: 0.5536593794822693
# Entity: ▁Paris | Type: I-LOC | Score: 0.998164713382721
#
# Chunk 499:
# Article 6 DEROGATION AU CCAG -TIC
#
#
# Entity: ▁CC | Type: I-ORG | Score: 0.6184351444244385
# Entity: AG | Type: I-ORG | Score: 0.7538489699363708
# Entity: TIC | Type: I-MISC | Score: 0.49472886323928833
#
# Chunk 500:
# Les dérogations au CCAG-TIC sont présentées dans le tableau récapitulatif ci-après :
# Article du présent
# CCAP Article du CCAG
#
#
# Entity: ▁CC | Type: I-MISC | Score: 0.80604487657547
# Entity: AG | Type: I-MISC | Score: 0.8247084617614746
# Entity: - | Type: I-MISC | Score: 0.8751108050346375
# Entity: TIC | Type: I-MISC | Score: 0.8722040057182312
# Entity: ▁C | Type: I-MISC | Score: 0.6216975450515747
# Entity: CAP | Type: I-MISC | Score: 0.5749192833900452
# Entity: ▁CC | Type: I-MISC | Score: 0.7755361795425415
# Entity: AG | Type: I-MISC | Score: 0.7582824230194092
#
# Chunk 501:
# auquel il est fait
# dérogation
#  Commentaire
#
# Entity: ▁Comment | Type: I-MISC | Score: 0.9893423318862915
# Entity: aire | Type: I-MISC | Score: 0.9914770722389221
#
# Chunk 502:
# - objet de la dérogation
# 2.13.3 5.1.1 La dérogation porte sur la Confidentialité
# 2.14.2 10.2.2
#
# Entity: ▁Confi | Type: I-MISC | Score: 0.9989571571350098
# Entity: d | Type: I-MISC | Score: 0.9991119503974915
# Entity: ential | Type: I-MISC | Score: 0.9993383288383484
# Entity: ité | Type: I-MISC | Score: 0.9991703033447266
# Entity: ▁2.1 | Type: I-MISC | Score: 0.701350748538971
#
# Chunk 503:
# La dérogation porte sur lapplication de la révision dans le
# temps
# 2.7 4.1 La dérogation porte lordre de priorité de pièces contractuelles
# 5.10.2.1
# 5.11.2.1, 5.11.2.6,
# 5.11.2.7 14
# 12.1.3 La dérogation porte sur les pénalités
# Règlement des groupements dopérateurs économiques
# 5.10.6 14.1.3
#
# Entity: ▁R | Type: I-ORG | Score: 0.7887717485427856
# Entity: è | Type: I-ORG | Score: 0.8130710124969482
# Entity: g | Type: I-ORG | Score: 0.8411037921905518
# Entity: lement | Type: I-ORG | Score: 0.843130350112915
# Entity: ▁des | Type: I-ORG | Score: 0.8492340445518494
# Entity: ▁groupe | Type: I-ORG | Score: 0.8983451724052429
# Entity: ments | Type: I-ORG | Score: 0.8681384325027466
# Entity: ▁d | Type: I-ORG | Score: 0.8447659611701965
# Entity: opéra | Type: I-ORG | Score: 0.8574035167694092
# Entity: teurs | Type: I-ORG | Score: 0.8591557741165161
# Entity: ▁économique | Type: I-ORG | Score: 0.8998398780822754
# Entity: s | Type: I-ORG | Score: 0.8533678650856018
#
# Chunk 504:
# La dérogation porte sur lexonération de pénalités
# 5.11.1 11 La dérogation porte sur Lavance
# 5.15.1 46 Régime PI
# 5.18 51 La dérogation porte sur la résiliation
# Article 7
#
# Entity: ▁L | Type: I-MISC | Score: 0.8469725251197815
# Entity: avance | Type: I-MISC | Score: 0.8982824683189392
# Entity: ▁Régi | Type: I-MISC | Score: 0.5634862184524536
# Entity: me | Type: I-MISC | Score: 0.5915027856826782
# Entity: ▁PI | Type: I-MISC | Score: 0.6388745307922363
# Entity: ▁Article | Type: I-MISC | Score: 0.48279592394828796
#
# Chunk 505:
# ANNEXE AU CCAP
# 1 - MODELE DE DECLARATION DINTERET
#
#
#
# Entity: ▁C | Type: I-MISC | Score: 0.7815225124359131
# Entity: CAP | Type: I-MISC | Score: 0.7752044796943665
# Entity: ▁D | Type: I-MISC | Score: 0.6551039814949036
# Entity: INTER | Type: I-MISC | Score: 0.8255996108055115
# Entity: ET | Type: I-MISC | Score: 0.8258028626441956

# %% [markdown]
# trial : Alizee/xlm-roberta-large-finetuned-wikiner-fr , with grouped_entities

# %%
import spacy
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline


nlp = spacy.load("fr_core_news_sm")

def split_text_into_sentence_chunks(text, sentences_per_chunk=2):
    doc = nlp(text)  
    #This line creates a list of all sentences in the text as strings.

    sentences = [sent.text for sent in doc.sents]
    chunks = []
    for i in range(0, len(sentences), sentences_per_chunk):
        chunk = " ".join(sentences[i:i + sentences_per_chunk])
        chunks.append(chunk)
    return chunks
#if current entity is in the allowed , it adds it , if not it resets it . then the function return the list of the grouped entities
def group_entities(results, allowed_types={"ORG", "LOC"}):
    grouped_entities = []
    current_entity = None

    for result in results:
        entity_type = result['entity'].split('-')[1]  # Assumes format B-ORG, I-LOC 
        word = result['word'].replace("▁", " ").strip()
        start = result['start']
        end = result['end']

        if entity_type not in allowed_types:
            if current_entity:
                grouped_entities.append(current_entity)
                current_entity = None
            continue

        if current_entity and entity_type == current_entity["type"]:
            current_entity["text"] += " " + word
            current_entity["end"] = end
        else:
            if current_entity:
                grouped_entities.append(current_entity)
            current_entity = {"text": word, "type": entity_type, "start": start, "end": end}

    if current_entity:
        grouped_entities.append(current_entity)

    return grouped_entities

# Load tokenizer and model 
model_name = "Alizee/xlm-roberta-large-finetuned-wikiner-fr"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)


ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer)
#input_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts/Contracts/2MAINS/cleaned_contract_fixed_nchalla.txt"
#input_path =  r"C:\Users\hp\Downloads\clever contact\cleanedcontract2.txt"
#input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract3.txt"
input_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract4.txt"

# Read and process the file
with open(input_path, "r", encoding="utf-8") as file:
    cleaned_text = file.read()


sentence_chunks = split_text_into_sentence_chunks(cleaned_text, sentences_per_chunk=2)
extracted_entities = []
# Apply NER on the chunks using the loaded model and group results
for i, chunk in enumerate(sentence_chunks):
    print(f"\nChunk {i + 1}:\n{chunk}\n")
    results = ner_pipeline(chunk)
    grouped_results = group_entities(results, allowed_types={"ORG", "LOC"})
    for entity in grouped_results:
         extracted_entities.append({
            "text": entity['text'],
            "type": entity['type'],
            "start": entity['start'],
            "end": entity['end'],
            "chunk_id": i + 1  # Track the chunk for reference
        })
         
        
    
# Save to a JSON file
with open("extracted_entities_Roberta4.json", "w", encoding="utf-8") as f:
    json.dump(extracted_entities, f, indent=4, ensure_ascii=False)

print(" Entities saved successfully!")
# Out:
# Device set to use cpu
# Chunk 1:
# SECRETARIAT GENERAL
# DIRECTION DES FINANCES
#
#
# Chunk 2:
# ,
# DES ACHATS ET DES SERVICES
#
#
#
# Chunk 3:
# Numéro de consultation : BPM060225
# ACCORD
#
#
# Chunk 4:
# - CADRE RELATIF
#
#
# Chunk 5:
# A DES PRESTATIONS DE VALORISATION DES
# DONNEES
#  CAHIER DES CLAUSES ADMINISTRATIVES
#
#
# Chunk 6:
# PARTICULIÈRES
#  Numéro de consultation :
#
#
# Chunk 7:
# BPM060225
# Procédure de passation : Appel doffres ouvert, en application des articles L2124-1, L2124-2, R2124-2
# et R2161-2 à R2161-5 du Code de la commande publique
# ACHETEUR
# MINISTERES SOCIAUX
# SECRETARIAT GENERAL
# DIRECTION DU NUMERIQUE
#
# CCAP BPM060225_DATAVAL BPM060225
# 2/48 Table des matières
# 2.6
#
#
# Chunk 8:
# Forme et étendue de laccord-cadre 10
# 2.6.1 Forme de chaque lot 10
# 2.6.2
#
#
# Chunk 9:
# Etendue de laccord-cadre 11
#  2.7 Documents contractuels de laccord-cadre 11
# 2.8
#
#
# Chunk 10:
# Représentation des parties de laccord-cadre 12
# 2.8.1 Représentation du pouvoir adjudicateur 12
#
#
#
# Chunk 11:
# 2.8.2 Représentation du titulaire 12
#
#
#
# Chunk 12:
# 2.9 Durée de laccord-cadre 12
# 2.9.1 Cadre général 12
# 2.9.2 Reconduction de laccord-cadre 12
# Chaque lot peut être reconduit 2 fois par période de 12 mois chacune au plus tôt à compter de la date à
# laquelle le montant maximum est atteint, ou au plus tard au terme d'un délai dun an à compter de sa
# date de notification ou de sa reconduction, le cas échéant.
#
#
# Chunk 13:
# La durée totale, reconductions comprises,
# nexcédera pas quatre ans. 12
# 2.10Lieu dexécution
# 13
# 2.11Forme des notifications et des informations
# 13
# 2.12Responsabilité du titulaire
# 13
# 2.13Obligations du titulaire
# 13
# 2.13.1 Obligation de conseil 13
# 2.13.2
#
#
# Chunk 14:
# Obligation dinformation 13
# 2.13.3 Obligation de confidentialité 14
# 2.13.4
#
#
# Chunk 15:
# Mesures de sécurité 14
# 2.13.5 Mise à disposition des documents relatifs aux politiques et procédures de sécurité 14
# 2.13.6
#
#
# Chunk 16:
# Maintien en condition de sécurité 14
# 2.13.7 Obligation de respect déontologique 15
# 2.13.8 État de lart 15
# 2.13.9 Initialisation
#
#
# Chunk 17:
# , Réversibilité et Transférabilité 16
#
# CCAP BPM060225_DATAVAL BPM060225
# 3/48 2.14Prix de laccord-cadre et des marches subséquents
# 16
# 2.14.1
#
#
# Chunk 18:
# Forme et contenu des prix de la partie à bons de commande de laccord-cadre 16
# 2.14.2 Révision des prix de la partie à bons de commande de laccord-cadre 16
# 2.14.3
#
#
# Chunk 19:
# Etablissement des prix plafonds de laccord-cadre pour les marchés subséquents 18
# 2.14.4 Révision des prix plafonds de laccord-cadre 18
# 3.1
#
#
# Chunk 20:
# Emission et exécution des bons de commande 18
# 3.2 Délai dexécution des prestations 20
# 4.1
#
#
# Chunk 21:
# Les pièces constitutives des marchés subséquents 20
# 4.2 Forme des marchés subséquents 20
# 4.3 Modalités de passation des marchés subséquents 20
# 4.3.1
#
#
# Chunk 22:
# Modalités de passation 20
# 4.3.2 Obligation de réponse 21
# 4.4 Durée des marchés subséquents 21
# 4.5 Délai dexécution des marchés subséquents 21
# 5.1
#
#
# Chunk 23:
# Conditions dexécution 22
# 5.1.1 Gestion du personnel
#
#
# Chunk 24:
# 22
# 5.1.2 Mise en place de léquipe technique 22
# 5.1.3 Remplacement du personnel 22
#
#
#
# Chunk 25:
# 5.1.4 Délais dexécution des prestations 23
# 5.2
#
#
# Chunk 26:
# Pilotage 23
#  5.3 Exigences relatives aux prestations 23
# 5.4
#
#
# Chunk 27:
# Clause dinsertion par lactivité économique 23
# 5.4.1
#
#
# Chunk 28:
# Les publics visés 23
# 5.4.2 Objectif dinsertion 24
# 5.4.3 Les modalités de mise en œuvre des actions dinsertion. 24
# 5.4.4 Le dispositif daccompagnement pour la mise en œuvre des clauses sociales 25
# 5.4.5 Les modalités de contrôle de laction dinsertion 25
# 5.4.6 Clause
#
#
# Chunk 29:
# RGPD relative au contrôle et au suivi de laction dinsertion 26
# 5.5 Considérations environnementales 27
# 5.6
#
#
# Chunk 30:
# Clauses de réexamen 27
# 5.6.1 Définitions 27
# 5.6.2
#
#
# Chunk 31:
# Modalités de mise en œuvre de la modification / de lajout 28
# 5.7
#
#
# Chunk 32:
# Constatation de lexécution des prestations et admission 28
#
# CCAP BPM060225_DATAVAL BPM060225
# 4/48 5.7.1
#
#
# Chunk 33:
# Contrôle 28
# 5.7.2 Opérations de vérification 28
# 5.7.3 Décision après vérifications 30
#
#
#
# Chunk 34:
# 5.7.4 Audits 31
# 5.7.5 Arrêt de lexécution des prestations 31
# 5.8 Destruction des données 31
# 5.9 Garantie 32
# 5.10Pénalités de laccord-cadre et des marches subséquents
#  32
# 5.10.1 Pénalités liées à la sécurité 32
# 5.10.2
#
#
# Chunk 35:
# Pénalités et primes liées à lexécution des prestations 32
#  5.10.3
#
#
# Chunk 36:
# Pénalités liées aux clauses sociales 33
# 5.10.5
#
#
# Chunk 37:
# Plafonnement des pénalités 33
#  Le montant total des pénalités encourues est plafonné à 50 % du montant du bon de commande 33
# 5.10.6
#
#
# Chunk 38:
# Seuil dexonération des pénalités 33
# 5.10.7 Modalités de mise en œuvre des pénalités et primes 34
# 5.11Régime financier
#
#
#
# Chunk 39:
# 34
# 5.11.1 Avance 34
# 5.11.2 Modalités financières 34
# 5.11.2.1 Répartition des paiements 34
# 5.11.2.2
#
#
# Chunk 40:
# Retenue de garantie et de cautionnement 35
# 5.11.2.3 Cession et nantissement de créance 35
# 5.11.2.4 Intérêts moratoires
#
#
# Chunk 41:
# 35
# 5.11.2.5 Modalités de facturation 35
#  5.11.2.6 Mentions obligatoires 36
# 5.11.2.7 Modalités de transmission des factures 37
# 5.11.2.8 Taux de TVA 38
# 5.11.2.9 Monnaie 38
# 5.12 Langue
# 38
# 5.13 Sous-traitance
# 38
# 5.14Protection des données personnelles
# 38
# 5.15régime des droits de propriété intellectuelle
# 42
# 5.15.1 Régime des droits sur les résultats 42
# 5.15.2 Régime des droits sur les connaissances antérieures
#
#
# Chunk 42:
# 43
# 5.15.3 Prix de la cession des droits 43
#
# CCAP BPM060225_DATAVAL BPM060225
# 5/48 5.16 Assurances
# 43
# 5.17Autres obligations administratives
# 43
# 5.18 Résiliation
# 44
# 5.19Exécution aux frais et risques du titulaire
# 45
# 5.20Dispositions applicables en cas de menace sanitaire grave appelant des mesures durgence
# 45
# 5.21Litiges et contentieux
# 48
# 5.22 Différends
# 48
#
# CCAP BPM060225_DATAVAL BPM060225
#  6/48 Définitions/Glossaire
#
#
#
# Chunk 43:
# Au sens du présent cahier des clauses administratives particulières (CCAP) et des différents documents
# particuliers du marché, les termes mentionnés ci-après sont définis comme suit :
# Pouvoir adjudicateur Acheteur public soumis à lordonnance n°2015-899 du 23 juillet 2015
# relative aux marchés publics.
#
#
# Chunk 44:
# Cest le cocontractant du titulaire.
#  Il sagit de la Direction du numérique, et des directions bénéficiaires en
# charge de la conclusion du marché pour chaque marché subséquent.
#
#
#
# Chunk 45:
# Département ministériel Partie, secteur de l'administration, constituant un ensemble spécialisé et
# autonome, attribué à un ministre.
# Service bénéficiaire Toutes les Directions des Ministères sociaux.
#
#
# Chunk 46:
# Les services bénéficiaires
# émettent directement leurs bons de commande et concluent leurs marchés
# subséquents.
#  DFAS
#
#
# Chunk 47:
# Direction des finances, des achats et des services
#  DNUM
#
#
# Chunk 48:
# Direction du numérique
#  DGCS
#
#
# Chunk 49:
# Direction Générale de la cohésion sociale
#  DGEFP
#
#
# Chunk 50:
# Délégation générale à l'emploi et à la formation professionnelle
#  MiTN Mission transformation numérique
# ARS
#
#
# Chunk 51:
# Agences régionales de santé
#  DGS
#
#
# Chunk 52:
# Direction Générale de la Santé
#  DGOS Direction Générale de l'Offre de Soins
#
#
#
# Chunk 53:
# Titulaire Opérateur économique signataire du marché
# Délais Sexpriment en jours calendaires, sauf mention contraire.
# CCAP Cahier des Clauses Administratives Particulières
#
#
#
# Chunk 54:
# RH Ressources Humaines
# Mission
#
#
# Chunk 55:
# Prestation réalisée sur la base dun ou plusieurs bons de commande ou dun
# marché subséquent en vue datteindre lobjectif cible défini par le pouvoir
# adjudicateur.
#
# CCAP BPM060225_DATAVAL BPM060225
# 7/48
# Article 1
#
#
# Chunk 56:
# PREAMBULE- CONTEXTE
#  Les ministères sociaux sont engagés dans une démarche de promotion de la diversité et de légalité
# Professionnelle entre les femmes et les hommes.
#
#
#
# Chunk 57:
# A ce titre, ils sont attentifs dans le choix de leurs contractants comme dans la réalisation des prestations, au
# respect des dispositions législatives et réglementaires en la matière.
#  Au-delà du respect de ces dispositions, les ministères sociaux sont également sensibles aux actions conduites
# par leurs prestataires dans ce domaine au sein de leur entreprise.
# Dans ce cadre, un questionnaire relatif aux actions conduites en matière de diversité et dégalité
# professionnelle entre les femmes et les hommes sera envoyé à la (aux) société(s) retenue(s) dans les jours
# suivant la notification du marché.
#
#
#
# Chunk 58:
# Ce questionnaire devra être complété et renvoyé dans le mois suivant sa réception à ladresse suivante :
# Ministères sociaux
# Direction des finances, des achats et des services
# Sous-direction des achats et du développement durable
# 78-84, rue Olivier-de-Serres CS 59234
# 75739 PARIS cedex
# ou par courriel à :
# DFAS-DADD-RESEAU-ACHAT@sg.social.gouv.fr
# Article 2 DISPOSITIONS RELATIVES A LACCORD-CADRE
# 2.1 OBJET DE LACCORD-CADRE
#
#
#
# Chunk 59:
# Le présent marché a pour objet les prestations nécessaires à la valorisation et au traitement des données des
# directions et délégations de ladministration centrale des ministères sociaux. Elle permet lachat de prestations
# de gouvernance et de cadrage de projets décisionnels, de modélisation et de création de bases de données,
# de chargement et mise en qualité des données, de traitements (croisement de sources de données, calculs
# dagrégats, traitements algorithmiques) et de mise à disposition des données (Business intelligence,
# datavisualisation).
#
#
#
# Chunk 60:
# Le périmètre technologique des projets concernés par ce marché correspond à lensemble des technologies
# et plateformes de traitement des données présentes aux ministères sociaux. Et quid pour lavenir ?
#
#
#
# Chunk 61:
# Ce marché ninclut pas lacquisition de progiciels.
#  Le présent marché est un marché de service.
# Codes CPV de la consultation : 72500000-0
#
#
# Chunk 62:
# - Services informatiques.
# 2.2 IDENTIFICATION DES ELEMENTS SOUMIS AU DROIT DE LA PROPRIETE INTELLECTUELLE
#
#
#
# Chunk 63:
# Les éléments soumis au droit de la propriété intellectuelle sont lensemble des livrables cités dans le CCTP
# aux articles 5, 6 (lot 1), 7 (lot 2), 8 (lot 3) et 9 (lot 4).
#
#  CCAP BPM060225_DATAVAL BPM060225
# 8/48 2.3 PERIMETRE DE LACCORD-CADRE
#
#
#
# Chunk 64:
# Les bénéficiaires du présent marché sont toutes les directions et services dadministration centrale des
# ministères sociaux.
#  La maîtrise dœuvre (MOE) en charge de la définition, de la commande et du pilotage des prestations de
# maintenance et de développement est la Direction du Numérique (DNUM).
#
#
#
# Chunk 65:
# Certaines directions disposant de leurs propres ressources pour la conduite et le pilotage des projets
# informatiques peuvent toutefois être aussi MOE. Dans ce cas, ces directions utilisant directement un des lots,
# sont responsables de lensemble des prestations quelles commandent.
#
#
# Chunk 66:
# Elles gèrent en autonomie le côté
# opérationnel depuis la validation des devis, jusquà lémission des PV de SF en passant par toutes les phases
# intermédiaires.
# La gouvernance générale du marché est réalisée par la Direction du numérique des ministères sociaux
# (DNUM). Les directions, utilisant un des lots, participent aux instances de pilotage du marché et se conforment
# à lensemble des procédures du marché, notamment la règle dattribution des projets.
#
#
# Chunk 67:
# Pour les lots multi-
# attributaires, la règle du « tour de rôle » est centralisée pour toutes les directions.
#  Le présent marché, conclu par le pouvoir adjudicateur représenté par la Direction du numérique (DNUM) des
# Ministères Sociaux est ouvert à lensemble des services relevant du périmètre budgétaire des Ministères
# Sociaux, qui peuvent émettre des bons de commande pour leur besoin propre.
#
#
#
# Chunk 68:
# Le périmètre du présent marché comprend lensemble des systèmes dinformation data des Directions
# dadministration centrale des ministères sociaux. Ce périmètre a vocation à senrichir au fur et à mesure de
# lexécution du présent marché.
#
#
#
# Chunk 69:
# Il comprend notamment :
#  Le système dinformation décisionnel de la DGEFP
#   La base connaissance entreprise (BCE) de la MiTN (DNUM)
#
#
#
# Chunk 70:
# Le SI MANDOLINE Décisionnel de la DGCS
#   Le SI DIAMANT du SCN SI des ARS (DNUM)
#
#
#
# Chunk 71:
# Le SI PILO360 de la DGOS
#   Le SI Aqua
#
#
# Chunk 72:
# - Sise de la DGS
#
#
#
# Chunk 73:
# Lensemble des réalisations BI des Directions des ministères sociaux
#   Lensemble des tableaux de bord des Directions des ministères sociaux
# A noter que la cartographie (au sens Système dInformation Géographique) est exclue du périmètre du présent
# marché, sauf quand elle est accessoire et peut être prise en charge dans les outils de production de rapports
# ou de Dataviz
# La maîtrise dœuvre (MOE) en charge de la définition, de la commande et du pilotage des prestations de
# maintenance et de développement est la Direction du NUMérique (DNUM), utilisatrice majoritaire du marché.
#
#
#
# Chunk 74:
# Certaines directions disposant de leurs propres ressources pour la conduite et le pilotage des projets
# informatiques peuvent toutefois être aussi MOE. Dans ce cas, ces directions utilisant directement un des lots,
# sont responsables de lensemble des prestations quelles commandent.
#
#
# Chunk 75:
# Elles gèrent en autonomie le côté
# opérationnel depuis la validation des devis, jusquà lémission des PV de SF en passant par toutes les phases
# intermédiaires.
# La gouvernance générale du marché est réalisée au niveau de la DNUM. Les directions, utilisant un des lots,
# participent aux instances de pilotage du marché et se conforment à lensemble des procédures du marché,
# notamment la règle dattribution des projets.
#
#
# Chunk 76:
# Pour les lots multi-attributaires, la règle du « tour de rôle» est
# centralisée pour toutes les directions.
#
#  CCAP BPM060225_DATAVAL BPM060225
# 9/48
# 2.4
#
#
# Chunk 77:
# ALLOTISSEMENT
# Laccord-cadre est multi attributaire et alloti en 4 lots de la manière suivante :
# Nom des lots Perimetre Nombre
# dattributaires
# maximum
# Lot 1
# Gouvernance de la donnée
#
#
# Chunk 78:
# Définition dune
#
#
# Chunk 79:
# stratégie de
# valorisation de la donnée
#   Définition du volet fonctionnel
#
#
#
# Chunk 80:
# Définition du volet technique
# 2
# Lot 2
# Informatique décisionnelle BI et
# Dataviz Cadrage et specification du besoin
#  Collecte et mise en qualité des
# données
#  Modélisation et réalisation de
# lentrepôt de données
#   Chargement des données et
# automatisation
#
#
#
# Chunk 81:
# Restitution des données
# 3
# Lot 3
# Data science et Intelligence
# artificielle Cadrage et spécification du besoin
#   Collecte et mise en qualité des
# données
#
#
#
# Chunk 82:
# Traitement algorithmique
#   Restitution des données
# 2
# Lot 4
#
#
#
# Chunk 83:
# Prestations daccompagnement à
# la valorisation des données Assistance à maîtrise dœuvre de
# projets data
#  Expertise technique
# 1
# Les soumissionnaires sont libres de présenter une offre pour chacun des lots. Cependant il existe une règle
# dexclusivité dattribution entre le lot 4 et les autres lots :
#
#
#
# Chunk 84:
# - Les lots 1, 2 et 3 peuvent être attribués aux mêmes soumissionnaires ;
#  - Le lot 4 est exclusif des autres lots, il ne peut être attribué quà un seul titulaire autre que ceux retenus
# sur les lots 1,2 et 3.
#
#
#
# Chunk 85:
# Le soumissionnaire précise donc, dans le document non-contractuel « ordre de préférence dattribution des
# lots » (annexe 1 au RC), son ordre de préférence dattribution entre le lot 4 et les lots 1, 2 et 3. Ce document
# est remis au moment du dépôt de loffre.
#
# CCAP BPM060225_DATAVAL BPM060225
# 10/48 2.5 PROCEDURE DE PASSATION
#
#
#
# Chunk 86:
# Le présent accord-cadre est un marché de services, passé selon une procédure dappel doffres ouvert en
# application des articles L2124-1, L2124-2, R2124-2 et R2161-2 à R2161-5 du Code de la commande publique.
# 2.6 FORME ET ETENDUE DE LACCORD-CADRE
#  Il sagit dun accord-cadre mixte, qui sexécute par lémission de bons de commande et à marchés
# subséquents, sans montant minimum mais avec un maximum de 126 000 000 HT sur la durée totale du
# marché (reconductions comprises), en application des articles R2162-2, R2162-13 et R2162-14 du code de la
# commande publique.
#
#
#
# Chunk 87:
# Le montant maximum indiqué ne correspond pas à un engagement de commandes.
# Pour chaque lot, celui-ci cessera automatiquement de produire ses effets et deviendra caduc si ce montant
# maximum est atteint. La fin du lot produite par l'atteinte du montant maximum sapplique quelle que soit la
# durée du lot prévue initialement.
# laccord-cadre est conclu à compter de sa date de notification pour une période initiale de 2 ans ferme, sauf si
# le montant maximum est atteint avant cette échéance, il sera ensuite reconductible 2 fois pour une durée pour
# une durée de 1 an s au plus tôt, à compter de la date à laquelle le montant maximum est atteint ou au plus
# tard au terme dun délai de :
#
#
#
# Chunk 88:
# - 2 ans mois à compter de sa date de notification pour la période ferme,
# - 1 an à compter de sa date de reconduction pour les périodes suivantes.
#  Sans que sa durée totale (toutes reconductions comprises) ne puisse excéder 4 ans
#
#
#
# Chunk 89:
# 2.6.1 Forme de chaque lot
# Chaque lot de laccord-cadre est multi-attributaires sauf le lot4 qui est mono-attributaire
#
#
#
# Chunk 90:
# Le présent document est commun à l'ensemble des lots. Pour chacun des lots, laccord-cadre est exécuté en
# partie par lémission de bons de commande et une partie donne lieu à la conclusion de marchés subséquents.
#
#
#
# Chunk 91:
# - Chaque lot est conclu sans minimum mais avec un maximum qui se décompose comme suit :
# Année 1 & Année 2 Année 3
#
#
# Chunk 92:
# Année 4 Total
# Lot 1 12 M 6 M 6 M 24 M
# Lot 2 36 M 18 M 18 M 72 M
#
#
#
# Chunk 93:
# Lot 3 9 M 4,5 M 4,5 M 18 M
#
#
#
# Chunk 94:
# Lot 4 6M 3 M 3 M 12 M
#
#
#
# Chunk 95:
# - Lestimation pour toute la durée du marché est de 42 M HT qui se répartissent comme suit :
#  Lot 1 : 8 M HT
#
#
#
# Chunk 96:
# Lot 2 : 24 M HT
#
#
#
# Chunk 97:
# Lot 3 : 6 M HT
#
#
#
# Chunk 98:
# Lot 4 : 4 M HT
#
# CCAP BPM060225_DATAVAL BPM060225
# 11/48 2.6.2
#
#
# Chunk 99:
# Etendue de laccord- cadre
# Partie à bons de commande
# Pour chacun des lots, la partie à bons de commande de laccord cadre concerne les prestations attendues,
# chacune de ces unités dœuvre fait lobjet
#
#
# Chunk 100:
# dune évaluation de charge ventilée par profil permettant de la
# chiffrer dans lannexe financière.
# Pour des prestations spécifiques du fait de leur nature
#
#
# Chunk 101:
# , leur complexité, ou leur importance, chaque service
# bénéficiaire pourra conclure des marchés subséquents.
#  Partie à marchés subséquents
# Dans le cas où la complexité des prestations envisagées ne seraient pas réalisables dans le cadre dun bon
# de commande, il est prévu de procéder via un marché subséquent.
#
#
#
# Chunk 102:
# Les cas envisageables pour la mise en œuvre de cette procédure pour lensemble des lots sont les suivants :
#  Nécessité dapporter des compléments ou des adaptations nécessaires au recours à une méthode de
# conduite de projet (les méthodes cycles en V, incrémentales ou mode agiles)
#  Nécessité dadaptation de la gouvernance du lot telle que, la phase dinitialisation sur un projet
# spécifique.
#  Pour des prestations spécifiques du fait de leur nature, leur complexité, ou leur importance, chaque
# service bénéficiaire pourra conclure des marchés subséquents permettant de préciser les
# caractéristiques et les modalités d'exécution des prestations demandées.
# Les marchés subséquents seront conclus sous la forme daccord-cadre à bons de commande, sur la base des
# Unités dœuvre à prix plafond décrites dans le BPU de chaque lot.
# Dans tous les autres cas on procèdera par simple bon de commande.
# 2.7 DOCUMENTS CONTRACTUELS DE LACCORD-
#
#
# Chunk 103:
# CADRE
#  Les pièces constitutives de laccord-cadre sont, par ordre de priorité décroissante :
#  Lacte dengagement et son annexe financière comprenant selon les lots, plusieurs onglets
# (BPU, charges et profils) ;
#  Le présent cahier des clauses administratives ;
#
#
#
# Chunk 104:
# Le cahier des clauses techniques particulières et ses annexes :
#  Annexe1 Glossaire
#  Annexe1 Glossaire
#  Annexe2 Profils métier nécessaires pour les prestations
#  Annexe 3 : Cadre de la sécurité :
# 1) Référentiel Général de Sécurité, version 2.0 (Dataval - RGS_v-2-
# 0_Corps_du_texte.pdf) ;
# 2) Politique de Sécurité des Systèmes dInformation des Ministères Sociaux
# (Dataval PSSI_MCAS_approuvée.pdf) ;
# 3)
#
#
# Chunk 105:
# Guide dhomologation RGS (
#
#
# Chunk 106:
# Dataval
# Homologation_securite_en_9_etapes.pdf) ;
# 4)
#
#
# Chunk 107:
# Plan assurance sécurité (Dataval Plan-Assurance v0.1.doc)
# 5) Engagement de confidentialité du titulaire (Dataval EIC.docx)
# 6)
#
#
# Chunk 108:
# Charte Sécurité applicable aux agents et prestataires (Dataval Charte Accès
# aux traces et copies.docx)
#
#
# Chunk 109:
# .
#   Annexe 4 :
#
#
# Chunk 110:
# Cadre de laccessibilité
# Référentiel Général de lAmélioration de lAccessibilité (Dataval RGAA
# -v4.1.pdf)
#  Circulaire relative à la lisibilité des sites internet de l'État et de la qualité des
#
# CCAP BPM060225_DATAVAL BPM060225
#
#
#
# Chunk 111:
# 12/48 démarches numériques (DATAVAL - Circulaire_6411-SG.pdf
#
#
# Chunk 112:
# )
#   Annexe 5 :
#
#
# Chunk 113:
# Cadre de léco-conception
# Référentiel Général décoconception de services numériques (Dataval rgesn-
# referentiel-general-ecoconception-v1.0.1.pdf)
#  Annexe 6 fiche de livraison
#   Le cahier des clauses administratives générales applicables aux marchés publics de
# techniques de linformation et de la communication approuvé par larrêté du 30 mars 2021 ;
#
#
#
# Chunk 114:
# Loffre technique du titulaire et ses éventuelles annexes dont la méthode dévaluation des
# charges,
#  Le plan dassurance securité (PAS) fondé sur le fichier sécurité complété
#   Le plan dassurance qualité (PAQ) ;
#
#
#
# Chunk 115:
# Les actes spéciaux de sous-traitance et leurs avenants postérieurs à la notification de
# laccord-cadre ;
#   Un accord de confidentialité, dengagement et de déclaration de reconnaissance des règles
# de discrétion, de confidentialité et de sécurité informatique.
# 2.8 REPRESENTATION DES PARTIES DE LACCORD-CADRE
#
#
#
# Chunk 116:
# 2.8.1 Représentation du pouvoir adjudicateur
# Dès la notification du marché, lacheteur désigne une ou plusieurs personnes physiques, habilitées à le
# représenter auprès du titulaire, pour les besoins de lexécution du marché.
#
#
#
# Chunk 117:
# Dautres personnes physiques peuvent être habilitées par lacheteur en cours dexécution du marché.
#  Lacheteur notifie toute modification de(s) interlocuteur(s) désignés au titulaire.
#
#
#
# Chunk 118:
# 2.8.2 Représentation du titulaire
#
#
#
# Chunk 119:
# Le titulaire désigne un ou plusieurs interlocuteurs, habilités à le représenter auprès de lacheteur, pour les
# besoins de lexécution de laccord-cadre. Cet ou ces interlocuteurs sont désignés dès la notification du marché.
#
#
#
# Chunk 120:
# Le titulaire sengage à informer dans un délai de 5 jour ouvré, lacheteur de toute modification dinterlocuteur
# désigné.
# 2.9 DUREE DE LACCORD-CADRE
# 2.9.1 Cadre général
# Chaque lot est conclu pour une durée de 2 ans fermes.
#
#
#
# Chunk 121:
# La durée de chaque lot court à compter de sa date de notification.
# 2.9.2 Reconduction de laccord-cadre
# Chaque lot peut être reconduit 2 fois par période de 12 mois chacune au plus tôt à compter de la date à
# laquelle le montant maximum est atteint, ou au plus tard au terme d'un délai dun an à compter de sa date
# de notification ou de sa reconduction, le cas échéant.
#
#
# Chunk 122:
# La durée totale, reconductions comprises,
# nexcédera pas quatre ans.
# Dans l'hypothèse où l'accord-cadre ne serait pas reconduit, les bons de commande émis et les marchés
# subséquents conclus continuent à s'exécuter jusqu'à leur terme dans les conditions définies aux articles 3.2
# et 4.3 du présent CCAP.
#
# CCAP BPM060225_DATAVAL BPM060225
# 13/48 2.10 LIEU DEXECUTION
#
#
#
# Chunk 123:
# Les prestations s'exécuteront principalement dans les locaux du titulaire.
#  Des réunions de travail pourront avoir lieu dans les locaux des services bénéficiaires.
# 2.11 FORME DES NOTIFICATIONS ET DES INFORMATIONS
# Le service bénéficiaire notifie au titulaire les décisions ou informations qui font courir un délai, par tous moyens
# permettant dattester la date de réception.
# 2.12 RESPONSABILITE DU TITULAIRE
#
#
#
# Chunk 124:
# Le titulaire est tenu de mettre en œuvre, dans le cadre des missions qui lui sont confiées, tous les procédés
# et moyens lui permettant de réaliser les prestations conformément aux spécifications du cahier des charges.
# Pour les prestations qui lui incombent, le titulaire doit strictement respecter les délais, les coûts et les niveaux
# de qualité prévus dans les documents contractuels régissant le marché. Les prestations devront être
# conformes aux prescriptions de l'ensemble des normes homologuées ou à toute norme européenne
# équivalente.
#
#
# Chunk 125:
# Cette disposition vaut non seulement pour les normes en vigueur au jour de la passation du
# marché mais également pour toutes les nouvelles normes qui deviendraient effectives en cours d'exécution
# du marché.
#  Le titulaire reconnaît l'importance cruciale de l'intégration éthique et responsable de l'intelligence artificielle
# (IA) dans ses activités.
#
#
# Chunk 126:
# Dans cette optique, il s'engage fermement à respecter des principes de
# développements responsables des technologies basée sur l'IA et à évoluer constamment pour répondre aux
# défis éthiques émergents dans ce domaine en rapide évolution.
# 2.13 OBLIGATIONS DU TITULAIRE
# 2.13.1 Obligation de conseil
# Le titulaire du marché est tenu à une obligation permanente de conseil et de mise en garde, relative aux
# matériels, logiciels et prestations fournies à lacheteur. Il est tenu de signaler à lacheteur tous les éléments
# qui lui paraissent de nature à compromettre la bonne exécution des prestations.
# Dans ce cadre, le titulaire notifie à lacheteur toute information permettant daméliorer le niveau de sécurité du
# système dinformation et signaler les difficultés et risques que certains choix peuvent entraîner.
#
#
# Chunk 127:
# Dans
# lhypothèse où le titulaire ne respecte pas cette obligation, il ne peut se prévaloir dune incohérence dans le
# marché pour sexonérer de ses obligations contractuelles.
#  Le titulaire a un devoir dalerte sil se rend compte, lors de ses interventions, de dérèglements, de
# dysfonctionnements ou de dangers potentiels au titre de ses prestations.
#
#
#
# Chunk 128:
# Ce devoir de conseil et dalerte est formel et fondé sur la production dun rapport qui décrit les risques et
# menaces et propose des actions pour les réduire.
#
#
#
# Chunk 129:
# Dans lhypothèse où le titulaire ne respecte pas cette obligation, il ne saurait se prévaloir dune incohérence
# dans le marché pour sexonérer de ses obligations contractuelles.
#
#
#
# Chunk 130:
# 2.13.2 Obligation dinformation
# Le titulaire est tenu de signaler au service bénéficiaire tous les éléments qui lui paraissent de nature à
# compromettre la bonne exécution de la prestation.
#
#  CCAP BPM060225_DATAVAL BPM060225
# 14/48 2.12.3
#
#
# Chunk 131:
# Informations sur les vulnérabilités et les incidents de sécurité détectés sur le système
# dinformation du titulaire (développement, MCO, MCS, etc.)
# Pour les prestations, produits et services fournis dans le cadre du marché, le titulaire met à disposition un
# dispositif dinformation dédié à la sécurité informatique (notamment flux RSS/ATOM, liste diffusion par courriel
# ou autre).
#  Ce dispositif vise à tenir lacheteur informé des événements et changements impactant la sécurité, notamment
# liés à la connaissance dune vulnérabilité impactant le système (annonce de correctif, attaque en cours,
# violation de données à caractère personnel si le traitement de données est sous-traité au titulaire), et des
# mesures correctives ou conservatoires à appliquer.
# 2.13.3 Obligation de confidentialité
# Par dérogation à l'article 5.1.1 du CCAG-TIC, une information confidentielle désigne toute information de
# quelque nature (y inclus la méthodologie, la documentation, les informations ou le savoir-faire), sous quelque
# forme que ce soit (y inclus sous forme orale, écrite, magnétique ou électronique), sur tout support dont le
# ministère est propriétaire ou titulaire, et qui est communiquée au titulaire, ou obtenue de toute autre façon par
# ce dernier dans le cadre de ses relations avec le ministère.
#
#
# Chunk 132:
# Le titulaire et son personnel, et le cas échéant ses
# sous-traitants, ne peut lutiliser que pour laccomplissement des prestations prévues au marché.
# Toutefois, nest pas considérée confidentielle toute information :
#  qui était dans le domaine public au moment de sa divulgation ou que le ministère aurait lui-même
# rendue publique pendant lexécution du marché ;
#  signalée comme présentant un caractère non confidentiel et relative aux prestations du marché ;
#  qui a été communiquée au titulaire du marché par un tiers ayant légalement le droit de diffuser cette
# information, comme le prouvent des documents existant antérieurement à sa divulgation par le
# ministère.
#  Les informations sensibles et celles de niveau
#
#
# Chunk 133:
# Diffusion Restreinte (DR)
#
#
# Chunk 134:
# doivent être protégées conformément
# à linstruction interministérielle n° 901 relative à la protection des systèmes dinformation sensibles.
#  En cas de manipulation dinformations classifiées de défense, le titulaire respecte linstruction générale
# interministérielle n° 1300 sur la protection du secret de la défense.
#
#
#
# Chunk 135:
# 2.13.4 Mesures de sécurité
# Toute personne relevant du titulaire ou de ses sous-traitants est soumise, le cas échéant, à des mesures de
# sécurité quil sagisse daccès physiques à des locaux ou daccès logiques à des informations.
# 2.13.5 Mise à disposition des documents relatifs aux politiques et procédures de sécurité
#
#
#
# Chunk 136:
# Le titulaire met à disposition de lacheteur lensemble des documents relatifs aux politiques et procédures de
# sécurité à la demande de lacheteur.
#  2.13.6 Maintien en condition de sécurité
#
#
#
# Chunk 137:
# Traitement des obsolescences
#  Le titulaire ne doit utiliser que des composants logiciels que léditeur sengage à maintenir pendant la durée
# du marché.
#
#
# Chunk 138:
# Si la durée du marché dépasse la durée pendant laquelle un éditeur sengage à maintenir un
# composant logiciel, le titulaire maintient, livre et respecte la feuille de route de migration vers des systèmes
# maintenus.
#
#  CCAP BPM060225_DATAVAL BPM060225
# 15/48 Correctifs de sécurité
#
#
#
# Chunk 139:
# Une vérification daptitude ou une vérification de service régulier (VA et VSR) peut être refusée si des
# composants ne sont pas à jour des correctifs de failles de sécurité.
#  Lacheteur définit les fréquences des livraisons en coordination avec les équipes dexploitation, en fonction
# des différentes criticités des vulnérabilités concernées.
#
#
#
# Chunk 140:
# Le titulaire sassure que lapplication des correctifs de sécurité ne modifie pas les performances du système,
# en modifiant si besoin et à ses frais le système pour maintenir le niveau de performance malgré lapplication
# du correctif.
#  2.13.7
#
#
# Chunk 141:
# Obligation de respect déontologique
#  Les intervenants des titulaires réalisent leurs prestations avec probité et intégrité.
#
#
#
# Chunk 142:
# Ils veillent à prévenir ou à faire cesser immédiatement tout conflit dintérêts, défini comme une situation
# dinterférence entre un intérêt public et des intérêts publics ou privés qui est de nature à influencer ou à paraître
# influencer lexercice indépendant, impartial et objectif de leur profession.
# Les titulaires et les bénéficiaires du présent accord-cadre sengagent à respecter toutes les mesures
# déontologiques applicables dans le cadre de lexécution des prestations.
#  Les intervenants doivent être à jour de leurs obligations déontologiques, notamment pour les anciens agents
# publics (autorisation de la commission de déontologie de ladministration dorigine ou autorisation de
# lemployeur soumise à approbation de ladministration bénéficiaire).
#
#
# Chunk 143:
# Au-delà des poursuites pénales
# applicables, ladministration peut être amenée à écarter du suivi du présent accord-cadre toute personne
# (titulaire ou bénéficiaire) ne respectant pas ces règles.
# Avant chaque mission, le titulaire, co-traitant ou sous-traitant complète lannexe n°1 du CCAP certifiant
# labsence de conflit dintérêt ou identifiant les potentiels conflits existants. Elle est communiquée à
# ladministration sans délai, pour tous les membres de léquipe mobilisée pour la réalisation des prestations.
#
#
#
# Chunk 144:
# Lannexe est également complétée par lentreprise en tant que personne morale. Cette déclaration est
# complétée quel que soit le statut de lentreprise mobilisée : mandataire, co-traitant ou sous-traitant.
#
#
#
# Chunk 145:
# Ladministration bénéficiaire pourra statuer sur les déclarations transmises et prendre les mesures idoines afin
# de faire cesser tout conflit dintérêt (demande de remplacement, mise en impossibilité dhonorer la commande,
# etc.).
#  En cas de modification substantielle des intérêts détenus au cours de la prestation, le prestataire et les
# consultants actualisent leur déclaration dans un délai de quinze jours et selon les mêmes modalités.
# Tout au long de l'exécution de l'accord-cadre
#
#
# Chunk 146:
# , le titulaire est tenu de déclarer sous sa responsabilité, à
# l'acheteur toute situation de nature à constituer un conflit d'intérêts.
# Les titulaires sengagent à ne pas proposer aux agents publics des récompenses en nature qui auraient pour
# conséquence le non-respect des principes déontologiques. Sont ainsi proscrits les comportements, actifs ou
# passifs, visant à bénéficier ou faire bénéficier dun avantage quelconque par le biais de récompense en nature
# (repas, invitation hors cadre professionnel, cadeaux individuels, etc.).
#
#
# Chunk 147:
# Toute action de démarchage ou
# invitation à des événements promotionnels de la part du titulaire auprès des bénéficiaires est prohibée.
#  Les actions de démarchage ou de prospection sont prohibées.
#
#
#
# Chunk 148:
# Les missions effectuées à titre gracieux (dites pro bono) au bénéfice des administrations publiques ne doivent
# donner lieu à aucune contrepartie. Toute mission pro-bono ou mécénat de compétence doit être autorisée par
# le secrétaire général du ministère concerné .
#
#
# Chunk 149:
# Aucun droit de suite ne peut être accordé au prestataire dune
# mission pro-bono.
#  En cas de conflit avéré, les prestations pourront être annulées avant le terme du bon de commande en cours.
#
#
#
# Chunk 150:
# Cette annulation entrainera uniquement le paiement des prestations réellement réalisées.
#  En cas de non-déclaration de conflit dintérêt ou de non-respect des obligations du présent article, des
# pénalités pourront être appliquées.
#
#
# Chunk 151:
# En cas de conflit dintérêt grave et répété, ou dabsence de déclaration, le
# marché pourra être résilié.
# 2.13.8 État de lart
# Le titulaire garantit à lacheteur quil est conforme à létat de lart pour les services et objets numériques fournis
# dans le cadre des prestations.
#
#
# Chunk 152:
# A première demande, le titulaire fournit la preuve de conformité. Il précise alors
# les domaines concernés (interfaces web et courriels), les objets et bases dinformation concernées (appareils
#
# CCAP BPM060225_DATAVAL BPM060225
# 16/48 connectés, sauvegardes de données, consoles dadministration).
#
#
# Chunk 153:
# Le CCTP décrit les exigences que le titulaire
# doit respecter pour chaque service ou produit.
#  2.13.9 Initialisation
#
#
# Chunk 154:
# , Réversibilité et Transférabilité
#  Le titulaire met en œuvre des mesures techniques et organisationnelles pour garantir la sécurité des données
# et des applications qui lui sont confiées, lors du transfert des prestations de la part du précédent titulaire en
# conformité avec les réglementations applicables.
# Durant la phase de transfert, lassurance de la sécurité réside notamment dans
#  La gestion des accès, habilitations ;
#
#
#
# Chunk 155:
# Le transfert de responsabilité ;
#   La fourniture dinformations nécessitant des mesures de protection adaptées
#  La gestion de la continuité de lactivité.
# 2.14 PRIX DE LACCORD-CADRE ET DES MARCHES SUBSEQUENTS
# 2.14.1
#
#
# Chunk 156:
# Forme et contenu des prix de la partie à bons de commande de laccord-cadre
# Les prestations seront rémunérées suivant la forme de prix suivante :
# Numéro
# du lot Forme de
# prix Bon de
# commandes /
# Quantité
# définie Type de prix
# unitaire Minimum (EUR HT) /
# Maximum (EUR HT) Variation(s) de
# prix
# 1 Prix
# unitaires BdC BPU Min : sans / Max : 24
# M Révisables
# 2 Prix
# Unitaires BdC BPU Min : sans / Max : 72 Révisables
# 3 Prix
# unitaires BdC BPU Min : sans / Max : 18
# M Révisables
# 4 Prix
#  Unitaires
#
#
# Chunk 157:
# BdC BPU Min :
#
#
# Chunk 158:
# sans / Max : 12
# M Révisables
# Dans le tableau ci-dessus :
# « BPU » = « bordereau des prix unitaires »,
# «
#
#
# Chunk 159:
# BdC » = « bons de commande »
# Les prix unitaires figurent dans le bordereau de prix unitaires (onglet 1) annexé à l'acte d'engagement.
#
#
#
# Chunk 160:
# Les prix sont réputés inclure :
# - les frais afférents à la réalisation des prestations,
#  - tous les frais annexes et les matériels nécessaires à l'exécution des prestations ;
#
#
#
# Chunk 161:
# - toutes les charges fiscales, parafiscales ou autres applicables aux prestations.
#  - les frais de déplacement
# 2.14.2
#
#
# Chunk 162:
# Révision des prix de la partie à bons de commande de laccord-cadre
# Par dérogation à larticle 10.2.4 du CCAG de références, les prix sont établis sur la base des conditions
# économiques en vigueur au mois M0 correspondant au mois de la date limite de remise des offres.
#
# CCAP BPM060225_DATAVAL BPM060225
# 17/48 Ils sont fermes pour la période initiale de 12 mois. Ils sont par la suite révisés à la demande du titulaire.
#
#
#
# Chunk 163:
# Cette demande est transmise au pouvoir adjudicateur au plus tard quinze jours après la date
# anniversaire de la notification du marché.
#  En cas dabsence de demande par le titulaire dans un délai de quinze jours après la date anniversaire,
# la révision ne pourra avoir lieu.
#
#
# Chunk 164:
# Labsence de production par lordonnateur au comptable dun BPU
# révisé emportera signification tacite par lordonnateur que la clause de révision nest mise en jeu ni
# par le titulaire ni par le RPA.
#  Les prix initiaux sont révisables par référence à lindice du coût horaire du travail Tous salariés (ICHT,
# ICHTrev-TS) édité par lINSEE (www.insee.fr ; identifiant 001565196).
#
#
#
# Chunk 165:
# Le prix révisé (P) est obtenu par application de la formule suivante :
# P = P0 (Io / No)
# Dans laquelle :
# P = Prix révisé
#
#
# Chunk 166:
# H.T.V.A.
# P0 = Prix de loffre H.T.V.A.
#  Io = Valeur du dernier indice définitif connu et lu à la date anniversaire de notification de laccord-
# cadre.
#
#
#
# Chunk 167:
# No = Valeur de ce même indice diffusé au titre du mois dans lequel est incluse la date limite de dépôt
# de la dernière offre.
#  Si laccord
#
#
# Chunk 168:
# -cadre est reconduit, il revient au titulaire de soumettre au RPA le nouveau prix révisé ainsi
# que le détail du calcul de celui-ci, conformément à la formule ci-dessus, dans un délai de deux
# semaines après la date anniversaire de laccord-cadre (N+2) et (N+3).
#  Modification d'un indice
# En cas de changement par l'INSEE (ou par un organisme habilité) de la dénomination et/ou de la base
# de calcul d'un indice avec ou sans coefficient de raccordement associé, ce changement s'applique
# automatiquement et sans formalités.
#
#
#
# Chunk 169:
# En cas de suppression par l'INSEE (ou par un organisme habilité) d'un indice et de son remplacement
# par un autre indice avec ou sans coefficient de raccordement associé, ce remplacement sera notifié
# par courrier au titulaire par le ministère porteur.
#  Le titulaire disposera dun délai de 21 jour calendaire pour formuler par écrit son éventuel désaccord.
#
#
#
# Chunk 170:
# Passé ce délai, l'absence de réponse de celui-ci vaudra acceptation du nouvel indice.
#  En cas de désaccord exprimé dans le délai ci-dessus, les parties devront trouver un accord par avenant.
#
#
#
# Chunk 171:
# Les prix révisés ne sappliqueront que sur les bons de commande notifiés après la date de révision de la
# période en cours
# Par
# Clause butoir : lévolution du prix de règlement résultant de lapplication de la référence dajustement ne peut
# en aucun cas conduire à une augmentation supérieure à 5% entre deux reconductions successives.
# Eventuellement, afin de pouvoir vérifier le respect de la clause butoir au moment des ajustements de prix, le
# détail estimatif daide à la décision (qui sert à lanalyse des offres) sera calculé avec les prix du nouveau
# document de référence et comparé au détail estimatif daide à la décision initial ou de la reconduction n-1.
#
# CCAP BPM060225_DATAVAL BPM060225
# 18/48
# 2.14.3 Etablissement des prix plafonds de laccord-cadre pour les marchés subséquents
# Les prestations seront rémunérées suivant la forme de prix suivante :
# Numéro
# du lot Forme de prix Bon de
# commandes
# / Quantité
# définie Type de prix
# unitaire Minimum (EUR HT) /
# Maximum (EUR HT) Variation(s) de
# prix
# 1 Prix unitaires BdC BPU Min : sans / Max : 24
# M Révisables
# 2 Prix
#
#
# Chunk 172:
# Unitaires BdC BPU Min : sans / Max : 72 Révisables
# 3 Prix unitaires BdC BPU Min : sans / Max : 18
# M Révisables
# Dans le tableau ci-dessus :
# « BPU » = « bordereau des prix unitaires »,
# «
#
#
# Chunk 173:
# BdC » = « bons de commande »
# Pour chacun des lots, les marchés subséquents seront conclus à prix unitaires. Les prix des marchés
# subséquents seront inférieurs ou égaux aux prix plafonds de l'accord-cadre.
#
#
#
# Chunk 174:
# Les prix sont réputés inclure :
# - les frais afférents à la réalisation des prestations,
#  - tous les frais annexes et les matériels nécessaires à l'exécution des prestations ;
#
#
#
# Chunk 175:
# - toutes les charges fiscales, parafiscales ou autres applicables aux prestations.
# 2.14.4 Révision des prix plafonds de laccord-cadre
#
#
#
# Chunk 176:
# Les prix plafonds sont établis sur la base des conditions économiques en vigueur au mois M0 correspondant
# au mois de la date limite de remise des offres.
#  En cas de marché subséquent dune durée supérieure à 2 ans
#
#
# Chunk 177:
# , une révision des prix est appliquée dans les
# conditions de larticle 2.14.2 du présent CCAP.
#  Article 3 MODALITES
#
#
# Chunk 178:
# DEXECUTION DES PRESTATIONS DE LACCORD -
#
#
# Chunk 179:
# CADRE RELEVANT DE
# LEMISSION DE BONS DE COMMANDE
# 3.1 EMISSION ET EXECUTION DES BONS DE COMMANDE
#  Les bons de commande sont émis par chaque service bénéficiaire et sont notifiés par tout moyen permettant
# d'en accuser date de réception certaine.
#
#
#
# Chunk 180:
# Le point de départ du délai dexécution du bon de commande est la date de sa notification ou à la date de
# début dexécution des prestations si celle-ci est précisée dans le bon de commande
# Conformément aux dispositions de larticle R. 2162-14 du code de la commande publique, lémission des bons
# de commande seffectue sans négociation ni remise en concurrence préalable des titulaires du lot considéré.
#
# CCAP BPM060225_DATAVAL BPM060225
# 19/48 Lattribution des bons de commande dans le cadre du présent accord-cadre seffectuera de la manière
# suivante pour chacun des lots multi attributaires (1,2et 3) :
# Attribution à tour de rôle : sous réserve de lexception indiquée ci-après, les bons de commande sont
# attribués à tour de rôle, selon lordre de classement des offres obtenu lors de la mise en concurrence initiale.
#
#
#
# Chunk 181:
# Ainsi, le premier bon de commande est notifié au candidat dont loffre est arrivée en première position du
# classement lors de la procédure dappel doffres de laccord-cadre, le deuxième bon de commande est attribué
# au candidat dont loffre est arrivée en deuxième position et ainsi de suite, le roulement reprenant au début une
# fois lensemble des titulaires sollicités.
#  La mise en place dun marché subséquent sur des prestations spécifiques du fait de leur nature, leur
# complexité, ou leur importance naltère en rien la règle de roulement du tourniquet.
#
#
#
# Chunk 182:
# Droit de suite : lorsquun bon de commande a pour objet de permettre la continuité dune même mission, il
# est attribué au titulaire qui a effectué le début de la mission. Exemple : mise en œuvre dun schéma cible
# élaboré dans le cadre dune commande précédente.
#
#
#
# Chunk 183:
# Exception au droit de suite : En cas dapplication de pénalités (pénalité de retard ou pénalité qualitative) lors
# de lexécution des prestations relatives à la première mission confiée au titulaire, ladministration se laisse la
# possibilité de ne pas faire droit au droit de suite et de facto dattribuer le bon de commande idoine en appliquant
# la règle du tour de rôle.
#
#
#
# Chunk 184:
# Incapacité de réaliser la prestation ou délai irraisonnable pour répondre à la demande de devis de
# ladministration : le prestataire , peut par voie écrite déclarer son impossibilité de réaliser la prestation, lorsque
# ladministration le sollicite dans le cadre du tour de rôle.
#
#
# Chunk 185:
# Cette déclaration doit obligatoirement intervenir au
# maximum 7 jours après que ladministration lai sollicité. Dans ce cas ladministration se réserve la possibilité
# de passer au titulaire suivant selon lordre du tourniquet.
#
#
#
# Chunk 186:
# Il en va de même lorsque le titulaire sollicité ne répond pas à la demande de ladministration relative à la
# remise dun devis dans un délai raisonnable, dans pareil cas ladministration alerte le titulaire en lui laissant
# un nouveau délai de réponse. En cas dabsence de réponse du titulaire pressenti, ladministration se réserve
# le droit de passer au titulaire suivant selon lordre du tourniquet.
#
#
#
# Chunk 187:
# La règle dattribution des bons de commande et sa gouvernance seront gérées par la DNUM.
#  Les directions, utilisant un des lots, participent aux instances de pilotage du marché et se conforment à
# lensemble des procédures du marché appliquées.
#
#
#
# Chunk 188:
# Chaque bon de commande
#
#
# Chunk 189:
# précise notamment :
#  - Le numéro et la date du bon de commande (correspondant au numéro de lengagement juridique
# nécessaire pour la transmission de la facture)
# - La date démission du bon de commande
#
#
#
# Chunk 190:
# - Le numéro de laccord-cadre
#  - Le code du service exécutant (ou le code didentification du service en charge du paiement
#
#
#
# Chunk 191:
# - La désignation et la quantité des prestations commandées
#  - Le prix correspondant hors taxes (HT) et toutes taxes comprises (TTC)
#
#
#
# Chunk 192:
# - Le montant total (HT et TTC) du bon de commande
# - La date de livraison prévisionnelle
# - Le délai dexécution de la prestation
# - La date de début dexécution du bon de commande le cas échéant
# - La date de fin dexécution du bon de commande
# - Les lieux dexécution des prestations
#  - La référence au devis
#
#
#
# Chunk 193:
# - Le nom de laccord-cadre
#  - La référence de laccord-cadre
#
# CCAP BPM060225_DATAVAL BPM060225
# 20/48
#
#
# Chunk 194:
# 3.2 DELAI DEXECUTION DES PRESTATIONS
#
#
#
# Chunk 195:
# Le point de départ du délai dexécution du bon de commande est la date de sa notification ou à la date de
# début dexécution des prestations si celle-ci est précisée dans le bon de commande.
# Lorsque le titulaire est mis dans l'impossibilité de respecter le délai contractuel figurant dans le bon de
# commande ou dans le marché subséquent, il doit formuler une demande expresse de report de délai exposant
# clairement les circonstances du retard prévu, la date de survenance du fait générateur et le délai
# supplémentaire demandé dans les conditions prévues au CCAG de référence. Cette demande peut être
# rejetée et ouvrir droit à sollicitation du prestataire suivant selon les règles du tourniquet.
#
#
#
# Chunk 196:
# Les bons de commande peuvent être émis jusquau dernier jour de validité de laccord-cadre en application
# de larticle R 2162-5 du code de la commande publique.
#
#
#
# Chunk 197:
# Les bons de commandes peuvent sexécuter jusquà maximum 6 mois après la fin du marché pour chaque
# lot.
#  La résiliation de l'accord-cadre ne remet pas en cause la validité du bon de commande émis avant la date
# d'effet de la décision de résiliation.
#
#
# Chunk 198:
# Le titulaire est tenu de respecter son engagement contractuel jusqu'à
# l'admission des prestations.
#  Article 4 MODALITES
#
#
# Chunk 199:
# DEXECUTION DES PRESTATIONS RELEVANT DE LA CONCLUSION DE
# MARCHES SUBSEQUENTS
# 4.1 LES PIECES CONSTITUTIVES DES MARCHES SUBSEQUENTS
#  Les pièces constitutives des marchés subséquents sont, pour chaque lot (1,2, et 3) et par ordre de priorité
# décroissante :
#  Les pièces contractuelles de laccord-cadre listées à larticle 2.6 dans le même ordre de priorité ;
#
#
#
# Chunk 200:
# Lacte d'engagement du marché subséquent et son annexe financière, le bordereau des prix
# unitaires ;
#   Le cas échéant, les actes spéciaux de sous-traitance et leurs avenants postérieurs à la notification
# des marchés ;
#  Loffre technique du titulaire pour le marché subséquent.
# 4.2 FORME DES MARCHES SUBSEQUENTS
# Chaque marché subséquent est conclu sous la forme d'un accord-cadre exécuté à bons de commande.
#
#
# Chunk 201:
# Les
# marchés subséquents seront mono-attributaires.
# 4.3 MODALITES DE PASSATION DES MARCHES SUBSEQUENTS
#  4.3.1
#
#
# ...
# a) Laccusé de réception de la déclaration de détachement effectuée sur le télé-service " SIPSI " du ministère
# chargé du travail, conformément aux articles R. 1263-5 et R. 1263-7 du code du travail ;
# b)
#
#
# Chunk 458:
# Une attestation sur lhonneur certifiant que le cocontractant sest, le cas échéant, acquitté du paiement des
# sommes dues au titre des amendes prévues aux articles L. 1263-6, L. 1264-1, L. 1264-2 et L. 8115-1 du code
# du travail. Cette attestation comporte les nom, prénom, raison sociale du cocontractant et la signature de son
# représentant légal.
# Dans les conditions fixées à larticle L.2196-4 et suivants du code de la commande publique, le titulaire fournit,
# si lacheteur en fait la demande, les renseignements sur les éléments techniques et comptables du coût de
# revient des prestations qui font lobjet du présent marché public (notamment bilans, comptes de résultat ainsi
# que leur comptabilité analytique et tout document de nature à permettre létablissement des coûts de revient).
# 5.18 RESILIATION
#
#
#
# Chunk 459:
# Lacheteur peut résilier le marché public dans les cas prévus aux articles L.2195-1 à L.2195-6 du code de la
# commande publique.
#  Laccord
#
#
# Chunk 460:
# - cadre peut être résilié conformément aux dispositions de larticle 8 du CCAG de référence (résiliation
# pour événements extérieurs ou liés au marché public, pour faute du titulaire ou pour motif dintérêt général).
#
#
#
# Chunk 461:
# En cas de résiliation pour motif dintérêt général et par dérogation à larticle 51 du CCAG TIC, le titulaire a droit
# à une indemnité de résiliation fondée sur les dépenses quil a engagées pour lexécution de laccord-cadre et
# qui nauraient pas été prises en compte dans le montant des prestations payées. La charge de la preuve pèse
# sur le prestataire et devra apporter lensemble des justificatifs idoines permettant au pouvoir adjudicateur de
# contrôler la réalité des dépenses engagées.
#
#
#
# Chunk 462:
# Une indemnisation de 5% du montant du dernier bons de commande non exécuté lui sera versée
# Au-delà des cas prévus au CCAG-TIC, le marché peut être résilié dans les cas suivants :
#  En cas d'inexactitude des documents et des renseignements prévus, ou de refus de produire
# les pièces prévues aux articles D8222-5 ou D8222-7 et D8222-8 du code du travail , l'accord-cadre
# sera résilié, après mise en demeure restée infructueuse, aux torts du titulaire selon les dispositions
# du CCAG de référence.
#  Pour inexactitude des renseignements communiqués. L'inexactitude des renseignements
# communiqués à l'appui des candidatures peut entraîner la résiliation de l'accord-cadre aux torts
# exclusifs du titulaire, sans indemnités.
#
#
#
# Chunk 463:
# Suite à une résiliation pour faute d'un marché subséquent. L'acheteur peut prononcer, sans
# préavis ni indemnité, la résiliation de l'accord-cadre à l'égard du titulaire dont un marché subséquent
# aurait été résilié pour faute par le service bénéficiaire.
#
#
#
# Chunk 464:
# Pour défaut de réponse aux consultations. L'acheteur peut prononcer, sans indemnité, la résiliation
# de l'accord-cadre à l'égard du titulaire qui n'aurait pas répondu à l'invitation suivant larticle 4.3.2.
#  Pour manquement grave et répété à lengagement dinsertion.
#
#
#
#
# Chunk 465:
# CCAP BPM060225_DATAVAL BPM060225
# 45/48
#   En complément de larticle 50 du CCAG-TIC, en cas non-respect des règles de sécurité ,
# lacheteur peut résilier pour faute le marché :
#
#
#
# Chunk 466:
# - Avec mise en demeure dans les conditions de larticle 50.2 du CCAG-TIC ;
#  - Sans mise en demeure.
#
#
#
# Chunk 467:
# La résiliation de l'accord-cadre n'entraîne pas la résiliation des marchés subséquents en cours d'exécution.
#  5.19 EXECUTION AUX FRAIS ET RISQUES DU TITULAIRE
#
#
#
# Chunk 468:
# Le titulaire est tenu de mettre en œuvre, dans le cadre des missions qui lui sont confiées, tous les procédés
# et moyens lui permettant de réaliser les prestations conformément aux spécifications du cahier des charges.
# Pour les prestations qui lui incombent, le titulaire doit strictement respecter les délais, les coûts et les niveaux
# de qualité prévus dans les documents contractuels régissant le marché. Les prestations devront être
# conformes aux prescriptions de l'ensemble des normes homologuées ou à toute norme européenne
# équivalente.
#
#
# Chunk 469:
# Cette disposition vaut non seulement pour les normes en vigueur au jour de la passation du
# marché mais également pour toutes les nouvelles normes qui deviendraient effectives en cours d'exécution
# du marché.
#  Le cas échéant, lacheteur peut faire procéder par un tiers à lexécution des prestations, aux frais et risques
# du titulaire et dans les conditions prévues au CCAG-TIC.
# 5.20 DISPOSITIONS APPLICABLES EN CAS DE MENACE SANITAIRE GRAVE
#
#
# Chunk 470:
# APPELANT DES
# MESURES DURGENCE
# La menace sanitaire appelant des mesures durgence,
#
#
# Chunk 471:
# notamment létat durgence sanitaire déclaré en
# application des dispositions du code de la santé publique, est assimilée à un cas de force majeure dès lors
# que cette situation est inconnue des parties au moment de la signature du marché public par lacheteur ou
# que cette situation, bien que connue des parties, donne lieu à des mesures durgences nouvelles inconnues
# des parties au moment de la signature du marché public par lacheteur et ayant un impact direct sur lexécution
# du contrat. Ces situations sont constitutives dun
#
#
# Chunk 472:
# « évènement perturbateur » au sens du présent article.
#  Lévènement perturbateur fait obstacle à lapplication de sanction, de pénalités contractuelles à légard du
# titulaire comme à la mise en œuvre de la responsabilité contractuelle des parties à raison de retards ou
# dinexécution des obligations qui leur incombe, dès lors quest établi un lien de causalité entre lévènement
# perturbateur et le retard ou linexécution.
#  Suspension de lexécution des prestations à la demande du titulaire
# Si le titulaire est temporairement dans limpossibilité dexécuter tout ou partie des prestations du fait de
# lévènement perturbateur
#
#
# Chunk 473:
# ou que cette exécution ferait peser sur lui une charge manifestement excessive, il
# peut en demander la suspension par tout moyen matériel ou dématérialisé permettant de déterminer de façon
# certaine la date et lheure de sa réception.
#  La décision de suspendre lexécution des prestations à la demande du titulaire fait lobjet dun écrit émanant
# de lacheteur et est transmise par tout moyen matériel ou dématérialisé permettant de déterminer de façon
# certaine la date et lheure de sa réception.
# Dans sa décision, lacheteur précise limpact éventuel de la suspension sur la durée du marché.
#
#
# Chunk 474:
# Toute
# modification de la durée du marché ne peut résulter que dun avenant.
#  En cas de suspension du marché à la demande du titulaire, lacheteur se réserve la possibilité de conclure un
# marché de substitution avec un tiers pour satisfaire les besoins qui ne peuvent souffrir aucun retard,
# nonobstant toute clause dexclusivité et sans que le titulaire du marché initial ne puisse engager, pour ce motif,
# la responsabilité contractuelle de lacheteur.
#
#
# Chunk 475:
# Lexécution du marché de substitution nest pas effectuée aux
# frais et risques du titulaire.
#
# CCAP BPM060225_DATAVAL BPM060225
# 46/48
# Le titulaire ne peut quant à lui être sanctionné, se voir appliquer de pénalités contractuelles, ni voir sa
# responsabilité contractuelle engagée dès lors quil démontre quil ne dispose pas des moyens suffisants pour
# exécuter les prestations ou que leur mobilisation ferait peser sur lui une charge manifestement excessive.
#  A ce titre, toute justification permettant à lacheteur dapprécier le bien-fondé des difficultés rencontrées ou à
# venir ainsi que leur lien de causalité avec lévènement perturbateur doit être fournie par le titulaire.
#
#
#
# Chunk 476:
# La suspension de lexécution des prestations à linitiative du titulaire nouvre droit à aucune indemnité au
# bénéfice de ce dernier.
#  Suspension à linitiative de lacheteur
#  Si lacheteur décide de suspendre lexécution de tout ou partie des prestations, il en informe le titulaire par
# écrit, dans les meilleurs délais et par tout moyen matériel ou dématérialisé permettant de déterminer de façon
# certaine la date et lheure de sa réception.
# Dans sa décision
#
#
# Chunk 477:
# , lacheteur précise limpact éventuel de la suspension sur la durée du marché. Toute
# modification de la durée du marché ne peut résulter que dun avenant.
#
#
#
# Chunk 478:
# En cas de suspension de tout ou partie des prestations, les parties procèdent à létablissement dun constat
# contradictoire des prestations réalisées jusquà la suspension, sauf lorsque celui-ci savère manifestement
# inutile.
#
#
#
# Chunk 479:
# Lacheteur ne peut voir sa responsabilité contractuelle engagée dès lors quest établi un lien de causalité entre
# lévènement perturbateur et la décision de suspension.
#  Le titulaire, quant à lui, ne peut être sanctionné, se voir appliquer de pénalités contractuelles, ni voir sa
# responsabilité contractuelle engagée du fait de cette suspension.
#
#
#
# Chunk 480:
# Celle-ci donne lieu à indemnisation du titulaire sil démontre lexistence dun lien direct entre le préjudice subi
# et la suspension des prestations.
#  Pour ce faire, il adresse à lacheteur un mémoire en réclamation, conformément aux dispositions de larticle
# du CCAG de référence relatif aux différends entre les parties.
#
#
# Chunk 481:
# Ce mémoire justifie :
# - les coûts darrêt des prestations objet du marché ;
#  - les coûts de remise en état à lissue de la suspension en vue de la reprise dexécution ;
#
#
#
# Chunk 482:
# - la part des charges dexploitation directement liées à lexécution du marché et qui ont continué dêtre
# supportées par le titulaire pendant la période de suspension.
#  Prolongation du délai dexécution des prestations
#
#
#
# Chunk 483:
# Lacheteur prolonge le délai dexécution dès lors que le titulaire est dans limpossibilité de le respecter, ou que
# cette exécution en temps et en heure nécessiterait des moyens dont la mobilisation ferait peser sur lui une
# charge manifestement excessive.
#
#
# Chunk 484:
# Pour bénéficier de cette prolongation, le titulaire justifie des causes faisant
# obstacle à lexécution de tout ou partie des prestations dans le délai contractuel et du lien de causalité entre
# cette impossibilité et lévènement perturbateur.
# La demande de prolongation intervient avant lexpiration du délai contractuel et de la période associée à
# lévènement perturbateur. Elle seffectue dans les conditions fixées par le CCAG de référence.
#
#
#
# Chunk 485:
# La prolongation du délai dexécution peut être à linitiative de lacheteur qui en informe le titulaire par écrit,
# dans les meilleurs délais et par tout moyen matériel ou dématérialisé permettant de déterminer de façon
# certaine la date et lheure de sa réception.
#
# CCAP BPM060225_DATAVAL BPM060225
# 47/48 En cas de prolongation, le nouveau délai a les mêmes effets que le délai contractuel et est dune durée
# suffisante pour la réalisation des prestations. La décision de prolongation précise son impact éventuel sur la
# durée du marché.
#
#
# Chunk 486:
# Toute modification de la durée du marché ne peut résulter que dun avenant.
#  Résiliation en cas dimpossibilité dexécuter la prestation et indemnisation associée
# Lorsque le titulaire est dans limpossibilité dexécuter le marché du fait de lévènement perturbateur
#
#
# Chunk 487:
# , lacheteur
# prononce la résiliation du marché sur le fondement de larticle L. 2195-2 du code de la commande publique.
#  Le décompte de résiliation est établi conformément aux dispositions du CCAG de référence, en faisant
# application des modalités de résiliation sattachant au cas de résiliation pour évènement présentant les
# caractéristiques de la force majeure.
#
#
#
# Chunk 488:
# Indemnisation suite à lannulation dun bon de commande
#  Lannulation dun bon de commande par lacheteur à la suite dun évènement perturbateur ouvre droit à une
# indemnisation du titulaire des dépenses spécifiquement engagées pour lexécution des prestations annulées.
#
#
#
# Chunk 489:
# Le titulaire adresse à lacheteur un mémoire en réclamation, conformément aux dispositions de larticle du
# CCAG de référence relative aux différends entre les parties. Ce mémoire justifie :
# - de lexistence du préjudice subi (réalité des charges pesant sur le titulaire et évaluation du montant demandé)
# ;
#
#
#
# Chunk 490:
# - de lexistence dun lien de causalité entre lévènement perturbateur et ledit préjudice.
#  Indemnisation en cas de poursuite dexécution bouleversant léquilibre du contrat
#
#
#
# Chunk 491:
# Lorsque léquilibre du contrat est bouleversé du fait de la poursuite de lexécution des prestations, le titulaire
# peut être indemnisé des charges supplémentaires extracontractuelles quil supporte, dans les conditions
# précisées par la circulaire du Premier ministre et du ministre de léconomie et des finances du 20 novembre
# 1974 relative à lindemnisation des titulaires de marchés publics en cas daccroissement imprévisible de leurs
# charges économiques
# Pour ce faire, le titulaire doit démontrer le bouleversement de léquilibre du contrat, la perte effective subie
# ainsi que le lien avec lévènement perturbateur. A défaut, la demande dindemnisation est rejetée.
#
#
#
# Chunk 492:
# Un pourcentage de 10% du montant de la perte effective reste à la charge du titulaire.
#  Demandes indemnitaires
#
#
#
# Chunk 493:
# Les demandes indemnitaires font lobjet dun mémoire en réclamation transmis à lacheteur par tout moyen
# matériel ou dématérialisé permettant de déterminer de façon certaine la date et lheure de sa réception. Le
# mémoire en réclamation est transmis dans les conditions fixées par larticle 55.2 du CCAG TIC et justifie de
# manière circonstanciée le préjudice subi, les coûts associés, et leur lien avec lévènement ayant caractère de
# force majeure.
#
#
#
# Chunk 494:
# Ne peuvent être indemnisés des coûts résultant de la négligence ou de la défaillance du titulaire.
#  Modalités de communications en cas de crise sanitaire
# En période de crise sanitaire
#
#
# Chunk 495:
# , les réunions en présentiel peuvent être remplacées par des réunions à distance
# par tous moyens de téléconférence (audioconférence, visioconférence notamment).
#  Lorsque les parties privilégient les échanges dématérialisés, les modalités fixées au présent document
# sappliquent (cf article «
#
#
# Chunk 496:
# Forme des notifications et des informations »).
#
#  CCAP BPM060225_DATAVAL BPM060225
# 48/48
#
#
# Chunk 497:
# 5.21 LITIGES ET CONTENTIEUX
#  Le présent accord-cadre est régi par le droit français.
# Tout litige dans le cadre du présent marché est soumis au Tribunal administratif de Paris (4 rue de Jouy
# 75004 Paris (Tel :01 44 59 44 00) pour les aspects concernant les modalités d'exécution du marché.
#
#
#
# Chunk 498:
# Les tribunaux de grande instance compétents pour connaitre des actions en matière de propriété intellectuelle
# sont désignés par le Code de l'organisation judiciaire.
# 5.22 DIFFERENDS
# La procédure de règlement à lamiable des différends ou litiges, susceptibles de survenir en cours dexécution
# du marché est celle prévue aux articles R2197-1 à R2197-25 et D2197-13 à D2197-22 du Code de la
# commande publique.
#  Le comité consultatif compétent est le comité consultatif national de règlement amiable des litiges, 6 rue Louise
# Weiss, 75013 Paris (Tel : 01 44 87 17 17).
#
#
#
# Chunk 499:
# Article 6 DEROGATION AU CCAG -TIC
#
#
#
# Chunk 500:
# Les dérogations au CCAG-TIC sont présentées dans le tableau récapitulatif ci-après :
# Article du présent
# CCAP Article du CCAG
#
#
#
# Chunk 501:
# auquel il est fait
# dérogation
#  Commentaire
#
#
# Chunk 502:
# - objet de la dérogation
# 2.13.3 5.1.1 La dérogation porte sur la Confidentialité
# 2.14.2 10.2.2
#
#
# Chunk 503:
# La dérogation porte sur lapplication de la révision dans le
# temps
# 2.7 4.1 La dérogation porte lordre de priorité de pièces contractuelles
# 5.10.2.1
# 5.11.2.1, 5.11.2.6,
# 5.11.2.7 14
# 12.1.3 La dérogation porte sur les pénalités
# Règlement des groupements dopérateurs économiques
# 5.10.6 14.1.3
#
#
# Chunk 504:
# La dérogation porte sur lexonération de pénalités
# 5.11.1 11 La dérogation porte sur Lavance
# 5.15.1 46 Régime PI
# 5.18 51 La dérogation porte sur la résiliation
# Article 7
#
#
# Chunk 505:
# ANNEXE AU CCAP
# 1 - MODELE DE DECLARATION DINTERET
#
#
#
#  Entities saved successfully!
