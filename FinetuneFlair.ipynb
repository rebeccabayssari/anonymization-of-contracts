# %%
import re
text_1 = """CCAP_BPM031594 _2MAINS BPM031594 22/39
 Procédure d installation défaillante : par manque de clarté, de détails, de lisibilité, etc. ;
 Séparation des variables défaillan te : les composants livrés ne doivent pas contenir « en dur » de
référence à la plate -forme sur laquelle ils sont destinés à être installés.
La liste des paramètres à adapter en fonction de la plate -forme de destination doit être clairement
identifiée dan s un document séparé, et sa prise en compte lors du déroulement de la procédure
dinstallation doit être aisée ;
 Anomalie bloquante dès l exécution des quelques tests destinés à vérifier la bonne installation ;
 Absence d un livrable documentaire prévu dans le CCTP : spécifications, rapport de pré -audit RGAA,
de sécurité, rapport SONAR, cahier de recette, rapport d exécution de la recette usine, fiches
danomalies non renseignées
Une fois que la MOM est prononcée sans réserve ou avec des réserves mineures , le Ministère entame la
Vérification d Aptitude.
Vérification d aptitude (VA)
La VA permet de vérifier le bon fonctionnement de la livraison et ce, à tous les niveaux (fonctionnel,
technique, performance, sécurité, etc.).
Elle démarre aussitôt le PV de MOM signé et sa durée est de 3 mois maximum.
La recette est réalisée essentiellement sur l environnement d intégration puis l environnement de
validation, voire de pré -production. La recette fonctionnelle est assurée par la MOA avec le cas échéant
une assi stance (AMOA, titulaire du marché PETRA). La recette technique est assurée par la DNUM avec
le cas échéant une assistance du titulaire du marché PETRA ou d autres marchés d expertise (ex : audit
dintrusion).
Toute anomalie détectée en VA doit être corrigé e à la charge du titulaire. La livraison d une version
corrective est planifiée intégrant la correction de toutes les anomalies au plus tôt et permettre au Ministère
de réitérer la recette.
En tout état de cause, la durée de la VA est suspendue en cas de détection d anomalie bloquante, tant
que le correctif (ou éventuellement, un palliatif simple) n a pas été livré. Les indicateurs qualité sont
impactés et des pénalités peuvent s appliquer le cas échéant.
Pour chaque livraison, le Ministère peut décider d ajourner ou de valider la livraison comme décrit
précédemment.
La fin de cette étape est formalisée par le PV de Service Fait (SF ).
A lissue de chaque vérification, le pouvoir adjudicateur prendra une déci sion conformément à l article
11.8.3 du présent do cument.
Vérification de service régulier (VSR)
La VSR permet de vérifier une fois que l application est en production qu il ne reste pas d anomalie, aussi
bien fonctionnelle que technique, notamment qu elle supporte convenablement la montée en charge des
utilisateurs.
Toute anomalie détectée en VSR doit être corrigée à la charge du titulaire, sans donner lieu à un nouveau
bon de commande.
La durée de la VSR est de 3 mois.
Le délai démarre à la mise en production ou au plus tard 1 mois après le PV de SF de la VA.

CCAP_BPM031594 _2MAINS BPM031594 23/39
Les conditions de fin de VSR sont l absence d anomalies majeures ou bloquantes sur le dernier mois de
la VSR. Si la VSR n est pas prononcée en raison de conditions de sortie non -remplies (anomalies
résiduelles majeures ou bloquantes détectées en production), celle -ci est prorogée d un mois à compter
de la date de la dernière livraison corrigeant ces anomalies.
Les conditions de sortie sont réexaminées à l issue de la période de prorogation et peuvent conduire à
une nouvelle prorogation.
A lissue de chaque vérification, le pouvoir adjudicateur prendra une décision conformément à l article
11.10.3 du présent document.
11.8.3 Décision après vérifications
En complément des articles 32 et 33 du CCAG -TIC, les opérations de vérification qualitative ont é galement
pour objet de contrôler les conformités à la politique de sécurité. Lacheteur apprécie lenjeu du défaut eu
Les pénalités ne présentent aucun caractère libératoire. Le titulaire est donc intégralement redevable de
ses obligations contractuelles et notamment des prestations dont l inexé cution a donné lieu à l application
de pénalités.
Il ne saurait se considérer comme libéré de son obligation, du fait du paiement desdites pénalités.
Lapplication de pénalités est effectuée sans préjudice de la faculté de la personne publique de prononce r
toute autre sanction contractuelle et notamment de faire réaliser tout ou partie de l accord -cadre aux frais
et risques du titulaire.
Les pénalités peuvent être précomptées sur les acomptes versés au titulaire tout au long de l exécution
des prestation s, lors de l établissement des états d acomptes, ou constituer un élément du décompte
général."""
entities_1 = [("Ministère", "ORG"), ("MOA", "ORG"), ("MOM", "ORG"), ("AMOA", "ORG"), ("PETRA", "ORG"), ("DNUM", "ORG"), ("administration", "PER")]

text_2 = """En cas de première mise en place de la facturation électronique et dans le respect de l obligation de
transmission des factures par voie dématérialisée telle que précisée dans le code de la comman de
publique , le titulaire dispose d un délai maximum de trois mois , à compter de la notification, pour être
opérationnel dans la mise en œuvre de la facturation par voie dématérialisée.
Durant ce délai, le titulaire peut remettre une facture papier. Les f actures sont établies en un seul original
et envoyées à l adresse suivante :
Service facturier des ministères sociaux
14 avenue Duquesne
75350 PARIS 07 SP
Passé ce délai, en cas de difficultés avérées dans la mise en place de la facturation électronique l ors de
lexécution du marché public, et sur demande expresse du titulaire justifiant des difficultés rencontrées, le
titulaire peut remettre une facture papier dans le délai provisoire qui lui a été accordé.
Durant ce délai, le titulaire remet une facture papier envoyée en un seul original à l adresse renseignée
ci-dessus.

CCAP_BPM031594 _2MAINS BPM031594 33/39
Pour tout renseignement concernant le paiement, il est possible de prendre contact avec le service
facturier des ministères sociaux (14, avenue Duquesne - 75350 PARIS 07 SP)
Téléphone: 01 40 56 83 79
Ou par mail :
helene.merlet@cbcm.social.gouv.fr
stephanie.smaghe@cbcm.social.gouv.fr"""
entities_2 =  [
    ("Service", "ORG"),
    ("facturier", "ORG"),
    ("ministères", "ORG"),
    ("sociaux", "ORG"),
    ("14", "LOC"),
    ("avenue", "LOC"),
    ("Duquesne", "LOC"),
    ("75350", "LOC"),
    ("PARIS", "LOC"),
    ("07", "LOC"),
    ("SP", "LOC"),
    ("helene", "PER"),
    ("merlet", "PER"),
    ("stephanie", "PER"),
    ("smaghe", "PER")
]
texts = [text_1, text_2]
annotations = [entities_1, entities_2]
def split_sentences(text):
    """ Divise le texte en phrases en utilisant la ponctuation. """
    sentences = re.split(r"(?<=[\.\?!;:])\s+", text)  # Séparer sur `.`, `?`, `!`, `;`, `:` suivi d'un espace
    return sentences
#1- Initialise tous les mots avec "O" (Outside).
#2- Cherche les entités dans la liste des mots.
#3- Marque le premier mot d'une entité avec B-TAG.
#4- Marque les mots suivants avec I-TAG.
#5- Retourne la liste sous forme de tuples 
def convert_to_bio(text, entities):
    words = text.split()
    bio_tags = ["O"] * len(words)

    for entity, label in entities:
        entity_words = entity.split()
        for i in range(len(words) - len(entity_words) + 1):
            if words[i:i + len(entity_words)] == entity_words:
                bio_tags[i] = f"B-{label}"
                for j in range(1, len(entity_words)):
                    bio_tags[i + j] = f"I-{label}"
                break  

    return list(zip(words, bio_tags))

# Génération du fichier train.txt
bio_data = []
for text, entity_list in zip(texts, annotations):
    sentences = split_sentences(text)  # Séparer en phrases
    for sentence in sentences:
        bio_data.extend(convert_to_bio(sentence, entity_list))
        bio_data.append(("", ""))  # Ligne vide après chaque phrase
   


with open("train.txt", "w", encoding="utf-8") as f:
    for word, tag in bio_data:
        f.write(f"{word} {tag}\n")

print(" Fichier train.txt généré avec le texte original et les annotations !")
# Out:
#  Fichier train.txt généré avec le texte original et les annotations !

# %%
file_path = r"C:\\Users\\hp\\Downloads\\clever contact\\clevercontracts\\Contracts\\2MAINS\\test_contract.txt"

with open(file_path, "r", encoding="utf-8") as f:
    contract_text = f.read()

print("Fichier chargé avec succès !")
# Out:
# Fichier chargé avec succès !

# %%
#Charge les données BIO de train.txt dans un Corpus Flair.
#Le modèle apprend les entités à partir de train.txt.
#Flair génère automatiquement des jeux de validation (dev) et de test (test) en prenant 10% des données d'entraînement

from flair.data import Corpus
from flair.datasets import ColumnCorpus
from flair.models import SequenceTagger
from flair.trainers import ModelTrainer
columns = {0: "text", 1: "ner"}
corpus = ColumnCorpus(".", columns, train_file="train.txt")
print(corpus)
# Out:
# 2025-03-13 00:06:56,145 Reading data from .
# 2025-03-13 00:06:56,149 Train: train.txt
# 2025-03-13 00:06:56,152 Dev: None
# 2025-03-13 00:06:56,154 Test: None
# 2025-03-13 00:06:56,247 No test split found. Using 10% (i.e. 8 samples) of the train split as test data
# 2025-03-13 00:06:56,252 No dev split found. Using 10% (i.e. 7 samples) of the train split as dev data
# Corpus: 63 train + 7 dev + 8 test sentences

# %%
# Charger un modèle NER français pré-entraîné
tagger = SequenceTagger.load("flair/ner-french")

#finetuner sur mes propres donnees (corpus)
trainer = ModelTrainer(tagger, corpus)

# Lancer l'entraînement
trainer.train("flair_ner_output",
              learning_rate=0.1,
              mini_batch_size=16,
              max_epochs=5,
              plugins=[])
# Out:
# 2025-03-13 00:07:34,004 SequenceTagger predicts: Dictionary with 19 tags: O, S-LOC, B-LOC, E-LOC, I-LOC, S-PER, B-PER, E-PER, I-PER, S-MISC, B-MISC, E-MISC, I-MISC, S-ORG, B-ORG, E-ORG, I-ORG, <START>, <STOP>
# 2025-03-13 00:07:34,434 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:34,436 Model: "SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): WordEmbeddings(
#       '0-/vol/home-vol2/ml/akbikala/.flair/embeddings/fr-wiki-fasttext-300d-1M'
#       (embedding): Embedding(1000000, 300)
#     )
#     (list_embedding_1): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.5, inplace=False)
#         (encoder): Embedding(275, 100)
#         (rnn): LSTM(100, 1024)
#       )
#     )
#     (list_embedding_2): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.5, inplace=False)
#         (encoder): Embedding(275, 100)
#         (rnn): LSTM(100, 1024)
#       )
#     )
#   )
#   (word_dropout): WordDropout(p=0.05)
#   (locked_dropout): LockedDropout(p=0.5)
#   (embedding2nn): Linear(in_features=2348, out_features=2348, bias=True)
#   (rnn): LSTM(2348, 256, batch_first=True, bidirectional=True)
#   (linear): Linear(in_features=512, out_features=19, bias=True)
#   (loss_function): ViterbiLoss()
#   (crf): CRF()
# )"
# 2025-03-13 00:07:34,437 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:34,438 Corpus: 63 train + 7 dev + 8 test sentences
# 2025-03-13 00:07:34,439 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:34,440 Train:  63 sentences
# 2025-03-13 00:07:34,442         (train_with_dev=False, train_with_test=False)
# 2025-03-13 00:07:34,443 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:34,443 Training Params:
# 2025-03-13 00:07:34,444  - learning_rate: "0.1"
# 2025-03-13 00:07:34,447  - mini_batch_size: "16"
# 2025-03-13 00:07:34,448  - max_epochs: "5"
# 2025-03-13 00:07:34,449  - shuffle: "True"
# 2025-03-13 00:07:34,450 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:34,451 Plugins:
# 2025-03-13 00:07:34,453  - AnnealOnPlateau | patience: '3', anneal_factor: '0.5', min_learning_rate: '0.0001'
# 2025-03-13 00:07:34,455 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:34,456 Final evaluation on model from best epoch (best-model.pt)
# 2025-03-13 00:07:34,457  - metric: "('micro avg', 'f1-score')"
# 2025-03-13 00:07:34,460 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:34,461 Computation:
# 2025-03-13 00:07:34,462  - compute on device: cpu
# 2025-03-13 00:07:34,463  - embedding storage: cpu
# 2025-03-13 00:07:34,464 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:34,467 Model training base path: "flair_ner_output"
# 2025-03-13 00:07:34,468 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:34,469 ----------------------------------------------------------------------------------------------------
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\flair\trainers\trainer.py:545: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp and flair.device.type != "cpu")
# 2025-03-13 00:07:36,095 epoch 1 - iter 1/4 - loss 0.54812566 - time (sec): 1.62 - samples/sec: 236.12 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:37,216 epoch 1 - iter 2/4 - loss 0.42202163 - time (sec): 2.74 - samples/sec: 249.99 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:38,382 epoch 1 - iter 3/4 - loss 0.35201056 - time (sec): 3.91 - samples/sec: 263.94 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:39,685 epoch 1 - iter 4/4 - loss 0.31271379 - time (sec): 5.21 - samples/sec: 248.41 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:39,691 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:39,692 EPOCH 1 done: loss 0.3127 - lr: 0.100000
# 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# 2025-03-13 00:07:40,583 DEV : loss 0.7070236802101135 - f1-score (micro avg)  0.1333
# 2025-03-13 00:07:40,587  - 0 epochs without improvement
# 2025-03-13 00:07:40,589 saving best model
# 2025-03-13 00:07:49,931 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:50,426 epoch 2 - iter 1/4 - loss 0.18538897 - time (sec): 0.49 - samples/sec: 817.26 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:50,673 epoch 2 - iter 2/4 - loss 0.29055425 - time (sec): 0.74 - samples/sec: 835.70 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:51,131 epoch 2 - iter 3/4 - loss 0.22410426 - time (sec): 1.20 - samples/sec: 799.75 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:51,500 epoch 2 - iter 4/4 - loss 0.20025300 - time (sec): 1.57 - samples/sec: 826.94 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:51,503 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:51,505 EPOCH 2 done: loss 0.2003 - lr: 0.100000
# 100%|██████████| 1/1 [00:00<00:00,  7.29it/s]
# 2025-03-13 00:07:51,665 DEV : loss 0.6661763787269592 - f1-score (micro avg)  0.1333
# 2025-03-13 00:07:51,672  - 0 epochs without improvement
# 2025-03-13 00:07:51,674 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:52,117 epoch 3 - iter 1/4 - loss 0.07746389 - time (sec): 0.44 - samples/sec: 657.84 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:52,431 epoch 3 - iter 2/4 - loss 0.04590339 - time (sec): 0.76 - samples/sec: 783.39 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:52,813 epoch 3 - iter 3/4 - loss 0.11547104 - time (sec): 1.14 - samples/sec: 802.90 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:53,248 epoch 3 - iter 4/4 - loss 0.15327130 - time (sec): 1.57 - samples/sec: 823.29 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:07:53,253 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:07:53,255 EPOCH 3 done: loss 0.1533 - lr: 0.100000
# 100%|██████████| 1/1 [00:00<00:00,  6.95it/s]
# 2025-03-13 00:07:53,429 DEV : loss 0.6317252516746521 - f1-score (micro avg)  0.1429
# 2025-03-13 00:07:53,431  - 0 epochs without improvement
# 2025-03-13 00:07:53,434 saving best model
# 2025-03-13 00:08:01,843 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:08:02,368 epoch 4 - iter 1/4 - loss 0.08617200 - time (sec): 0.51 - samples/sec: 590.54 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:08:02,868 epoch 4 - iter 2/4 - loss 0.19221191 - time (sec): 1.02 - samples/sec: 709.17 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:08:03,195 epoch 4 - iter 3/4 - loss 0.15618831 - time (sec): 1.34 - samples/sec: 766.82 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:08:03,532 epoch 4 - iter 4/4 - loss 0.13486404 - time (sec): 1.68 - samples/sec: 771.18 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:08:03,534 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:08:03,535 EPOCH 4 done: loss 0.1349 - lr: 0.100000
# 100%|██████████| 1/1 [00:00<00:00,  6.82it/s]
# 2025-03-13 00:08:03,707 DEV : loss 0.6027817130088806 - f1-score (micro avg)  0.1429
# 2025-03-13 00:08:03,711  - 0 epochs without improvement
# 2025-03-13 00:08:03,713 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:08:04,183 epoch 5 - iter 1/4 - loss 0.01658923 - time (sec): 0.47 - samples/sec: 845.03 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:08:04,542 epoch 5 - iter 2/4 - loss 0.04662841 - time (sec): 0.83 - samples/sec: 842.38 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:08:04,857 epoch 5 - iter 3/4 - loss 0.05140824 - time (sec): 1.14 - samples/sec: 841.66 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:08:05,178 epoch 5 - iter 4/4 - loss 0.09448223 - time (sec): 1.46 - samples/sec: 885.12 - lr: 0.100000 - momentum: 0.000000
# 2025-03-13 00:08:05,186 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:08:05,188 EPOCH 5 done: loss 0.0945 - lr: 0.100000
# 100%|██████████| 1/1 [00:00<00:00,  6.79it/s]
# 2025-03-13 00:08:05,359 DEV : loss 0.5618904232978821 - f1-score (micro avg)  0.1429
# 2025-03-13 00:08:05,361  - 0 epochs without improvement
# 2025-03-13 00:08:13,832 ----------------------------------------------------------------------------------------------------
# 2025-03-13 00:08:13,838 Loading model from best epoch ...
# 2025-03-13 00:08:19,990 SequenceTagger predicts: Dictionary with 19 tags: O, S-LOC, B-LOC, E-LOC, I-LOC, S-PER, B-PER, E-PER, I-PER, S-MISC, B-MISC, E-MISC, I-MISC, S-ORG, B-ORG, E-ORG, I-ORG, <START>, <STOP>
# 100%|██████████| 1/1 [00:00<00:00,  1.59it/s]
# 2025-03-13 00:08:21,544
# Results:
# - F-score (micro) 0.4
# - F-score (macro) 0.25
# - Accuracy 0.25
#
# By class:
#               precision    recall  f1-score   support
#
#          ORG     0.5000    0.5000    0.5000         2
#          PER     0.0000    0.0000    0.0000         1
#
#    micro avg     0.5000    0.3333    0.4000         3
#    macro avg     0.2500    0.2500    0.2500         3
# weighted avg     0.3333    0.3333    0.3333         3
#
# 2025-03-13 00:08:21,545 ----------------------------------------------------------------------------------------------------
# {'test_score': 0.4}

# %%
from flair.data import Sentence
from flair.models import SequenceTagger

# Charger le modèle entraîné
tagger = SequenceTagger.load("flair_ner_output/best-model.pt")

print(" Modèle chargé avec succès !")
# Out:
# 2025-04-05 03:06:22,829 SequenceTagger predicts: Dictionary with 19 tags: O, S-LOC, B-LOC, E-LOC, I-LOC, S-PER, B-PER, E-PER, I-PER, S-MISC, B-MISC, E-MISC, I-MISC, S-ORG, B-ORG, E-ORG, I-ORG, <START>, <STOP>
#  Modèle chargé avec succès !

# %%
# Charger le fichier de test
file_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts\Contracts\2MAINS\test_contract.txt"

with open(file_path, "r", encoding="utf-8") as f:
    contract_text = f.read()

# Convertir en une "Sentence" Flair
sentence = Sentence(contract_text)

# Prédire les entités
tagger.predict(sentence)
print(" Résultat de l'anonymisation :")
print(sentence.to_tagged_string())
# Out:
#  Résultat de l'anonymisation :
# Sentence[17991]: "CCAP_BPM031594 _2MAINS BPM031594 1/39 Secrétariat général Direction des finances, des achats et des services Prestations de développement et de maintenance intégrées d application des Ministères sociaux - "2MAINS" Cahier des clauses administratives Numéro de consultation : BPM 031594 Procédure de passation : Appel d offres ouvert de larticle R.2124 -2 1° du code de la commande publique,  CCAP_BPM031594 _2MAINS BPM031594 2/39 Table des matières 8.1 Cadre général 5 8.2 Reconduction de laccord -cadre 6  11.1 Représentation des parties .. 7 11.2 Conditions dexécution 7 11.3 Obligations du titulaire 10 11.4 Considérations sociales 12 11.5 Considérations environnementales 15 11.6 Traitement de données à caractère personnel 15 11.7 Clauses de réexamen 19 11.8 Constatation de lexécution des prestations et admission 20 11.9 Garantie 24 11.10 Primes 24 11.11 Pénalités 24 11.12 Destruction des données . 26 12.1 Forme et contenu des prix . 26 12.2 Variation des prix 28 12.3 Avances 29 12.4 Modalités financières 29  13.1 Régime des droits sur les résultats 33 13.2 Régime des droits sur les connaissances antérieures 33 13.3 Prix de la cession des droits 33 14.1 Forme des notifications et des informations 34 14.2 Langue 34 14.3 Sous -traitance 34 14.4 Assurances 35 14.5 Autres obligations administratives 35 14.6 Résiliation 35 14.7 Exécution aux frais et risques du titulaire 36 14.8 Dispositions applicables en cas de menace sanitaire grave appelant des mesures durgence 36 14.9 Différends 39 14.10 Litiges et contentieux 39  CCAP_BPM031594 _2MAINS BPM031594 3/39 Article 1 - PREAMBULE - CONTEXTE Les ministères sociaux sont engagés dans une démarche de promotion de la diversité et de l égalité professionne lle entre les femmes et les hommes. A ce titre, ils sont attentifs dans le choix de leurs contractants comme dans la réalisation des prestations, au respect des dispositions législatives et réglementaires en la matière. Au-delà du respect de ces dispositio ns, les ministères sociaux sont également sensibles aux actions conduites par leurs prestataires dans ce domaine au sein de leur entreprise. Dans ce cadre, un questionnaire relatif aux actions conduites en matière de diversité et d égalité professionnelle entre les femmes et les hommes sera envoyé à la (aux) société(s) retenue(s) dans les jours suivant la notification du marché. Ce questionnaire devra être complété et renvoyé dans le mois suivant sa réception à l adresse suivante : Ministères sociaux Direction des finances, des achats et des services Sous -direction des achats et du développement durable 14 avenue Duquesne 75350 Paris 07 SP ou par courriel à : DFAS -DADD -RESEAU -ACHAT@sg.s ocial.gouv.fr Article 2 - ACHETEUR Ministères sociaux Secrétariat Général Direction du numérique Article 3 - OBJET DE L ACCORD -CADRE Le présent marché a pour objet des prestations de développement et de maintenance d applications des directions et délégations de l administration centrale des Ministères Sociaux. Il permet l achat de maintenance corrective, évolutive, préventive et adaptative des applications numériques confiées aux titulaires pour assurer le fonctionnement continu et sécurisé des applications ainsi q ue le développement de nouvelles applications. Il permet de développer les applications et services de demain, vitrines des Ministères Sociaux, en intégrant les dernières technologies et méthodes. Le présent marché est un marché de service. Code s CPV de la consultation : 72500000 -0 - Services informatiques. Article 4 - IDENTIFICATION DES ÉLÉMENTS SOUMIS AU DROIT DE LA PROPRIÉTÉ INTELLECTUELLE Les éléments soumis au droit de la propriété intellectuelle sont l ensemble des livrables cité s dans le CCTP aux articles 5 (lot 1), 6 (lot 2), 7 (lot 3) et 8 (lot 4) . Article 5 - PÉRIMÈTRE DE L ACCORD -CADRE Le présent accord -cadre concerne l ensemble des applications gérées par l administration centrale des Ministères Sociaux hors décisionnel , intelligence artificielle et progic ...

# %%
import json
#  Extract detected entities and store them in a list
extracted_entities = []
for entity in sentence.get_spans("ner"):
    extracted_entities.append({
        "text": entity.text,
        "type": entity.tag,
        "start": entity.start_position,
        "end": entity.end_position
    })

#  Save extracted entities to a JSON file
json_output_file = "flair_finetuned_entities.json"
with open(json_output_file, "w", encoding="utf-8") as f:
    json.dump(extracted_entities, f, indent=4, ensure_ascii=False)

# %%
output_path = r"C:\Users\hp\Downloads\clever contact\clevercontracts\Contracts\2MAINS\test_predictions.txt"

with open(output_path, "w", encoding="utf-8") as f:
    f.write(sentence.to_tagged_string())

print(f" Résultats sauvegardés dans {output_path} !")
# Out:
#  Résultats sauvegardés dans C:\Users\hp\Downloads\clever contact\clevercontracts\Contracts\2MAINS\test_predictions.txt !

# %%
# Charger le fichier de test
#file_path = "cleaned_contract_fixed_final.txt"
#file_path = "cleanedcontract3.txt"
file_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract4.txt"

with open(file_path, "r", encoding="utf-8") as f:
    contract_text = f.read()

# Convertir en une "Sentence" Flair
sentence = Sentence(contract_text)

# Prédire les entités
tagger.predict(sentence)
print(" Résultat de l'anonymisation :")
print(sentence.to_tagged_string())
import json
# Extract detected entities and store them in a list
extracted_entities = []
for entity in sentence.get_spans("ner"):
    extracted_entities.append({
        "text": entity.text,
        "type": entity.tag,
        "start": entity.start_position,
        "end": entity.end_position
    })

#  Save extracted entities to a JSON file
json_output_file = "flair_finetuned_entities_fulltext4.json"
with open(json_output_file, "w", encoding="utf-8") as f:
    json.dump(extracted_entities, f, indent=4, ensure_ascii=False)
# Out:
#  Résultat de l'anonymisation :
# Sentence[22979]: "SECRETARIAT GENERAL DIRECTION DES FINANCES , DES ACHATS ET DES SERVICES Numéro de consultation : BPM060225 ACCORD-CADRE RELATIF A DES PRESTATIONS DE VALORISATION DES DONNEES CAHIER DES CLAUSES ADMINISTRATIVES PARTICULIÈRES Numéro de consultation : BPM060225 Procédure de passation : Appel doffres ouvert, en application des articles L2124-1, L2124-2, R2124-2 et R2161-2 à R2161-5 du Code de la commande publique ACHETEUR MINISTERES SOCIAUX SECRETARIAT GENERAL DIRECTION DU NUMERIQUE  CCAP BPM060225_DATAVAL BPM060225 2/48 Table des matières 2.6 Forme et étendue de laccord-cadre 10 2.6.1 Forme de chaque lot 10 2.6.2 