# %%
import spacy
import json

# Load spaCy French NER model
nlp = spacy.load("fr_core_news_lg")

def split_text_into_sentence_chunks(text, sentences_per_chunk=2):
    """Splits text into chunks containing a fixed number of sentences."""
    doc = nlp(text)
    sentences = [sent.text for sent in doc.sents]
    
    chunks = []
    for i in range(0, len(sentences), sentences_per_chunk):
        chunk = " ".join(sentences[i:i + sentences_per_chunk])
        chunks.append(chunk)
    
    return chunks

def extract_entities_spacy(text):
    
    doc = nlp(text)
    extracted_entities = []

    for ent in doc.ents:
        extracted_entities.append({
            "text": ent.text,
            "type": ent.label_,
            "start": ent.start_char,
            "end": ent.end_char
        })
    
    return extracted_entities

def group_entities(entities, allowed_types={"ORG", "LOC"}):
    """Groups consecutive entities of the same type to handle multi-word entities."""
    grouped_entities = []
    current_entity = None

    for entity in entities:
        entity_type = entity["type"]

        # Skip entity if not in allowed types
        if entity_type not in allowed_types:
            if current_entity:
                grouped_entities.append(current_entity)
                current_entity = None
            continue

        if current_entity and entity_type == current_entity["type"]:
            # Merge entity if it's part of the previous one
            current_entity["text"] += " " + entity["text"]
            current_entity["end"] = entity["end"]
        else:
            # Save previous entity and start a new one
            if current_entity:
                grouped_entities.append(current_entity)
            current_entity = entity  # Start new entity

    # Append last entity if it exists
    if current_entity:
        grouped_entities.append(current_entity)

    return grouped_entities

#contract_path = "cleaned_contract_fixed_final.txt"
#contract_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract2.txt"
#contract_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract3.txt"
contract_path = r"C:\Users\hp\Downloads\clever contact\cleanedcontract4.txt"


# Load contract text
with open(contract_path, "r", encoding="utf-8") as file:
    contract_text = file.read()

# Step 1: Split into chunks
chunks = split_text_into_sentence_chunks(contract_text, sentences_per_chunk=2)

# Step 2: Apply NER and group entities
all_entities = []
for chunk in chunks:
    raw_entities = extract_entities_spacy(chunk)
    grouped = group_entities(raw_entities)
    all_entities.extend(grouped)
print(f"Entities extracted: {len(all_entities)}")

# Step 3: Save results to JSON
with open("spacy_extracted_entities4.json", "w", encoding="utf-8") as f:
    json.dump(all_entities, f, indent=4, ensure_ascii=False)

# Step 4: Print results
print("Extracted Entities:")
for entity in all_entities:
    print(f"Entity: {entity['text']} | Type: {entity['type']} | Start: {entity['start']} | End: {entity['end']}")
# Out:
# Entities extracted: 285
# Extracted Entities:
# Entity: BPM060225 | Type: LOC | Start: 97 | End: 106
# Entity: R2161-2 R2161-5 | Type: LOC | Start: 79 | End: 96
# Entity: ACHETEUR | Type: ORG | Start: 129 | End: 137
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 206 | End: 233
# Entity: laccord | Type: LOC | Start: 43 | End: 50
# Entity: laccord | Type: ORG | Start: 40 | End: 47
# Entity: laccord | Type: LOC | Start: 30 | End: 37
# Entity: État | Type: LOC | Start: 46 | End: 50
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 44 | End: 71
# Entity: Exigences | Type: LOC | Start: 20 | End: 29
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 120 | End: 147
# Entity: Décision | Type: LOC | Start: 42 | End: 50
# Entity: Pénalités | Type: LOC | Start: 160 | End: 169
# Entity: TVA | Type: ORG | Start: 59 | End: 62
# Entity: Monnaie | Type: LOC | Start: 75 | End: 82
# Entity: Régime des droits sur les résultats 42
# 5.15.2 Régime des droits sur les connaissances antérieures | Type: ORG | Start: 0 | End: 97
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 49 | End: 76
# Entity: Assurances | Type: ORG | Start: 87 | End: 97
# Entity: Différends BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 196 | End: 243
# Entity: CCAP | Type: ORG | Start: 69 | End: 73
# Entity: Direction du numérique | Type: ORG | Start: 15 | End: 37
# Entity: Directions des Ministères sociaux | Type: ORG | Start: 11 | End: 44
# Entity: Direction | Type: LOC | Start: 5 | End: 14
# Entity: Direction | Type: ORG | Start: 0 | End: 9
# Entity: Direction Générale DGEFP | Type: ORG | Start: 0 | End: 47
# Entity: ARS Agences régionales de santé DGS | Type: ORG | Start: 33 | End: 68
# Entity: Direction Générale de la Santé Direction Générale | Type: ORG | Start: 0 | End: 54
# Entity: Opérateur | Type: LOC | Start: 10 | End: 19
# Entity: Ressources Humaines
#   | Type: ORG | Start: 0 | End: 21
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 9 | End: 36
# Entity: Ministères sociaux
# Direction des finances Sous-direction | Type: ORG | Start: 345 | End: 429
# Entity: rue Olivier-de-Serres CS PARIS | Type: LOC | Start: 476 | End: 519
# Entity: LACCORD | Type: LOC | Start: 108 | End: 115
# Entity: Business intelligence | Type: ORG | Start: 516 | End: 537
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 88 | End: 115
# Entity: LACCORD | Type: LOC | Start: 13 | End: 20
# Entity: Direction du Numérique | Type: ORG | Start: 144 | End: 166
# Entity: Direction du numérique des ministères sociaux
#  | Type: ORG | Start: 213 | End: 259
# Entity: Direction du numérique | Type: ORG | Start: 72 | End: 94
# Entity: Ministères Sociaux Ministères
# Sociaux Directions
# dadministration centrale des ministères sociaux | Type: ORG | Start: 106 | End: 428
# Entity: DGEFP BCE | Type: ORG | Start: 156 | End: 199
# Entity: ARS | Type: ORG | Start: 4 | End: 7
# Entity: DGS Directions des ministères sociaux
#   | Type: ORG | Start: 13 | End: 87
# Entity: Directions des ministères sociaux
# A | Type: ORG | Start: 35 | End: 70
# Entity: Direction du NUMérique | Type: ORG | Start: 90 | End: 112
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 114 | End: 141
# Entity: ALLOTISSEMENT | Type: ORG | Start: 0 | End: 13
# Entity: Lot 1
#  | Type: ORG | Start: 128 | End: 134
# Entity: Lot | Type: LOC | Start: 32 | End: 35
# Entity: Lot 3
# Data science Intelligence
# artificielle | Type: ORG | Start: 163 | End: 210
# Entity: Collecte | Type: ORG | Start: 37 | End: 45
# Entity: Lot | Type: LOC | Start: 26 | End: 29
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: R2161-2 R2161-5 | Type: LOC | Start: 223 | End: 240
# Entity: HT | Type: ORG | Start: 144 | End: 146
# Entity: laccord-cadre | Type: LOC | Start: 620 | End: 633
# Entity: Lot | Type: LOC | Start: 363 | End: 366
# Entity: M HT Lot | Type: LOC | Start: 54 | End: 96
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 163 | End: 190
# Entity: BPU | Type: LOC | Start: 522 | End: 525
# Entity: LACCORD | Type: LOC | Start: 96 | End: 103
# Entity: laccord-cadre Lacte BPU | Type: LOC | Start: 28 | End: 178
# Entity: Ministères Sociaux | Type: ORG | Start: 17 | End: 35
# Entity: Dataval
# Homologation_securite_en_9_etapes.pdf | Type: LOC | Start: 63 | End: 109
# Entity: Référentiel | Type: LOC | Start: 35 | End: 46
# Entity: Circulaire État BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 69 | End: 188
# Entity: DATAVAL - Circulaire_6411-SG.pdf | Type: LOC | Start: 23 | End: 55
# Entity: Référentiel | Type: LOC | Start: 26 | End: 37
# Entity: PAS | Type: LOC | Start: 129 | End: 132
# Entity: PAQ | Type: ORG | Start: 202 | End: 205
# Entity: LACCORD | Type: LOC | Start: 292 | End: 299
# Entity: laccord-cadre | Type: LOC | Start: 252 | End: 265
# Entity: LACCORD | Type: LOC | Start: 133 | End: 140
# Entity: CCAP | Type: ORG | Start: 296 | End: 300
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 309 | End: 336
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: MCO | Type: ORG | Start: 131 | End: 134
# Entity: ATOM | Type: ORG | Start: 334 | End: 338
# Entity: Diffusion Restreinte DR | Type: ORG | Start: 47 | End: 71
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 220 | End: 247
# Entity: lannexe | Type: LOC | Start: 0 | End: 7
# Entity: CCAP | Type: ORG | Start: 15 | End: 19
# Entity: Ladministration | Type: ORG | Start: 0 | End: 15
# Entity: État | Type: LOC | Start: 339 | End: 343
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 198 | End: 225
# Entity: Maximum | Type: ORG | Start: 183 | End: 190
# Entity: EUR HT | Type: LOC | Start: 192 | End: 198
# Entity: BdC | Type: ORG | Start: 86 | End: 89
# Entity: BPU | Type: LOC | Start: 0 | End: 3
# Entity: BdC | Type: ORG | Start: 44 | End: 47
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 154 | End: 181
# Entity: BPU | Type: LOC | Start: 57 | End: 60
# Entity: RPA | Type: ORG | Start: 189 | End: 192
# Entity: ICHT | Type: ORG | Start: 295 | End: 299
# Entity: P P P0 Io P | Type: LOC | Start: 41 | End: 130
# Entity: Prix | Type: ORG | Start: 133 | End: 137
# Entity: H.T.V.A.
# P0 | Type: LOC | Start: 145 | End: 156
# Entity: RPA | Type: ORG | Start: 198 | End: 201
# Entity: laccord-cadre | Type: LOC | Start: 366 | End: 379
# Entity: N+3 | Type: LOC | Start: 390 | End: 393
# Entity: INSEE INSEE | Type: ORG | Start: 27 | End: 267
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 333 | End: 360
# Entity: Maximum | Type: ORG | Start: 211 | End: 218
# Entity: EUR HT | Type: LOC | Start: 220 | End: 226
# Entity: BPU | Type: LOC | Start: 12 | End: 15
# Entity: BdC | Type: ORG | Start: 56 | End: 59
# Entity: CCAP | Type: ORG | Start: 145 | End: 149
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: Lattribution | Type: ORG | Start: 39 | End: 51
# Entity: laccord-cadre | Type: LOC | Start: 159 | End: 172
# Entity: HT TTC HT TTC | Type: ORG | Start: 34 | End: 100
# Entity: laccord-cadre | Type: LOC | Start: 37 | End: 50
# Entity: laccord BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 18 | End: 66
# Entity: DELAI | Type: ORG | Start: 77 | End: 82
# Entity: RELEVANT | Type: LOC | Start: 27 | End: 35
# Entity: laccord | Type: ORG | Start: 283 | End: 290
# Entity: Lacte | Type: LOC | Start: 4 | End: 9
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 124 | End: 151
# Entity: DELAI | Type: ORG | Start: 125 | End: 130
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: SUBSEQUENTS | Type: ORG | Start: 68 | End: 79
# Entity: CCAP | Type: ORG | Start: 419 | End: 423
# Entity: laccord-cadre | Type: LOC | Start: 66 | End: 79
# Entity: Léquipe | Type: ORG | Start: 0 | End: 7
# Entity: Remplacement | Type: ORG | Start: 216 | End: 228
# Entity: lalinéa | Type: LOC | Start: 199 | End: 206
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 671 | End: 698
# Entity: CCAP | Type: ORG | Start: 551 | End: 555
# Entity: EXIGENCES | Type: ORG | Start: 0 | End: 9
# Entity: AUX | Type: LOC | Start: 20 | End: 23
# Entity: Solidarité Active lAAH | Type: ORG | Start: 37 | End: 105
# Entity: PACEA SMA SMV Garantie Jeunes lEcole de
# la Deuxième Chance E2C | Type: ORG | Start: 275 | End: 408
# Entity: Insertion | Type: ORG | Start: 57 | End: 66
# Entity: Association Intermédiaire | Type: ORG | Start: 148 | End: 173
# Entity: Entreprise de
# Travail | Type: ORG | Start: 189 | End: 210
# Entity: ETTI | Type: ORG | Start: 12 | End: 16
# Entity: EI | Type: ORG | Start: 13 | End: 15
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 12 | End: 39
# Entity: ACI | Type: ORG | Start: 78 | End: 81
# Entity: GEIQ Groupements dEmployeurs | Type: ORG | Start: 164 | End: 193
# Entity: RIEP | Type: ORG | Start: 165 | End: 169
# Entity: lheure | Type: LOC | Start: 162 | End: 168
# Entity: Lot 1 - Gouvernance | Type: LOC | Start: 80 | End: 99
# Entity: HT | Type: ORG | Start: 171 | End: 173
# Entity: Lot | Type: LOC | Start: 183 | End: 186
# Entity: HT Lot 3 Intelligence Artificielle | Type: ORG | Start: 39 | End: 100
# Entity: HT | Type: ORG | Start: 58 | End: 60
# Entity: Lot | Type: LOC | Start: 70 | End: 73
# Entity: HT | Type: ORG | Start: 50 | End: 52
# Entity: Lattributaire | Type: LOC | Start: 0 | End: 13
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: Entreprise de travail temporaire | Type: ORG | Start: 19 | End: 51
# Entity: Association
# intermédiaire Groupement demployeurs pour linsertion Entreprise dinsertion | Type: ORG | Start: 7 | End: 199
# Entity: Entreprise
# dinsertion | Type: ORG | Start: 117 | End: 138
# Entity: SIAE | Type: LOC | Start: 923 | End: 927
# Entity: CCAP | Type: ORG | Start: 323 | End: 327
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: X CCAP AR | Type: ORG | Start: 343 | End: 470
# Entity: ARCHE MC2 CNIL | Type: ORG | Start: 90 | End: 144
# Entity: Règlement européen UE | Type: ORG | Start: 384 | End: 416
# Entity: Paris BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 33 | End: 74
# Entity: Commission Nationale de lInformatique | Type: ORG | Start: 138 | End: 175
# Entity: Commission Nationale de lInformatique | Type: ORG | Start: 214 | End: 251
# Entity: CNIL | Type: ORG | Start: 269 | End: 273
# Entity: Place de Fontenoy | Type: LOC | Start: 277 | End: 294
# Entity: PARIS | Type: ORG | Start: 311 | End: 316
# Entity: ENVIRONNEMENTALES | Type: ORG | Start: 175 | End: 192
# Entity: laccord | Type: ORG | Start: 171 | End: 178
# Entity: laccord-cadre | Type: LOC | Start: 240 | End: 253
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 505 | End: 532
# Entity: laccord-cadre | Type: LOC | Start: 280 | End: 293
# Entity: A | Type: LOC | Start: 743 | End: 744
# Entity: Comité consultatif de règlement amiable
# des | Type: ORG | Start: 70 | End: 113
# Entity: Comité consultatif national de règlement amiable
# des | Type: ORG | Start: 280 | End: 332
# Entity: Paris | Type: LOC | Start: 477 | End: 482
# Entity: CONSTATATION | Type: LOC | Start: 0 | End: 12
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 181 | End: 208
# Entity: BL | Type: LOC | Start: 79 | End: 81
# Entity: BL BL | Type: ORG | Start: 304 | End: 314
# Entity: Service Régulier | Type: ORG | Start: 54 | End: 70
# Entity: Ministère de
# modifier afin | Type: ORG | Start: 132 | End: 158
# Entity: Ministère | Type: ORG | Start: 3 | End: 12
# Entity: Ordre de Marche
#  | Type: ORG | Start: 370 | End: 386
# Entity: Ministère | Type: ORG | Start: 140 | End: 149
# Entity: Ministère Ministère | Type: ORG | Start: 3 | End: 133
# Entity: Anomalie | Type: LOC | Start: 170 | End: 178
# Entity: Ministère | Type: ORG | Start: 246 | End: 255
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 296 | End: 323
# Entity: VA | Type: LOC | Start: 3 | End: 5
# Entity: VA | Type: LOC | Start: 27 | End: 29
# Entity: Ministère | Type: ORG | Start: 202 | End: 211
# Entity: VA | Type: LOC | Start: 274 | End: 276
# Entity: Ministère | Type: ORG | Start: 116 | End: 125
# Entity: Service Fait | Type: ORG | Start: 254 | End: 266
# Entity: Décision | Type: LOC | Start: 104 | End: 112
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 539 | End: 566
# Entity: Ministère | Type: ORG | Start: 3 | End: 12
# Entity: PAQ | Type: ORG | Start: 14 | End: 17
# Entity: Ministère Ministère | Type: ORG | Start: 62 | End: 263
# Entity: lavance | Type: LOC | Start: 36 | End: 43
# Entity: Titulaire | Type: LOC | Start: 46 | End: 55
# Entity: Titulaire | Type: LOC | Start: 62 | End: 71
# Entity: Diffusion Restreinte | Type: ORG | Start: 0 | End: 20
# Entity: DR | Type: ORG | Start: 0 | End: 2
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 9 | End: 36
# Entity: GARANTIE
# Lensemble | Type: ORG | Start: 47 | End: 65
# Entity: LACCORD | Type: LOC | Start: 139 | End: 146
# Entity: états dacomptes | Type: LOC | Start: 147 | End: 162
# Entity: TIG | Type: ORG | Start: 285 | End: 288
# Entity: HT | Type: ORG | Start: 338 | End: 340
# Entity: HT | Type: ORG | Start: 200 | End: 202
# Entity: P | Type: LOC | Start: 195 | End: 196
# Entity: V x R/100 | Type: ORG | Start: 199 | End: 208
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 215 | End: 242
# Entity: P | Type: LOC | Start: 16 | End: 17
# Entity: HT
# R | Type: ORG | Start: 49 | End: 53
# Entity: TVA | Type: ORG | Start: 261 | End: 264
# Entity: P Mnt | Type: LOC | Start: 867 | End: 874
# Entity: BdC | Type: LOC | Start: 0 | End: 3
# Entity: P | Type: LOC | Start: 131 | End: 132
# Entity: P Mt BdC | Type: LOC | Start: 2 | End: 12
# Entity: P | Type: LOC | Start: 851 | End: 852
# Entity: P | Type: LOC | Start: 880 | End: 881
# Entity: HT
# R | Type: ORG | Start: 919 | End: 923
# Entity: HT | Type: ORG | Start: 139 | End: 141
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 188 | End: 215
# Entity: HT HT | Type: ORG | Start: 301 | End: 399
# Entity: FINANCIER | Type: ORG | Start: 12 | End: 21
# Entity: lavance | Type: LOC | Start: 11 | End: 18
# Entity: HT | Type: ORG | Start: 262 | End: 264
# Entity: lavance | Type: LOC | Start: 123 | End: 130
# Entity: R.2191-11 | Type: LOC | Start: 162 | End: 171
# Entity: R.2191-22 | Type: LOC | Start: 170 | End: 179
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 77 | End: 104
# Entity: CBCM | Type: ORG | Start: 104 | End: 108
# Entity: lEtat | Type: LOC | Start: 477 | End: 482
# Entity: L.2192 | Type: LOC | Start: 102 | End: 108
# Entity: R.2192-36 | Type: LOC | Start: 434 | End: 443
# Entity: Banque centrale européenne | Type: ORG | Start: 75 | End: 101
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 97 | End: 124
# Entity: HNO | Type: LOC | Start: 18 | End: 21
# Entity: CCAP | Type: ORG | Start: 241 | End: 245
# Entity: VA | Type: ORG | Start: 56 | End: 58
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: Chorus pro | Type: ORG | Start: 158 | End: 168
# Entity: https://communaute.chorus-pro.gouv.fr/ | Type: ORG | Start: 337 | End: 375
# Entity: Service | Type: ORG | Start: 82 | End: 89
# Entity: avenue Duquesne | Type: LOC | Start: 126 | End: 141
# Entity: BPM060225_DATAVAL BPM060225 avenue Duquesne | Type: LOC | Start: 590 | End: 894
# Entity: Téléphone TVA | Type: ORG | Start: 13 | End: 177
# Entity: Monnaie
# Lunité monétaire | Type: ORG | Start: 11 | End: 35
# Entity: UE Parlement européen Conseil | Type: ORG | Start: 236 | End: 284
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: lUnion | Type: ORG | Start: 299 | End: 305
# Entity: Etats | Type: LOC | Start: 322 | End: 327
# Entity: lUnion européenne | Type: ORG | Start: 129 | End: 146
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 359 | End: 386
# Entity: Régime des droits sur les résultats
#   | Type: ORG | Start: 0 | End: 37
# Entity: Ministères sociaux | Type: ORG | Start: 59 | End: 77
# Entity: la France létranger BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 228 | End: 291
# Entity: Régime des droits sur les connaissances antérieures
#  | Type: ORG | Start: 305 | End: 357
# Entity: laccord-cadre | Type: LOC | Start: 563 | End: 576
# Entity: ASSURANCES | Type: ORG | Start: 63 | End: 73
# Entity: ADMINISTRATIVES | Type: ORG | Start: 19 | End: 34
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 121 | End: 148
# Entity: D.8222-7 | Type: LOC | Start: 152 | End: 160
# Entity: D.8254-5 | Type: LOC | Start: 175 | End: 183
# Entity: L.2195-6 | Type: LOC | Start: 98 | End: 106
# Entity: Laccord | Type: LOC | Start: 0 | End: 7
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: APPELANT | Type: ORG | Start: 438 | End: 446
# Entity: DURGENCE | Type: LOC | Start: 0 | End: 8
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 98 | End: 125
# Entity: Suspension | Type: ORG | Start: 0 | End: 10
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 5 | End: 32
# Entity: L. 2195-2 | Type: LOC | Start: 258 | End: 267
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC | Start: 428 | End: 455
# Entity: Tribunal administratif de Paris | Type: ORG | Start: 58 | End: 89
# Entity: rue de Jouy
# 75004 Paris | Type: LOC | Start: 93 | End: 117
# Entity: R2197-25 | Type: LOC | Start: 175 | End: 183
# Entity: Paris | Type: LOC | Start: 368 | End: 373
# Entity: Confidentialité | Type: ORG | Start: 27 | End: 42
# Entity: Lavance | Type: LOC | Start: 302 | End: 309

# %%
import spacy
nlp = spacy.load("fr_core_news_lg")
print("Model loaded!")
# Out:
# Model loaded!

# %%
import os
# Change working directory to the correct path
os.chdir(r"C:\Users\hp\Downloads\clever contact")

# Verify the new working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\hp\Downloads\clever contact

# %%
import json

def merge_ner_results(spacy_results, flair_results):
    """ Merges SpaCy and Flair results by matching entity text. """
    merged_entities = []
    entity_dict = {}

    # Combine entities from both models
    for entity in spacy_results + flair_results:
        key = entity["text"]  # Match by entity text only

        if key in entity_dict:
            existing = entity_dict[key]
            # If the entity types are the same, keep one
            if entity["type"] == existing["type"]:  
                entity_dict[key] = entity  
        else:
            entity_dict[key] = entity  # Add new entity if it's not present

    return list(entity_dict.values())

# File paths
spacy_json_path = "spacy_extracted_entities4.json"
flair_json_path = "flair_finetuned_entities_fulltext4.json"
merged_output_path = "merged_spacy_flair_entities4.json"

# Load extracted entities from JSON files
with open(spacy_json_path, "r", encoding="utf-8") as f:
    spacy_entities = json.load(f)
print(f" Loaded {len(spacy_entities)} entities from SpaCy output!")

with open(flair_json_path, "r", encoding="utf-8") as f:
    flair_entities = json.load(f)
print(f" Loaded {len(flair_entities)} entities from Flair output!")

# Merge SpaCy & Flair results
final_entities = merge_ner_results(spacy_entities, flair_entities)

# Save merged results to a new JSON file
with open(merged_output_path, "w", encoding="utf-8") as f:
    json.dump(final_entities, f, ensure_ascii=False, indent=4)

print(f"\n Merged NER results saved in {merged_output_path}!")

# Print some merged entities for verification
print("\n Final Merged Entities Sample:")
for entity in final_entities[:10]:  # Print only first 10
    print(f"Entity: {entity['text']} | Type: {entity['type']}")
# Out:
#  Loaded 285 entities from SpaCy output!
#  Loaded 295 entities from Flair output!
#
#  Merged NER results saved in merged_spacy_flair_entities4.json!
#
#  Final Merged Entities Sample:
# Entity: BPM060225 | Type: LOC
# Entity: R2161-2 R2161-5 | Type: LOC
# Entity: ACHETEUR | Type: ORG
# Entity: BPM060225_DATAVAL BPM060225 | Type: LOC
# Entity: laccord | Type: LOC
# Entity: État | Type: LOC
# Entity: Exigences | Type: LOC
# Entity: Décision | Type: LOC
# Entity: Pénalités | Type: LOC
# Entity: TVA | Type: ORG

# %%
import json

def get_common_entities(spacy_results, flair_results):
    """Extracts only entities that are common between SpaCy and Flair."""
    common_entities = []
    
    # Convert Flair entities into a dictionary for quick lookup
    flair_dict = { (entity["text"].lower(), entity["type"]) for entity in flair_results }

    # Compare each SpaCy entity to Flair's results
    for entity in spacy_results:
        key = (entity["text"].lower(), entity["type"])  # Normalize case
        if key in flair_dict:  # Entity exists in both SpaCy and Flair
            common_entities.append(entity)

    return common_entities 

# File paths
spacy_json_path = "spacy_extracted_entities4.json"
flair_json_path = "flair_finetuned_entities_fulltext4.json"
common_output_path = "common_spacy_flair_entities4.json"

# Load extracted entities from JSON files
with open(spacy_json_path, "r", encoding="utf-8") as f:
    spacy_entities = json.load(f)
print(f" Loaded {len(spacy_entities)} entities from SpaCy output!")

with open(flair_json_path, "r", encoding="utf-8") as f:
    flair_entities = json.load(f)
print(f" Loaded {len(flair_entities)} entities from Flair output!")

# Find common entities
common_entities = get_common_entities(spacy_entities, flair_entities)

# Save common results to a new JSON file
with open(common_output_path, "w", encoding="utf-8") as f:
    json.dump(common_entities, f, ensure_ascii=False, indent=4)

print(f"\n Common NER results saved in {common_output_path}!")

# Print some common entities for verification
print("\n Common Entities Found in Both SpaCy & Flair:")
for entity in common_entities[:10]:  # Print only first 10
    print(f"Entity: {entity['text']} | Type: {entity['type']}")
# Out:
#  Loaded 285 entities from SpaCy output!
#  Loaded 295 entities from Flair output!
#
#  Common NER results saved in common_spacy_flair_entities4.json!
#
#  Common Entities Found in Both SpaCy & Flair:
# Entity: État | Type: LOC
# Entity: Direction du numérique | Type: ORG
# Entity: Directions des Ministères sociaux | Type: ORG
# Entity: Direction du Numérique | Type: ORG
# Entity: Direction du numérique | Type: ORG
# Entity: Direction du NUMérique | Type: ORG
# Entity: Lot | Type: LOC
# Entity: Lot | Type: LOC
# Entity: Lot | Type: LOC
# Entity: Ministères Sociaux | Type: ORG
